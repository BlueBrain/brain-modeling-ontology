# %%
import copy
import getpass
import rdflib

from collections import defaultdict

import numpy as np
import pandas as pd

from kgforge.core import KnowledgeGraphForge
from kgforge.specializations.resources import Dataset

from bluegraph import PandasPGFrame
from bluegraph.backends.neo4j import pgframe_to_neo4j

from bmo.ontologies import subontology_from_term
from bmo.kbs.gene_kbs import get_gene_data

# %%
ONTO_CLASS_LABEL = "ONTOLOGY_CLASS"

# %% [markdown]
# ## Fetch protein interactions from Nexus

# %%
ENDPOINT = "https://bbp.epfl.ch/nexus/v1"
ORG = "bbp"
PROJ = "membranal-protein-interactions"

# %%
TOKEN = getpass.getpass()
# Out:
# ········

# %%
forge = KnowledgeGraphForge("../../config/prod-forge-config.yml",
                            endpoint=ENDPOINT,
                            token=TOKEN,
                            bucket=f"{ORG}/{PROJ}")

# %%
interactions = forge.search({"type": "Interaction"}, limit=None)
interactions_df = forge.as_dataframe(interactions)

# %%
interactions_df.sample(5)
# Out:
#                                                      id  \
# 978   https://bbp.epfl.ch/neurosciencegraph/data/int...
# 27    https://bbp.epfl.ch/neurosciencegraph/data/int...
# 506   https://bbp.epfl.ch/neurosciencegraph/data/int...
# 386   https://bbp.epfl.ch/neurosciencegraph/data/int...
# 1329  https://bbp.epfl.ch/neurosciencegraph/data/int...
#
#                        type  \
# 978   [Interaction, Entity]
# 27    [Interaction, Entity]
# 506   [Interaction, Entity]
# 386   [Interaction, Entity]
# 1329  [Interaction, Entity]
#
#                                                    name  \
# 978   Membranal protein interaction between Potassiu...
# 27    Membranal protein interaction between Acid-sen...
# 506   Membranal protein interaction between Proton c...
# 386   Membranal protein interaction between Voltage-...
# 1329  Membranal protein interaction between Acid-sen...
#
#                                             participant
# 978   [{'motif': {'type': 'Motif', 'cost': 2, 'error...
# 27    [{'motif': {'type': 'Motif', 'cost': 2, 'error...
# 506   [{'motif': {'type': 'Motif', 'cost': 2, 'error...
# 386   [{'motif': {'type': 'Motif', 'cost': 1, 'error...
# 1329  [{'motif': {'type': 'Motif', 'cost': 2, 'error...

# %%
genes = forge.search({"type": "Gene"}, limit=None)

# %%
gene_df = forge.as_dataframe(genes)

# %%
proteins = forge.search({"type": "Protein"}, limit=None)
protein_df = forge.as_dataframe(proteins)

# %%
def get_participation_data(x, index):
    interaction_id = x.id
    participant_id = x["participant"][index]["protein"]["id"]
    data = copy.deepcopy(x["participant"][index]["motif"])
    del data["type"]
    data["fixedResidue"] = data["fixedResidue"]["count"]
    data["motif"] = data["value"]
    del data["value"]
    data["@source_id"] = participant_id
    data["@target_id"] = interaction_id
    return data

# %%
def generate_edge_frame(df, index):
    edges = pd.DataFrame(
        df.apply(lambda x: get_participation_data(x, index), axis=1).tolist())
    edges["@type"] = "participatesIn"
    edges = edges.set_index(["@source_id", "@target_id"])
    return edges

# %%
participation_edges = pd.concat([
    generate_edge_frame(interactions_df, 0),
    generate_edge_frame(interactions_df, 1)
])

# %%
encoded_edges = protein_df[["id", "encodedBy.id"]].rename(columns={
    "id": "@source_id",
    "encodedBy.id": "@target_id"
}).set_index(["@source_id", "@target_id"])
encoded_edges["@type"] = "encodedBy"

# %%
gene_df.sample(5)
# Out:
#                                                     id            type  \
# 235  https://bbp.epfl.ch/neurosciencegraph/data/gen...  [Gene, Entity]
# 456  https://bbp.epfl.ch/neurosciencegraph/data/gen...  [Gene, Entity]
# 140  https://bbp.epfl.ch/neurosciencegraph/data/gen...  [Gene, Entity]
# 323  https://bbp.epfl.ch/neurosciencegraph/data/gen...  [Gene, Entity]
# 76   https://bbp.epfl.ch/neurosciencegraph/data/gen...  [Gene, Entity]
#
#          name subject.type                              subject.species.id  \
# 235     Avpr2      Subject  http://purl.obolibrary.org/obo/NCBITaxon_10090
# 456  Slc22a18      Subject  http://purl.obolibrary.org/obo/NCBITaxon_10090
# 140      SV2B      Subject   http://purl.obolibrary.org/obo/NCBITaxon_9606
# 323     ACKR3      Subject   http://purl.obolibrary.org/obo/NCBITaxon_9606
# 76      CHRM2      Subject   http://purl.obolibrary.org/obo/NCBITaxon_9913
#
#     subject.species.label
# 235          Mus musculus
# 456          Mus musculus
# 140          Homo sapiens
# 323          Homo sapiens
# 76             Bos taurus

# %% [markdown]
# ## Get additional gene data from Ensembl

# %%
records = {}
for gene in gene_df[["name", "subject.species.label"]].to_dict("records"):
    gene_name = gene["name"]
    species = gene["subject.species.label"].lower().replace(" ", "_")
    print(gene_name, species)
    if (gene_name, species) not in records:
        try:a
            records[(gene_name, species)] = get_gene_data(
                gene_name, species)
        except TypeError as e:
            print(e)
            print("Skipped: ", gene["name"])
#             break
# Out:
# PLPP1 homo_sapiens
# Rom1 mus_musculus
# Selp mus_musculus
# Ntrk1 rattus_norvegicus
# Aqp2 rattus_norvegicus
# Chrm4 rattus_norvegicus
# Mc5r rattus_norvegicus
# ADRA1B homo_sapiens
# Olr1571 rattus_norvegicus
# SRC2 arabidopsis_thaliana
# SLC1A4 homo_sapiens
# Ldlr rattus_norvegicus
# OPT2 arabidopsis_thaliana
# Tnfrsf4 mus_musculus
# Htr1f mus_musculus
# AQP2 homo_sapiens
# Mc5r mus_musculus
# Chrm2 rattus_norvegicus
# GCGR homo_sapiens
# STP7 arabidopsis_thaliana
# Ldlr mus_musculus
# TACR2 homo_sapiens
# Slc1a2 mus_musculus
# Clcn5 rattus_norvegicus
# Clcn3 mus_musculus
# COMT homo_sapiens
# AQP5 homo_sapiens
# ADCY7 homo_sapiens
# Slc5a2 rattus_norvegicus
# Gcgr rattus_norvegicus
# Epha2 mus_musculus
# Coq8b mus_musculus
# Abcg1 mus_musculus
# AQP4 homo_sapiens
# CHRM2 gallus_gallus
# SLC1A2 homo_sapiens
# Sdc3 mus_musculus
# CLCN3 homo_sapiens
# Adcy6 mus_musculus
# Trpc1 mus_musculus
# CCKBR homo_sapiens
# Aqp5 rattus_norvegicus
# Mip mus_musculus
# Aqp4 mus_musculus
# MC5R homo_sapiens
# Asic3 rattus_norvegicus
# RBOHF arabidopsis_thaliana
# Slc5a10 mus_musculus
# Slc39a4 mus_musculus
# Ntrk1 mus_musculus
# SLC43A2 homo_sapiens
# UNC5A homo_sapiens
# MUC3B homo_sapiens
# GPR135 homo_sapiens
# CD300A homo_sapiens
# HCST homo_sapiens
# OR6S1 homo_sapiens
# TSPAN18 homo_sapiens
# OR1S2 homo_sapiens
# P2RY11 homo_sapiens
# FCRL6 homo_sapiens
# GNRHR2 homo_sapiens
# OR4S1 homo_sapiens
# COQ8B homo_sapiens
# SLC52A3 homo_sapiens
# ESAM homo_sapiens
# SELP bos_taurus
# SERINC5 homo_sapiens
# LAPTM5 homo_sapiens
# MARVELD1 homo_sapiens
# mfsd5 danio_rerio
# Cacna1h rattus_norvegicus
# FCRL5 homo_sapiens
# CACNA1C homo_sapiens
# STAB1 homo_sapiens
# Cd47 rattus_norvegicus
# CHRM2 bos_taurus
# CELSR3 homo_sapiens
# CACNA1H homo_sapiens
# MGAM homo_sapiens
# ABCC5 homo_sapiens
# heg danio_rerio
# Cacna1h mus_musculus
# Chrm1 mus_musculus
# Fpr-rs4 mus_musculus
# GALR2 homo_sapiens
# Sstr4 rattus_norvegicus
# OR4C46 homo_sapiens
# Slc16a2 mus_musculus
# Ackr3 rattus_norvegicus
# BAK1 arabidopsis_thaliana
# Slc26a3 rattus_norvegicus
# GPR182 homo_sapiens
# Ldlrad3 mus_musculus
# Ackr2 mus_musculus
# NPC1 homo_sapiens
# Chrm5 rattus_norvegicus
# SLC16A2 rattus_norvegicus
# Itpr3 rattus_norvegicus
# Bace2 rattus_norvegicus
# AQP4 bos_taurus
# SLC26A9 homo_sapiens
# Avpr2 rattus_norvegicus
# Parm1 mus_musculus
# AVPR2 bos_taurus
# ABCG23 arabidopsis_thaliana
# Slc39a8 mus_musculus
# CAT5 arabidopsis_thaliana
# Abcg2 mus_musculus
# STP1 arabidopsis_thaliana
# Mip rattus_norvegicus
# Abca4 mus_musculus
# Ptch2 mus_musculus
# PLXNB1 homo_sapiens
# Slc16a3 rattus_norvegicus
# CALHM4 homo_sapiens
# MIP gallus_gallus
# OXER1 homo_sapiens
# TSPAN18 bos_taurus
# SULTR4 arabidopsis_thaliana
# asic4b danio_rerio
# SLC16A13 homo_sapiens
# SLC26A11 bos_taurus
# SLC16A14 homo_sapiens
# MC5R bos_taurus
# SYPL1 homo_sapiens
# At5g41800 arabidopsis_thaliana
# asic1c danio_rerio
# taar13c danio_rerio
# asic1b danio_rerio
# asic2 danio_rerio
# OR10AC1 homo_sapiens
# KIRREL3 homo_sapiens
# NRG4 homo_sapiens
# SLC2A6 homo_sapiens
# slc39a1 danio_rerio
# SLC16A11 homo_sapiens
# ASIC4 homo_sapiens
# HGSNAT homo_sapiens
# DUOXA1 homo_sapiens
# SV2B homo_sapiens
# MRGPRX4 homo_sapiens
# SLC39A8 homo_sapiens
# OR11H7 homo_sapiens
# AVP1 arabidopsis_thaliana
# AQP2 bos_taurus
# DCST1 homo_sapiens
# SLC5A5 homo_sapiens
# SLC6A7 homo_sapiens
# KCNK15 homo_sapiens
# ASIC2 homo_sapiens
# Slc16a3 mus_musculus
# Ttyh2 mus_musculus
# Erbb3 mus_musculus
# Gcgr mus_musculus
# Asic2 rattus_norvegicus
# Asic2 mus_musculus
# MIP bos_taurus
# ICAM4 homo_sapiens
# TACR2 bos_taurus
# TRPC6 bos_taurus
# TRPC1 bos_taurus
# Asic3 mus_musculus
# Slc7a9 rattus_norvegicus
# OPT3 arabidopsis_thaliana
# Plxnb1 mus_musculus
# Slc16a14 mus_musculus
# Unc5a mus_musculus
# Slc22a12 rattus_norvegicus
# Kirrel3 mus_musculus
# Erbb3 rattus_norvegicus
# Slc39a8 rattus_norvegicus
# Slc52a3 rattus_norvegicus
# RHAG homo_sapiens
# Selp rattus_norvegicus
# Duoxa1 mus_musculus
# ATP1A4 homo_sapiens
# Adcy5 rattus_norvegicus
# Adcy6 rattus_norvegicus
# Slc6a7 mus_musculus
# asic1a danio_rerio
# ADCY1 bos_taurus
# SLAMF1 homo_sapiens
# ADCY1 homo_sapiens
# asic4a danio_rerio
# CHRM4 gallus_gallus
# SLC1A5 homo_sapiens
# Marveld1 mus_musculus
# Slc43a2 mus_musculus
# Otop1 mus_musculus
# Slc26a11 mus_musculus
# Stab1 mus_musculus
# Slc16a13 mus_musculus
# Tmc6 mus_musculus
# Aqp6 mus_musculus
# TMC6 homo_sapiens
# YSL3 arabidopsis_thaliana
# Abca7 mus_musculus
# Celsr3 mus_musculus
# ASIC3 homo_sapiens
# MYMK homo_sapiens
# Htr1f rattus_norvegicus
# HTR1F homo_sapiens
# MIP homo_sapiens
# ASIC1 homo_sapiens
# SLC22A1 homo_sapiens
# Slc6a7 rattus_norvegicus
# Cxcr4 rattus_norvegicus
# Asic1 rattus_norvegicus
# Slc22a1 mus_musculus
# Unc5a rattus_norvegicus
# Plpp1 rattus_norvegicus
# Adcy1 mus_musculus
# SCAMP1 homo_sapiens
# GPR31 homo_sapiens
# PLPP2 homo_sapiens
# Plxnb3 rattus_norvegicus
# Asic1 mus_musculus
# SLC16A3 homo_sapiens
# SLC5A10 homo_sapiens
# CHRM4 homo_sapiens
# MSL6 arabidopsis_thaliana
# HTR1E homo_sapiens
# TPK4 arabidopsis_thaliana
# MSL7 arabidopsis_thaliana
# Aqp2 mus_musculus
# EPHA2 homo_sapiens
# DUR3 arabidopsis_thaliana
# IRT2 arabidopsis_thaliana
# ABCC6 homo_sapiens
# OPT7 arabidopsis_thaliana
# AVT1I arabidopsis_thaliana
# Epha1 mus_musculus
# Cckbr mus_musculus
# Cckbr rattus_norvegicus
# Avpr2 mus_musculus
# Cxcr4 mus_musculus
# CHRM2 homo_sapiens
# Slc1a2 rattus_norvegicus
# Scarb1 mus_musculus
# ITGAV homo_sapiens
# Plpp1 mus_musculus
# Chrm4 mus_musculus
# C3ar1 rattus_norvegicus
# MLNR homo_sapiens
# Sirpa rattus_norvegicus
# Npc1l1 rattus_norvegicus
# Ano7 rattus_norvegicus
# Slc52a2 rattus_norvegicus
# CHRM1 homo_sapiens
# Tmem100 rattus_norvegicus
# Ackr2 rattus_norvegicus
# Erbb2 rattus_norvegicus
# Gramd1a rattus_norvegicus
# ACKR2 homo_sapiens
# Abcc2 rattus_norvegicus
# Cdh20 rattus_norvegicus
# Aqp4 rattus_norvegicus
# Amigo1 rattus_norvegicus
# Celsr3 rattus_norvegicus
# PIGN homo_sapiens
# Slc6a2 mus_musculus
# SELP homo_sapiens
# Adra1b rattus_norvegicus
# Cdh22 rattus_norvegicus
# CTLA4 homo_sapiens
# Slc4a9 rattus_norvegicus
# ZP3 homo_sapiens
# ABCG1 homo_sapiens
# Fgfr4 rattus_norvegicus
# ADCY6 homo_sapiens
# Dscam rattus_norvegicus
# Hrh2 rattus_norvegicus
# C3ar1 mus_musculus
# Chrm1 rattus_norvegicus
# Hcn4 rattus_norvegicus
# Chrne rattus_norvegicus
# Hcn1 rattus_norvegicus
# ADCY7 bos_taurus
# HCN3 homo_sapiens
# Aqp8 rattus_norvegicus
# Hcn3 rattus_norvegicus
# HCN2 homo_sapiens
# cftr danio_rerio
# Klri1 rattus_norvegicus
# Hcn1 mus_musculus
# HVCN1 homo_sapiens
# Hcn2 mus_musculus
# Hcn2 rattus_norvegicus
# Hcn3 mus_musculus
# Drd1 rattus_norvegicus
# SLC11A1 gallus_gallus
# SMPD2 homo_sapiens
# ASIC1 gallus_gallus
# SLC16A2 homo_sapiens
# Fcamr mus_musculus
# Fcer1g mus_musculus
# Hvcn1 mus_musculus
# At1g31820 arabidopsis_thaliana
# At1g31830 arabidopsis_thaliana
# Abca1 mus_musculus
# RST1 arabidopsis_thaliana
# SERK5 arabidopsis_thaliana
# SLC7A9 homo_sapiens
# CD34 homo_sapiens
# CCR7 homo_sapiens
# OR4A47 homo_sapiens
# CLDN6 homo_sapiens
# ABCA12 homo_sapiens
# MRGPRE homo_sapiens
# Itpr3 mus_musculus
# KCNMB4 homo_sapiens
# SLC20A2 homo_sapiens
# Sirpa mus_musculus
# FPR2 homo_sapiens
# OR52E4 homo_sapiens
# TACR1 homo_sapiens
# Ptprm mus_musculus
# ROM1 bos_taurus
# ABCA1 homo_sapiens
# MRGPRF homo_sapiens
# OR5M3 homo_sapiens
# RLP57 arabidopsis_thaliana
# ACKR3 homo_sapiens
# OR5B3 homo_sapiens
# SIRPA homo_sapiens
# SLC38A5 homo_sapiens
# LDLR homo_sapiens
# NHX8 arabidopsis_thaliana
# Ccr7 mus_musculus
# CHRNE homo_sapiens
# OPT4 arabidopsis_thaliana
# ABCG2 bos_taurus
# Chrne mus_musculus
# OR4A16 homo_sapiens
# C3AR1 homo_sapiens
# CXCR1 homo_sapiens
# NHX2 arabidopsis_thaliana
# SLC52A3 bos_taurus
# DRD1 homo_sapiens
# THE1 arabidopsis_thaliana
# CHRM5 homo_sapiens
# Sstr4 mus_musculus
# LDLRAD3 homo_sapiens
# At5g16150 arabidopsis_thaliana
# OR6T1 homo_sapiens
# DSG4 homo_sapiens
# SLC38A4 homo_sapiens
# KIR3DL1 homo_sapiens
# OR4A4P homo_sapiens
# SLC10A6 homo_sapiens
# PTPRM homo_sapiens
# OR51G1 homo_sapiens
# OR6K6 homo_sapiens
# IGDCC4 homo_sapiens
# TAS2R19 homo_sapiens
# CXCR2 homo_sapiens
# ADORA2A homo_sapiens
# Ano7 mus_musculus
# ITPR3 homo_sapiens
# GRAMD1C homo_sapiens
# OR1L3 homo_sapiens
# OR4A8 homo_sapiens
# SLC13A3 homo_sapiens
# Ackr3 mus_musculus
# CLDN23 homo_sapiens
# APLP1 homo_sapiens
# ATP1A2 gallus_gallus
# SLC16A7 homo_sapiens
# Kcne2 rattus_norvegicus
# Slc40a1 rattus_norvegicus
# Abca7 rattus_norvegicus
# App rattus_norvegicus
# Slco1a5 rattus_norvegicus
# YSL7 arabidopsis_thaliana
# Kcnh4 rattus_norvegicus
# ABCG29 arabidopsis_thaliana
# Slco1a4 rattus_norvegicus
# Slc24a2 rattus_norvegicus
# Smpd2 rattus_norvegicus
# CCKBR bos_taurus
# Slc5a5 rattus_norvegicus
# Otop1 rattus_norvegicus
# SERK4 arabidopsis_thaliana
# SDC3 homo_sapiens
# Slc22a1 rattus_norvegicus
# Coq8b rattus_norvegicus
# mymk danio_rerio
# Clcn3 rattus_norvegicus
# Slc22a2 rattus_norvegicus
# SLC43A1 homo_sapiens
# CLCN5 homo_sapiens
# Slc1a5 mus_musculus
# LPLAT1 arabidopsis_thaliana
# MSL8 arabidopsis_thaliana
# Slc16a13 rattus_norvegicus
# Kcnk15 rattus_norvegicus
# KCNH5 homo_sapiens
# Plpp2 rattus_norvegicus
# Slc12a9 rattus_norvegicus
# Abcg2 rattus_norvegicus
# Trpc1 rattus_norvegicus
# KCNJ9 homo_sapiens
# SLC1A5 bos_taurus
# Kcnj9 rattus_norvegicus
# Kcnh5 mus_musculus
# Kcnk10 rattus_norvegicus
# Kcnj3 mus_musculus
# Kcnh5 rattus_norvegicus
# KCNK2 homo_sapiens
# KCNJ3 homo_sapiens
# Kcnj6 mus_musculus
# Kcnj3 rattus_norvegicus
# Kcnj9 mus_musculus
# KCNK10 homo_sapiens
# Kcnk2 rattus_norvegicus
# ABCG10 arabidopsis_thaliana
# NHX1 arabidopsis_thaliana
# RLP31 arabidopsis_thaliana
# PERK6 arabidopsis_thaliana
# ABCG22 arabidopsis_thaliana
# At3g25290 arabidopsis_thaliana
# ABCG21 arabidopsis_thaliana
# SLC43A2 bos_taurus
# Mst1r mus_musculus
# AZG2 arabidopsis_thaliana
# COR2 gallus_gallus
# SLC5A10 bos_taurus
# SERK1 arabidopsis_thaliana
# slc2a12 danio_rerio
# RLP44 arabidopsis_thaliana
# DEK1 arabidopsis_thaliana
# COR4 gallus_gallus
# RBOHB arabidopsis_thaliana
# IRT1 arabidopsis_thaliana
# NAT11 arabidopsis_thaliana
# FER arabidopsis_thaliana
# LECRK56 arabidopsis_thaliana
# YSL1 arabidopsis_thaliana
# COR5 gallus_gallus
# Kcnmb4 mus_musculus
# ABCG14 arabidopsis_thaliana
# LECRK82 arabidopsis_thaliana
# COR6 gallus_gallus
# Kcnmb4 rattus_norvegicus
# At3g13620 arabidopsis_thaliana
# ZIP7 arabidopsis_thaliana
# NHX7 arabidopsis_thaliana
# WAKL13 arabidopsis_thaliana
# Slc29a2 mus_musculus
# ZIP8 arabidopsis_thaliana
# Slc13a5 mus_musculus
# Sema4a mus_musculus
# DTX43 arabidopsis_thaliana
# RHAG bos_taurus
# Cd6 mus_musculus
# Slc22a18 mus_musculus
# Drd1 mus_musculus
# Cd47 mus_musculus
# YSL2 arabidopsis_thaliana
# LECRKS5 arabidopsis_thaliana
# Slc38a3 mus_musculus
# Npc1l1 mus_musculus
# Paqr8 mus_musculus
# Amigo1 mus_musculus
# Cldn23 mus_musculus
# Ghr mus_musculus
# Chrm5 mus_musculus
# Kcnn2 rattus_norvegicus
# Dscam mus_musculus
# Ghr rattus_norvegicus
# Mrgprx2 mus_musculus
# Kcnn1 mus_musculus
# STP6 arabidopsis_thaliana
# KCNN3 homo_sapiens
# SULTR3 arabidopsis_thaliana
# Nectin4 mus_musculus
# Bves mus_musculus
# Gramd1a mus_musculus
# YSL8 arabidopsis_thaliana
# KCNN2 homo_sapiens
# NKG7 bos_taurus
# Kcnn3 mus_musculus
# Slc19a3 mus_musculus
# CD37 bos_taurus
# NRT2.5 arabidopsis_thaliana
# Kcnn2 mus_musculus
# Tmc5 mus_musculus
# Kcnt2 rattus_norvegicus
# Kcnn3 rattus_norvegicus
# Kcnn1 rattus_norvegicus
# Gramd1c mus_musculus
# Tspan33 mus_musculus
# Igdcc4 mus_musculus
# HM13 homo_sapiens
# Hm13 mus_musculus
# PLPP2 bos_taurus
# Havcr2 mus_musculus
# Slco1a1 rattus_norvegicus
# KCNT2 homo_sapiens
# Adcy2 rattus_norvegicus
# APP oryctolagus_cuniculus
# MS4A1 homo_sapiens
# KCNE2 oryctolagus_cuniculus
# PCDH19 homo_sapiens
# ADCY2 homo_sapiens
# ATP10B homo_sapiens
# LRP4 homo_sapiens
# THBD homo_sapiens
# Slc28a2 rattus_norvegicus
# TSPAN6 homo_sapiens
# At2g19210 arabidopsis_thaliana
# MSL5 arabidopsis_thaliana
# SLC17A1 homo_sapiens
# CXCR4 homo_sapiens
# Mpig6b mus_musculus
# At1g80640 arabidopsis_thaliana
# CACNG1 bos_taurus
# SIRPA bos_taurus
# hvcn1 xenopus_laevis
# string indices must be integers
# Skipped:  hvcn1
# ROS1 gallus_gallus
# Tl drosophila_melanogaster
# Shab drosophila_melanogaster
# HVCN1 gallus_gallus
# Emp2 mus_musculus
# Slc4a3 rattus_norvegicus
# hvcn1 xenopus_tropicalis
# Tmc4 mus_musculus
# Piezo1 mus_musculus
# Slc4a3 mus_musculus
# drd1 xenopus_laevis
# string indices must be integers
# Skipped:  drd1
# ETN8 arabidopsis_thaliana
# ldlrad3 xenopus_tropicalis
# Uts2r rattus_norvegicus
# Tmc4 rattus_norvegicus
# Pdgfrb mus_musculus
# Slc30a8 rattus_norvegicus
# Ano8 mus_musculus
# Thsd7a mus_musculus
# At3g47570 arabidopsis_thaliana
# HRD1B arabidopsis_thaliana
# nAChRbeta1 drosophila_melanogaster
# CHRNE bos_taurus
# Alk mus_musculus
# Epcam rattus_norvegicus
# Pdgfrb rattus_norvegicus
# Notch4 mus_musculus
# At5g10290 arabidopsis_thaliana
# TMK1 arabidopsis_thaliana
# slc38a6 xenopus_tropicalis
# Slc26a1 rattus_norvegicus
# At5g05160 arabidopsis_thaliana
# NRT2.3 arabidopsis_thaliana
# At5g47470 arabidopsis_thaliana
# CRK29 arabidopsis_thaliana
# K-CAM gallus_gallus
# PSY1R arabidopsis_thaliana
# TPC1 arabidopsis_thaliana
# PHO1-H1 arabidopsis_thaliana
# At1g61480 arabidopsis_thaliana
# SWEET1 arabidopsis_thaliana
# NPF2.9 arabidopsis_thaliana
# At2g23680 arabidopsis_thaliana
# At3g16300 arabidopsis_thaliana
# SLAH2 arabidopsis_thaliana
# PAT22 arabidopsis_thaliana
# OCT1 arabidopsis_thaliana
# NPF2.14 arabidopsis_thaliana
# ABCG19 arabidopsis_thaliana
# FRO2 arabidopsis_thaliana
# CES101 arabidopsis_thaliana
# GTG2 arabidopsis_thaliana
# At3g18200 arabidopsis_thaliana
# 5 arabidopsis_thaliana
# At4g02900 arabidopsis_thaliana
# STT3B arabidopsis_thaliana
# At4g08290 arabidopsis_thaliana
# ALA1 arabidopsis_thaliana
# COR413PM2 arabidopsis_thaliana
# CHX21 arabidopsis_thaliana
# DWF5 arabidopsis_thaliana
# PEPR2 arabidopsis_thaliana
# At1g69450 arabidopsis_thaliana
# SULTR2 arabidopsis_thaliana
# PIP2-7 arabidopsis_thaliana
# LECRK41 arabidopsis_thaliana
# Trpc6 mus_musculus
# mom-5 caenorhabditis_elegans
# Trpc3 mus_musculus
# At1g74360 arabidopsis_thaliana
# glc-2 caenorhabditis_elegans
# At3g55390 arabidopsis_thaliana
# At3g28130 arabidopsis_thaliana
# TRPC3 homo_sapiens
# gab-1 caenorhabditis_elegans
# At3g06390 arabidopsis_thaliana
# RLP1 arabidopsis_thaliana
# ZIP1 arabidopsis_thaliana
# TRPC7 homo_sapiens
# TRPC6 homo_sapiens
# AAP1 arabidopsis_thaliana
# TRPC4 homo_sapiens
# Trpc5 mus_musculus
# TRPC5 homo_sapiens
# TRPM6 homo_sapiens
# Trpc4 mus_musculus
# CD200R1 homo_sapiens
# Trpc7 mus_musculus

# %%
for (name, species), v in records.items():
    v["name"] = name
    v["species"] = species.replace("_", " ").capitalize()

# %%
gene_df.sample(5)

# %%
gene_df.columns
# Out:
# Index(['id', 'type', 'name', 'subject.type', 'subject.species.id', 'species',
#        'ensembl_id', 'xrefs', 'uniprot_ac', 'desctiption', 'prefLabel',
#        'go_edges', 'label'],
#       dtype='object')

# %%
gene_df
# Out:
#                                                     id            type  \
# 0    https://bbp.epfl.ch/neurosciencegraph/data/gen...  [Gene, Entity]
# 1    https://bbp.epfl.ch/neurosciencegraph/data/gen...  [Gene, Entity]
# 2    https://bbp.epfl.ch/neurosciencegraph/data/gen...  [Gene, Entity]
# 3    https://bbp.epfl.ch/neurosciencegraph/data/gen...  [Gene, Entity]
# 4    https://bbp.epfl.ch/neurosciencegraph/data/gen...  [Gene, Entity]
# ..                                                 ...             ...
# 601  https://bbp.epfl.ch/neurosciencegraph/data/gen...  [Gene, Entity]
# 602  https://bbp.epfl.ch/neurosciencegraph/data/gen...  [Gene, Entity]
# 603  https://bbp.epfl.ch/neurosciencegraph/data/gen...  [Gene, Entity]
# 604  https://bbp.epfl.ch/neurosciencegraph/data/gen...  [Gene, Entity]
# 605  https://bbp.epfl.ch/neurosciencegraph/data/gen...  [Gene, Entity]
#
#         name subject.type                              subject.species.id  \
# 0      PLPP1      Subject   http://purl.obolibrary.org/obo/NCBITaxon_9606
# 1       Rom1      Subject  http://purl.obolibrary.org/obo/NCBITaxon_10090
# 2       Selp      Subject  http://purl.obolibrary.org/obo/NCBITaxon_10090
# 3      Ntrk1      Subject  http://purl.obolibrary.org/obo/NCBITaxon_10116
# 4       Aqp2      Subject  http://purl.obolibrary.org/obo/NCBITaxon_10116
# ..       ...          ...                                             ...
# 601    TRPC5      Subject   http://purl.obolibrary.org/obo/NCBITaxon_9606
# 602    TRPM6      Subject   http://purl.obolibrary.org/obo/NCBITaxon_9606
# 603    Trpc4      Subject  http://purl.obolibrary.org/obo/NCBITaxon_10090
# 604  CD200R1      Subject   http://purl.obolibrary.org/obo/NCBITaxon_9606
# 605    Trpc7      Subject  http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#                species          ensembl_id  \
# 0         Homo sapiens     ENSG00000067113
# 1         Mus musculus  ENSMUSG00000071648
# 2         Mus musculus  ENSMUSG00000026580
# 3    Rattus norvegicus  ENSRNOG00000013953
# 4    Rattus norvegicus  ENSRNOG00000054378
# ..                 ...                 ...
# 601       Homo sapiens     ENSG00000072315
# 602       Homo sapiens     ENSG00000119121
# 603       Mus musculus  ENSMUSG00000027748
# 604       Homo sapiens     ENSG00000163606
# 605       Mus musculus  ENSMUSG00000021541
#
#                                                  xrefs uniprot_ac  \
# 0    {'ArrayExpress': 'ENSG00000067113', 'EntrezGen...     D6REC3
# 1    {'ArrayExpress': 'ENSMUSG00000071648', 'Entrez...     P32958
# 2    {'ArrayExpress': 'ENSMUSG00000026580', 'Entrez...     Q01102
# 3    {'Reactome_gene': 'R-RNO-170984', 'RGD': '6201...     P35739
# 4    {'Reactome_gene': 'R-RNO-382551', 'Uniprot_gn'...       None
# ..                                                 ...        ...
# 601  {'ArrayExpress': 'ENSG00000072315', 'EntrezGen...     Q9UL62
# 602  {'ArrayExpress': 'ENSG00000119121', 'EntrezGen...     Q9BX84
# 603  {'ArrayExpress': 'ENSMUSG00000027748', 'Entrez...     Q0VB97
# 604  {'ArrayExpress': 'ENSG00000163606', 'EntrezGen...     H9KV32
# 605  {'ArrayExpress': 'ENSMUSG00000021541', 'Entrez...     G3UWT1
#
#                                            desctiption prefLabel  \
# 0    phospholipid phosphatase 1 [Source:HGNC Symbol...     PLPP1
# 1    rod outer segment membrane protein 1 [Source:M...      Rom1
# 2    selectin, platelet [Source:MGI Symbol;Acc:MGI:...      Selp
# 3    neurotrophic receptor tyrosine kinase 1 [Sourc...     Ntrk1
# 4             aquaporin 2 [Source:RGD Symbol;Acc:2142]      Aqp2
# ..                                                 ...       ...
# 601  transient receptor potential cation channel su...     TRPC5
# 602  transient receptor potential cation channel su...     TRPM6
# 603  transient receptor potential cation channel, s...     Trpc4
# 604  CD200 receptor 1 [Source:HGNC Symbol;Acc:HGNC:...   CD200R1
# 605  transient receptor potential cation channel, s...     Trpc7
#
#                                               go_edges    label
# 0    [(involved_in, GO:0016311), (involved_in, GO:0...    PLPP1
# 1    [(is_active_in, GO:0005887), (located_in, GO:0...     Rom1
# 2    [(involved_in, GO:0034097), (enables, GO:00336...     Selp
# 3    [(enables, GO:0005515), (enables, GO:0005515),...    Ntrk1
# 4                                                  NaN     Aqp2
# ..                                                 ...      ...
# 601  [(enables, GO:0015279), (is_active_in, GO:0005...    TRPC5
# 602  [(enables, GO:0004674), (enables, GO:0005262),...    TRPM6
# 603  [(enables, GO:0005216), (enables, GO:0005262),...    Trpc4
# 604  [(enables, GO:0038023), (involved_in, GO:01500...  CD200R1
# 605  [(involved_in, GO:0055085), (involved_in, GO:0...    Trpc7
#
# [606 rows x 13 columns]

# %%
new_gene_df = pd.DataFrame(records.values())
new_gene_df["label"] = new_gene_df["prefLabel"]
gene_df = gene_df.rename(columns={"subject.species.label": "species"})
gene_df = gene_df.merge(
    new_gene_df, on=["name", "species"])

# %%
gene_nodes = gene_df.drop(
    columns=[
        "type", "subject.type",
        "subject.species.id", "go_edges"
    ])
gene_nodes["@type"] = "GENE"
gene_nodes = gene_nodes.rename(
    columns={"id": "@id"}).set_index("@id")

# %% [markdown]
# ## Extract GO terms (only cellular compartment) and edges

# %%
go = rdflib.Graph()
go.parse("../../ontologies/external/go.ttl", format="turtle")
# Out:
# <Graph identifier=N873ef68fbe404681a6dddd9c984ac95c (<class 'rdflib.graph.Graph'>)>

# %%
go_terms_to_include = {}
for g, record in records.items():
    if "go_edges" in record:
        for _, t in record["go_edges"]:
            if t not in go_terms_to_include:
                for s in go.subjects(
                        rdflib.URIRef("http://www.geneontology.org/formats/oboInOwl#id"),
                        rdflib.Literal(t, datatype=rdflib.XSD.string)):
                    go_terms_to_include[t] = s
                    break

# %%
selected_go = rdflib.Graph()
for t in go_terms_to_include.values():
    subontology = subontology_from_term(go, t, top_down=False, closed=True)
    selected_go += subontology

# %% [markdown]
# ## Create a PG from selected GO terms + interactions + ontology classes

# %%
frame = PandasPGFrame.from_ontology(rdf_graph=selected_go, remove_prop_uris=True)
frame.remove_isolated_nodes()
frame.rename_node_properties({"id": "go_id"})

# %% [markdown]
# Select only 'cellular component'

# %%
frame = frame.subgraph(
    nodes=go_frame._nodes[
        go_frame._nodes["has_obo_namespace"] == "cellular_component"].index)

# %%
frame._nodes["@type"] = "GENE_ONTOLOGY_CLASS"

# %% [markdown]
# ### Add nodes

# %% [markdown]
# Add nodes corresponding to BMO concepts

# %%
frame.add_nodes([
    "Gene",
    "Protein",
    "ProteinProteinInteraction",
    "BiochemicalReaction"
])
frame._nodes.loc["Gene", "@type"] = "GENE"
frame._nodes.loc["Protein", "@type"] = "MOLECULE"
frame._nodes.loc["ProteinProteinInteraction", "@type"] = "BIOCHEMICAL_REACTION"
frame._nodes.loc["BiochemicalReaction", "@type"] = "BIOCHEMICAL_REACTION"

# %% [markdown]
# Add interaction / protein / gene nodes.

# %%
interaction_nodes = interactions_df[["id", "name"]]
interaction_nodes["@type"] = "BIOCHEMICAL_REACTION"
interaction_nodes = interaction_nodes.rename(
    columns={"id": "@id"}).set_index("@id")

protein_nodes = protein_df[[
    "id", "identifier", "name",
    "structureAvailable",
    "subject.species.id", "subject.species.label"]]
protein_nodes["@type"] = "MOLECULE"
protein_nodes = protein_nodes.rename(columns={
    "id": "@id",
    "subject.species.id": "subject_species_id",
    "subject.species.label": "subject_species_label"}).set_index("@id")
# Out:
# /Users/oshurko/opt/anaconda3/envs/bg/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/oshurko/opt/anaconda3/envs/bg/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
frame._nodes = pd.concat([
    frame._nodes,
    interaction_nodes,
    protein_nodes,
    gene_nodes])

# %%
for c in frame._nodes.columns:
    frame.node_prop_as_category(c)

# %% [markdown]
# ### Add edges

# %% [markdown]
# Add edges between BMO concepts

# %%
frame.add_edges([
    ("Protein", "Gene"),
    ("Protein", "ProteinProteinInteraction"),
    ("ProteinProteinInteraction", "BiochemicalReaction")
])
frame._edges.loc[("Protein", "Gene"), "@type"] = "encodedBy"
frame._edges.loc[("Protein", "ProteinProteinInteraction"), "@type"] = "participatesIn"
frame._edges.loc[("ProteinProteinInteraction", "BiochemicalReaction"), "@type"] = "IS_SUBCLASS_OF"

# %% [markdown]
# Add edges between proteins/genes and interactions

# %%
frame._edges = pd.concat(
    [frame._edges, encoded_edges, participation_edges])

for c in frame._edges.columns:
    if c not in ["cost", "errorRate", "motif"]:
        frame.edge_prop_as_category(c)
frame.edge_prop_as_text("motif")
frame.edge_prop_as_numeric("cost")
frame.edge_prop_as_numeric("errorRate")

# %% [markdown]
# Add edges to ontology concepts

# %%
interaction_instance_edges = pd.DataFrame(
    interaction_nodes.index).rename(columns={"@id": "@source_id"})
interaction_instance_edges["@target_id"] = "ProteinProteinInteraction"
interaction_instance_edges["@type"] = "IS_INSTANCE_OF"
interaction_instance_edges = interaction_instance_edges.set_index(["@source_id", "@target_id"])

# %%
protein_instance_edges = pd.DataFrame(
    protein_nodes.index).rename(columns={"@id": "@source_id"})
protein_instance_edges["@target_id"] = "Protein"
protein_instance_edges["@type"] = "IS_INSTANCE_OF"
protein_instance_edges = protein_instance_edges.set_index(["@source_id", "@target_id"])

# %%
gene_instance_edges = pd.DataFrame(
    gene_nodes.index).rename(columns={"@id": "@source_id"})
gene_instance_edges["@target_id"] = "Gene"
gene_instance_edges["@type"] = "IS_INSTANCE_OF"
gene_instance_edges = gene_instance_edges.set_index(["@source_id", "@target_id"])

# %%
instance_edges = pd.concat([
    interaction_instance_edges,
    protein_instance_edges,
    gene_instance_edges
])

# %%
frame._edges = pd.concat(
    [frame._edges, instance_edges])

# %% [markdown]
# Add edges from Genes to GO terms

# %%
go_edges = gene_df[["id", "go_edges"]]

# %%
# Select only edges of type 'located_in'
go_edges["go_edges"] = go_edges["go_edges"].apply(
    lambda x:
        [el for el in x if el[0] == "located_in"]
        if isinstance(x, list) else np.nan)
# Out:
# /Users/oshurko/opt/anaconda3/envs/bg/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
frame.add_edges(go_edges.keys())
for e, types in go_edges.items():
    frame._edges.loc[e, "@type"] = types

frame.rename_node_properties({
    p: p.replace(" ", "_") for p in frame.node_properties()
})

# %%
located_in_edges = defaultdict(set)
for row in go_edges.to_dict("records"):
    source  = row["id"]
    if isinstance(row["go_edges"], list):
        for rel, go_term in row["go_edges"]:
            try:
                target = frame._nodes[frame._nodes["go_id"] == go_term].index[0]
                located_in_edges[(source, target)].add(rel.replace(" ", "_"))
            except IndexError:
                pass

# %%
frame.add_edges(located_in_edges.keys())
for e, types in located_in_edges.items():
    frame._edges.loc[e, "@type"] = types

frame.rename_node_properties({
    p: p.replace(" ", "_") for p in frame.node_properties()
})

# %%
gene_compartment_data = pd.DataFrame(
    [(s, t) for s, t in located_in_edges.keys()],
    columns=["geneId", "cellularComponent.label"])

# %%
compartment_data = frame._nodes.loc[
    gene_compartment_data["cellularComponent.label"].unique()].dropna(
    axis=1).drop(columns=["@type", "label"]).reset_index().rename(columns={"@id": "cellularComponent.label"})

# %%
gene_compartment_data["cellularComponent.id"] = gene_compartment_data["go_id"].apply(
    lambda x: "http://purl.obolibrary.org/obo/GO_" + x.split(":")[1])

# %%
gene_compartment_data = gene_compartment_data.rename(columns={
    "go_id": "cellularComponent.goId",
    "definition":  "cellularComponent.definition",
    "has_obo_namespace":  "cellularComponent.hasOboNamespace",
})

# %%
gene_compartment_data.to_csv("../data/gene_compartments.csv", index=None)

# %%
gene_nodes.reset_index().drop(columns=["@type"]).to_csv(
    "../data/gene_ensembl_meta_data.csv", index=None)

# %%
gene_nodes
# Out:
#                                                        name  \
# @id
# https://bbp.epfl.ch/neurosciencegraph/data/gene...     MYMK
# https://bbp.epfl.ch/neurosciencegraph/data/gene...    Htr1f
# https://bbp.epfl.ch/neurosciencegraph/data/gene...    HTR1F
# https://bbp.epfl.ch/neurosciencegraph/data/gene...      MIP
# https://bbp.epfl.ch/neurosciencegraph/data/gene...    ASIC1
# ...                                                     ...
# https://bbp.epfl.ch/neurosciencegraph/data/gene...    TRPC5
# https://bbp.epfl.ch/neurosciencegraph/data/gene...    TRPM6
# https://bbp.epfl.ch/neurosciencegraph/data/gene...    Trpc4
# https://bbp.epfl.ch/neurosciencegraph/data/gene...  CD200R1
# https://bbp.epfl.ch/neurosciencegraph/data/gene...    Trpc7
#
#                                                               species  \
# @id
# https://bbp.epfl.ch/neurosciencegraph/data/gene...       Homo sapiens
# https://bbp.epfl.ch/neurosciencegraph/data/gene...  Rattus norvegicus
# https://bbp.epfl.ch/neurosciencegraph/data/gene...       Homo sapiens
# https://bbp.epfl.ch/neurosciencegraph/data/gene...       Homo sapiens
# https://bbp.epfl.ch/neurosciencegraph/data/gene...       Homo sapiens
# ...                                                               ...
# https://bbp.epfl.ch/neurosciencegraph/data/gene...       Homo sapiens
# https://bbp.epfl.ch/neurosciencegraph/data/gene...       Homo sapiens
# https://bbp.epfl.ch/neurosciencegraph/data/gene...       Mus musculus
# https://bbp.epfl.ch/neurosciencegraph/data/gene...       Homo sapiens
# https://bbp.epfl.ch/neurosciencegraph/data/gene...       Mus musculus
#
#                                                             ensembl_id  \
# @id
# https://bbp.epfl.ch/neurosciencegraph/data/gene...     ENSG00000187616
# https://bbp.epfl.ch/neurosciencegraph/data/gene...  ENSRNOG00000000716
# https://bbp.epfl.ch/neurosciencegraph/data/gene...     ENSG00000179097
# https://bbp.epfl.ch/neurosciencegraph/data/gene...     ENSG00000135517
# https://bbp.epfl.ch/neurosciencegraph/data/gene...     ENSG00000110881
# ...                                                                ...
# https://bbp.epfl.ch/neurosciencegraph/data/gene...     ENSG00000072315
# https://bbp.epfl.ch/neurosciencegraph/data/gene...     ENSG00000119121
# https://bbp.epfl.ch/neurosciencegraph/data/gene...  ENSMUSG00000027748
# https://bbp.epfl.ch/neurosciencegraph/data/gene...     ENSG00000163606
# https://bbp.epfl.ch/neurosciencegraph/data/gene...  ENSMUSG00000021541
#
#                                                                                                 xrefs  \
# @id
# https://bbp.epfl.ch/neurosciencegraph/data/gene...  {'ArrayExpress': 'ENSG00000187616', 'EntrezGen...
# https://bbp.epfl.ch/neurosciencegraph/data/gene...  {'Uniprot_gn': 'G3V626', 'RGD': '71083', 'Reac...
# https://bbp.epfl.ch/neurosciencegraph/data/gene...  {'ArrayExpress': 'ENSG00000179097', 'EntrezGen...
# https://bbp.epfl.ch/neurosciencegraph/data/gene...  {'ArrayExpress': 'ENSG00000135517', 'EntrezGen...
# https://bbp.epfl.ch/neurosciencegraph/data/gene...  {'ArrayExpress': 'ENSG00000110881', 'EntrezGen...
# ...                                                                                               ...
# https://bbp.epfl.ch/neurosciencegraph/data/gene...  {'ArrayExpress': 'ENSG00000072315', 'EntrezGen...
# https://bbp.epfl.ch/neurosciencegraph/data/gene...  {'ArrayExpress': 'ENSG00000119121', 'EntrezGen...
# https://bbp.epfl.ch/neurosciencegraph/data/gene...  {'ArrayExpress': 'ENSMUSG00000027748', 'Entrez...
# https://bbp.epfl.ch/neurosciencegraph/data/gene...  {'ArrayExpress': 'ENSG00000163606', 'EntrezGen...
# https://bbp.epfl.ch/neurosciencegraph/data/gene...  {'ArrayExpress': 'ENSMUSG00000021541', 'Entrez...
#
#                                                    uniprot_ac  \
# @id
# https://bbp.epfl.ch/neurosciencegraph/data/gene...     A6NI61
# https://bbp.epfl.ch/neurosciencegraph/data/gene...     G3V626
# https://bbp.epfl.ch/neurosciencegraph/data/gene...     P30939
# https://bbp.epfl.ch/neurosciencegraph/data/gene...     P30301
# https://bbp.epfl.ch/neurosciencegraph/data/gene...     F8VSK4
# ...                                                       ...
# https://bbp.epfl.ch/neurosciencegraph/data/gene...     Q9UL62
# https://bbp.epfl.ch/neurosciencegraph/data/gene...     Q9BX84
# https://bbp.epfl.ch/neurosciencegraph/data/gene...     Q0VB97
# https://bbp.epfl.ch/neurosciencegraph/data/gene...     H9KV32
# https://bbp.epfl.ch/neurosciencegraph/data/gene...     G3UWT1
#
#                                                                                           desctiption  \
# @id
# https://bbp.epfl.ch/neurosciencegraph/data/gene...  myomaker, myoblast fusion factor [Source:HGNC ...
# https://bbp.epfl.ch/neurosciencegraph/data/gene...  5-hydroxytryptamine receptor 1F [Source:RGD Sy...
# https://bbp.epfl.ch/neurosciencegraph/data/gene...  5-hydroxytryptamine receptor 1F [Source:HGNC S...
# https://bbp.epfl.ch/neurosciencegraph/data/gene...  major intrinsic protein of lens fiber [Source:...
# https://bbp.epfl.ch/neurosciencegraph/data/gene...  acid sensing ion channel subunit 1 [Source:HGN...
# ...                                                                                               ...
# https://bbp.epfl.ch/neurosciencegraph/data/gene...  transient receptor potential cation channel su...
# https://bbp.epfl.ch/neurosciencegraph/data/gene...  transient receptor potential cation channel su...
# https://bbp.epfl.ch/neurosciencegraph/data/gene...  transient receptor potential cation channel, s...
# https://bbp.epfl.ch/neurosciencegraph/data/gene...  CD200 receptor 1 [Source:HGNC Symbol;Acc:HGNC:...
# https://bbp.epfl.ch/neurosciencegraph/data/gene...  transient receptor potential cation channel, s...
#
#                                                    prefLabel    label @type
# @id
# https://bbp.epfl.ch/neurosciencegraph/data/gene...      MYMK     MYMK  GENE
# https://bbp.epfl.ch/neurosciencegraph/data/gene...     Htr1f    Htr1f  GENE
# https://bbp.epfl.ch/neurosciencegraph/data/gene...     HTR1F    HTR1F  GENE
# https://bbp.epfl.ch/neurosciencegraph/data/gene...       MIP      MIP  GENE
# https://bbp.epfl.ch/neurosciencegraph/data/gene...     ASIC1    ASIC1  GENE
# ...                                                      ...      ...   ...
# https://bbp.epfl.ch/neurosciencegraph/data/gene...     TRPC5    TRPC5  GENE
# https://bbp.epfl.ch/neurosciencegraph/data/gene...     TRPM6    TRPM6  GENE
# https://bbp.epfl.ch/neurosciencegraph/data/gene...     Trpc4    Trpc4  GENE
# https://bbp.epfl.ch/neurosciencegraph/data/gene...   CD200R1  CD200R1  GENE
# https://bbp.epfl.ch/neurosciencegraph/data/gene...     Trpc7    Trpc7  GENE
#
# [606 rows x 9 columns]

# %% [markdown]
# ## Export created PG to Neo4j

# %%
for c in frame._nodes.columns:
    frame._nodes.loc[frame._nodes[c].apply(lambda x: x is None), c] = np.nan

# %%
pgframe_to_neo4j(
    frame,
    uri="bolt://localhost:7687",
    username="neo4j",
    password="admin",
    node_types_as_labels=True,
    edge_types_as_labels=True,
    batch_size=10)

# %%
pd.DataFrame(located_in_edges.items())
# Out:
#                                                       0             1
# 0     (https://bbp.epfl.ch/neurosciencegraph/data/ge...  {located_in}
# 1     (https://bbp.epfl.ch/neurosciencegraph/data/ge...  {located_in}
# 2     (https://bbp.epfl.ch/neurosciencegraph/data/ge...  {located_in}
# 3     (https://bbp.epfl.ch/neurosciencegraph/data/ge...  {located_in}
# 4     (https://bbp.epfl.ch/neurosciencegraph/data/ge...  {located_in}
# ...                                                 ...           ...
# 1702  (https://bbp.epfl.ch/neurosciencegraph/data/ge...  {located_in}
# 1703  (https://bbp.epfl.ch/neurosciencegraph/data/ge...  {located_in}
# 1704  (https://bbp.epfl.ch/neurosciencegraph/data/ge...  {located_in}
# 1705  (https://bbp.epfl.ch/neurosciencegraph/data/ge...  {located_in}
# 1706  (https://bbp.epfl.ch/neurosciencegraph/data/ge...  {located_in}
#
# [1707 rows x 2 columns]

# %%
compartment_data = gene_nodes.reset_index().merge(
    com,
    on="@id")
# Out:
#                                                     @id  \
# 0     https://bbp.epfl.ch/neurosciencegraph/data/gen...
# 1     https://bbp.epfl.ch/neurosciencegraph/data/gen...
# 2     https://bbp.epfl.ch/neurosciencegraph/data/gen...
# 3     https://bbp.epfl.ch/neurosciencegraph/data/gen...
# 4     https://bbp.epfl.ch/neurosciencegraph/data/gen...
# ...                                                 ...
# 1702  https://bbp.epfl.ch/neurosciencegraph/data/gen...
# 1703  https://bbp.epfl.ch/neurosciencegraph/data/gen...
# 1704  https://bbp.epfl.ch/neurosciencegraph/data/gen...
# 1705  https://bbp.epfl.ch/neurosciencegraph/data/gen...
# 1706  https://bbp.epfl.ch/neurosciencegraph/data/gen...
#
#                    cellularComponent.label   name       species  \
# 0           integral component of membrane   MYMK  Homo sapiens
# 1                                 membrane   MYMK  Homo sapiens
# 2                          plasma membrane   MYMK  Homo sapiens
# 3                          Golgi apparatus   MYMK  Homo sapiens
# 4     integral component of Golgi membrane   MYMK  Homo sapiens
# ...                                    ...    ...           ...
# 1702                          cell surface  Trpc4  Mus musculus
# 1703                       plasma membrane  Trpc4  Mus musculus
# 1704                    cell-cell junction  Trpc4  Mus musculus
# 1705                              membrane  Trpc7  Mus musculus
# 1706        integral component of membrane  Trpc7  Mus musculus
#
#               ensembl_id                                              xrefs  \
# 0        ENSG00000187616  {'ArrayExpress': 'ENSG00000187616', 'EntrezGen...
# 1        ENSG00000187616  {'ArrayExpress': 'ENSG00000187616', 'EntrezGen...
# 2        ENSG00000187616  {'ArrayExpress': 'ENSG00000187616', 'EntrezGen...
# 3        ENSG00000187616  {'ArrayExpress': 'ENSG00000187616', 'EntrezGen...
# 4        ENSG00000187616  {'ArrayExpress': 'ENSG00000187616', 'EntrezGen...
# ...                  ...                                                ...
# 1702  ENSMUSG00000027748  {'ArrayExpress': 'ENSMUSG00000027748', 'Entrez...
# 1703  ENSMUSG00000027748  {'ArrayExpress': 'ENSMUSG00000027748', 'Entrez...
# 1704  ENSMUSG00000027748  {'ArrayExpress': 'ENSMUSG00000027748', 'Entrez...
# 1705  ENSMUSG00000021541  {'ArrayExpress': 'ENSMUSG00000021541', 'Entrez...
# 1706  ENSMUSG00000021541  {'ArrayExpress': 'ENSMUSG00000021541', 'Entrez...
#
#      uniprot_ac                                        desctiption prefLabel  \
# 0        A6NI61  myomaker, myoblast fusion factor [Source:HGNC ...      MYMK
# 1        A6NI61  myomaker, myoblast fusion factor [Source:HGNC ...      MYMK
# 2        A6NI61  myomaker, myoblast fusion factor [Source:HGNC ...      MYMK
# 3        A6NI61  myomaker, myoblast fusion factor [Source:HGNC ...      MYMK
# 4        A6NI61  myomaker, myoblast fusion factor [Source:HGNC ...      MYMK
# ...         ...                                                ...       ...
# 1702     Q0VB97  transient receptor potential cation channel, s...     Trpc4
# 1703     Q0VB97  transient receptor potential cation channel, s...     Trpc4
# 1704     Q0VB97  transient receptor potential cation channel, s...     Trpc4
# 1705     G3UWT1  transient receptor potential cation channel, s...     Trpc7
# 1706     G3UWT1  transient receptor potential cation channel, s...     Trpc7
#
#       label @type
# 0      MYMK  GENE
# 1      MYMK  GENE
# 2      MYMK  GENE
# 3      MYMK  GENE
# 4      MYMK  GENE
# ...     ...   ...
# 1702  Trpc4  GENE
# 1703  Trpc4  GENE
# 1704  Trpc4  GENE
# 1705  Trpc7  GENE
# 1706  Trpc7  GENE
#
# [1707 rows x 11 columns]

# %% [markdown]
# ## Extract interactions from IntAct

# %%
import requests

# %%
URL = "https://www.ebi.ac.uk/intact/ws/interaction"

# %%
INTACT_FIELDS = [
    "uniqueIdA",
    "uniqueIdB",
    "speciesA",
    "speciesB",
    "featuresA",
    "featuresB",
    "confidenceValues",
    "type",
    "negative",
    "allAnnotations",
]

# %%
print("Unique genes: ", len(gene_df["name"].unique()))
# Out:
# Unique genes:  516

# %%
def search_intact_interactions(query, species=None):
    
    def _fetch_page(page=0):
        request_url = f"{URL}/findInteractionWithFacet"
        params={
            "query": query,
            "page": page
        }
        if species is not None:
            params["interactorSpeciesFilter"] = species
        r = requests.post(request_url, params=params)
        data = r.json()
        return data["data"]
    
    data = _fetch_page()
    n_pages = data["totalPages"]
    print(f"Fetching {n_pages} pages for '{query}' (species '{species}')...")
    if n_pages > 150:
        print("Skipping...")
        return {}
        
    interactions = {}
    for el in data["content"]:
        interactions[el["ac"]] = el
    
    for i in range(1, n_pages):
        page_data =  _fetch_page(i)["content"]
        for el in page_data:
            interactions[el["ac"]] = el

    return interactions

# %%
SKIP = ["App", "FER", "APP", "Tl", "Alk", "5"]

# %%
intact_interactions = {}
all_species = ["Homo sapiens", "Mus musculus", "Rattus norvegicus"]
for gene_name in gene_df["name"].unique():
    if gene_name not in SKIP:
        for species in all_species:
            intact_interactions.update(search_intact_interactions(gene_name, species))
# Out:
# Fetching 4 pages for 'PLPP1' (species 'Homo sapiens')...
# Fetching 1 pages for 'PLPP1' (species 'Mus musculus')...
# Fetching 0 pages for 'PLPP1' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'Rom1' (species 'Homo sapiens')...
# Fetching 0 pages for 'Rom1' (species 'Mus musculus')...
# Fetching 0 pages for 'Rom1' (species 'Rattus norvegicus')...
# Fetching 5 pages for 'Selp' (species 'Homo sapiens')...
# Fetching 1 pages for 'Selp' (species 'Mus musculus')...
# Fetching 0 pages for 'Selp' (species 'Rattus norvegicus')...
# Fetching 7 pages for 'Ntrk1' (species 'Homo sapiens')...
# Fetching 2 pages for 'Ntrk1' (species 'Mus musculus')...
# Fetching 0 pages for 'Ntrk1' (species 'Rattus norvegicus')...
# Fetching 103 pages for 'Aqp2' (species 'Homo sapiens')...
# Fetching 1 pages for 'Aqp2' (species 'Mus musculus')...
# Fetching 0 pages for 'Aqp2' (species 'Rattus norvegicus')...
# Fetching 9 pages for 'Chrm4' (species 'Homo sapiens')...
# Fetching 1 pages for 'Chrm4' (species 'Mus musculus')...
# Fetching 0 pages for 'Chrm4' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Mc5r' (species 'Homo sapiens')...
# Fetching 0 pages for 'Mc5r' (species 'Mus musculus')...
# Fetching 0 pages for 'Mc5r' (species 'Rattus norvegicus')...
# Fetching 3 pages for 'ADRA1B' (species 'Homo sapiens')...
# Fetching 1 pages for 'ADRA1B' (species 'Mus musculus')...
# Fetching 0 pages for 'ADRA1B' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'Olr1571' (species 'Homo sapiens')...
# Fetching 0 pages for 'Olr1571' (species 'Mus musculus')...
# Fetching 0 pages for 'Olr1571' (species 'Rattus norvegicus')...
# Fetching 17 pages for 'SRC2' (species 'Homo sapiens')...
# Fetching 3 pages for 'SRC2' (species 'Mus musculus')...
# Fetching 0 pages for 'SRC2' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'SLC1A4' (species 'Homo sapiens')...
# Fetching 1 pages for 'SLC1A4' (species 'Mus musculus')...
# Fetching 0 pages for 'SLC1A4' (species 'Rattus norvegicus')...
# Fetching 107 pages for 'Ldlr' (species 'Homo sapiens')...
# Fetching 8 pages for 'Ldlr' (species 'Mus musculus')...
# Fetching 0 pages for 'Ldlr' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'OPT2' (species 'Homo sapiens')...
# Fetching 0 pages for 'OPT2' (species 'Mus musculus')...
# Fetching 0 pages for 'OPT2' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Tnfrsf4' (species 'Homo sapiens')...
# Fetching 6 pages for 'Tnfrsf4' (species 'Mus musculus')...
# Fetching 0 pages for 'Tnfrsf4' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'Htr1f' (species 'Homo sapiens')...
# Fetching 0 pages for 'Htr1f' (species 'Mus musculus')...
# Fetching 0 pages for 'Htr1f' (species 'Rattus norvegicus')...
# Fetching 103 pages for 'AQP2' (species 'Homo sapiens')...
# Fetching 1 pages for 'AQP2' (species 'Mus musculus')...
# Fetching 0 pages for 'AQP2' (species 'Rattus norvegicus')...
# Fetching 3 pages for 'Chrm2' (species 'Homo sapiens')...
# Fetching 1 pages for 'Chrm2' (species 'Mus musculus')...
# Fetching 0 pages for 'Chrm2' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'GCGR' (species 'Homo sapiens')...
# Fetching 1 pages for 'GCGR' (species 'Mus musculus')...
# Fetching 0 pages for 'GCGR' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'STP7' (species 'Homo sapiens')...
# Fetching 0 pages for 'STP7' (species 'Mus musculus')...
# Fetching 0 pages for 'STP7' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'TACR2' (species 'Homo sapiens')...
# Fetching 0 pages for 'TACR2' (species 'Mus musculus')...
# Fetching 0 pages for 'TACR2' (species 'Rattus norvegicus')...
# Fetching 3 pages for 'Slc1a2' (species 'Homo sapiens')...
# Fetching 1 pages for 'Slc1a2' (species 'Mus musculus')...
# Fetching 0 pages for 'Slc1a2' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'Clcn5' (species 'Homo sapiens')...
# Fetching 1 pages for 'Clcn5' (species 'Mus musculus')...
# Fetching 0 pages for 'Clcn5' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'Clcn3' (species 'Homo sapiens')...
# Fetching 0 pages for 'Clcn3' (species 'Mus musculus')...
# Fetching 0 pages for 'Clcn3' (species 'Rattus norvegicus')...
# Fetching 35 pages for 'COMT' (species 'Homo sapiens')...
# Fetching 0 pages for 'COMT' (species 'Mus musculus')...
# Fetching 0 pages for 'COMT' (species 'Rattus norvegicus')...
# Fetching 3 pages for 'AQP5' (species 'Homo sapiens')...
# Fetching 1 pages for 'AQP5' (species 'Mus musculus')...
# Fetching 0 pages for 'AQP5' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'ADCY7' (species 'Homo sapiens')...
# Fetching 0 pages for 'ADCY7' (species 'Mus musculus')...
# Fetching 0 pages for 'ADCY7' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Slc5a2' (species 'Homo sapiens')...
# Fetching 1 pages for 'Slc5a2' (species 'Mus musculus')...
# Fetching 0 pages for 'Slc5a2' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Gcgr' (species 'Homo sapiens')...
# Fetching 1 pages for 'Gcgr' (species 'Mus musculus')...
# Fetching 0 pages for 'Gcgr' (species 'Rattus norvegicus')...
# Fetching 13 pages for 'Epha2' (species 'Homo sapiens')...
# Fetching 1 pages for 'Epha2' (species 'Mus musculus')...
# Fetching 0 pages for 'Epha2' (species 'Rattus norvegicus')...
# Fetching 10 pages for 'Coq8b' (species 'Homo sapiens')...
# Fetching 1 pages for 'Coq8b' (species 'Mus musculus')...
# Fetching 0 pages for 'Coq8b' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'Abcg1' (species 'Homo sapiens')...
# Fetching 1 pages for 'Abcg1' (species 'Mus musculus')...
# Fetching 0 pages for 'Abcg1' (species 'Rattus norvegicus')...
# Fetching 3 pages for 'AQP4' (species 'Homo sapiens')...
# Fetching 1 pages for 'AQP4' (species 'Mus musculus')...
# Fetching 0 pages for 'AQP4' (species 'Rattus norvegicus')...
# Fetching 3 pages for 'CHRM2' (species 'Homo sapiens')...
# Fetching 1 pages for 'CHRM2' (species 'Mus musculus')...
# Fetching 0 pages for 'CHRM2' (species 'Rattus norvegicus')...
# Fetching 3 pages for 'SLC1A2' (species 'Homo sapiens')...
# Fetching 1 pages for 'SLC1A2' (species 'Mus musculus')...
# Fetching 0 pages for 'SLC1A2' (species 'Rattus norvegicus')...
# Fetching 10 pages for 'Sdc3' (species 'Homo sapiens')...
# Fetching 1 pages for 'Sdc3' (species 'Mus musculus')...
# Fetching 0 pages for 'Sdc3' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'CLCN3' (species 'Homo sapiens')...
# Fetching 0 pages for 'CLCN3' (species 'Mus musculus')...
# Fetching 0 pages for 'CLCN3' (species 'Rattus norvegicus')...
# Fetching 3 pages for 'Adcy6' (species 'Homo sapiens')...
# Fetching 1 pages for 'Adcy6' (species 'Mus musculus')...
# Fetching 0 pages for 'Adcy6' (species 'Rattus norvegicus')...
# Fetching 9 pages for 'Trpc1' (species 'Homo sapiens')...
# Fetching 2 pages for 'Trpc1' (species 'Mus musculus')...
# Fetching 0 pages for 'Trpc1' (species 'Rattus norvegicus')...
# Fetching 3 pages for 'CCKBR' (species 'Homo sapiens')...
# Fetching 1 pages for 'CCKBR' (species 'Mus musculus')...
# Fetching 0 pages for 'CCKBR' (species 'Rattus norvegicus')...
# Fetching 3 pages for 'Aqp5' (species 'Homo sapiens')...
# Fetching 1 pages for 'Aqp5' (species 'Mus musculus')...
# Fetching 0 pages for 'Aqp5' (species 'Rattus norvegicus')...
# Fetching 166 pages for 'Mip' (species 'Homo sapiens')...
# Skipping...
# Fetching 8 pages for 'Mip' (species 'Mus musculus')...
# Fetching 0 pages for 'Mip' (species 'Rattus norvegicus')...
# Fetching 3 pages for 'Aqp4' (species 'Homo sapiens')...
# Fetching 1 pages for 'Aqp4' (species 'Mus musculus')...
# Fetching 0 pages for 'Aqp4' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'MC5R' (species 'Homo sapiens')...
# Fetching 0 pages for 'MC5R' (species 'Mus musculus')...
# Fetching 0 pages for 'MC5R' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'Asic3' (species 'Homo sapiens')...
# Fetching 1 pages for 'Asic3' (species 'Mus musculus')...
# Fetching 0 pages for 'Asic3' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'RBOHF' (species 'Homo sapiens')...
# Fetching 0 pages for 'RBOHF' (species 'Mus musculus')...
# Fetching 0 pages for 'RBOHF' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'Slc5a10' (species 'Homo sapiens')...
# Fetching 0 pages for 'Slc5a10' (species 'Mus musculus')...
# Fetching 0 pages for 'Slc5a10' (species 'Rattus norvegicus')...
# Fetching 7 pages for 'Slc39a4' (species 'Homo sapiens')...
# Fetching 0 pages for 'Slc39a4' (species 'Mus musculus')...
# Fetching 0 pages for 'Slc39a4' (species 'Rattus norvegicus')...
# Fetching 3 pages for 'SLC43A2' (species 'Homo sapiens')...
# Fetching 0 pages for 'SLC43A2' (species 'Mus musculus')...
# Fetching 0 pages for 'SLC43A2' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'UNC5A' (species 'Homo sapiens')...
# Fetching 1 pages for 'UNC5A' (species 'Mus musculus')...
# Fetching 0 pages for 'UNC5A' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'MUC3B' (species 'Homo sapiens')...
# Fetching 0 pages for 'MUC3B' (species 'Mus musculus')...
# Fetching 0 pages for 'MUC3B' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'GPR135' (species 'Homo sapiens')...
# Fetching 0 pages for 'GPR135' (species 'Mus musculus')...
# Fetching 0 pages for 'GPR135' (species 'Rattus norvegicus')...
# Fetching 3 pages for 'CD300A' (species 'Homo sapiens')...
# Fetching 0 pages for 'CD300A' (species 'Mus musculus')...
# Fetching 0 pages for 'CD300A' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'HCST' (species 'Homo sapiens')...
# Fetching 1 pages for 'HCST' (species 'Mus musculus')...
# Fetching 0 pages for 'HCST' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'OR6S1' (species 'Homo sapiens')...
# Fetching 0 pages for 'OR6S1' (species 'Mus musculus')...
# Fetching 0 pages for 'OR6S1' (species 'Rattus norvegicus')...
# Fetching 3 pages for 'TSPAN18' (species 'Homo sapiens')...
# Fetching 0 pages for 'TSPAN18' (species 'Mus musculus')...
# Fetching 0 pages for 'TSPAN18' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'OR1S2' (species 'Homo sapiens')...
# Fetching 0 pages for 'OR1S2' (species 'Mus musculus')...
# Fetching 0 pages for 'OR1S2' (species 'Rattus norvegicus')...
# Fetching 4 pages for 'P2RY11' (species 'Homo sapiens')...
# Fetching 0 pages for 'P2RY11' (species 'Mus musculus')...
# Fetching 0 pages for 'P2RY11' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'FCRL6' (species 'Homo sapiens')...
# Fetching 0 pages for 'FCRL6' (species 'Mus musculus')...
# Fetching 0 pages for 'FCRL6' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'GNRHR2' (species 'Homo sapiens')...
# Fetching 0 pages for 'GNRHR2' (species 'Mus musculus')...
# Fetching 0 pages for 'GNRHR2' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'OR4S1' (species 'Homo sapiens')...
# Fetching 0 pages for 'OR4S1' (species 'Mus musculus')...
# Fetching 0 pages for 'OR4S1' (species 'Rattus norvegicus')...
# Fetching 10 pages for 'COQ8B' (species 'Homo sapiens')...
# Fetching 1 pages for 'COQ8B' (species 'Mus musculus')...
# Fetching 0 pages for 'COQ8B' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'SLC52A3' (species 'Homo sapiens')...
# Fetching 1 pages for 'SLC52A3' (species 'Mus musculus')...
# Fetching 0 pages for 'SLC52A3' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'ESAM' (species 'Homo sapiens')...
# Fetching 0 pages for 'ESAM' (species 'Mus musculus')...
# Fetching 0 pages for 'ESAM' (species 'Rattus norvegicus')...
# Fetching 5 pages for 'SELP' (species 'Homo sapiens')...
# Fetching 1 pages for 'SELP' (species 'Mus musculus')...
# Fetching 0 pages for 'SELP' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'SERINC5' (species 'Homo sapiens')...
# Fetching 0 pages for 'SERINC5' (species 'Mus musculus')...
# Fetching 0 pages for 'SERINC5' (species 'Rattus norvegicus')...
# Fetching 7 pages for 'LAPTM5' (species 'Homo sapiens')...
# Fetching 1 pages for 'LAPTM5' (species 'Mus musculus')...
# Fetching 0 pages for 'LAPTM5' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'MARVELD1' (species 'Homo sapiens')...
# Fetching 0 pages for 'MARVELD1' (species 'Mus musculus')...
# Fetching 0 pages for 'MARVELD1' (species 'Rattus norvegicus')...
# Fetching 19 pages for 'mfsd5' (species 'Homo sapiens')...
# Fetching 0 pages for 'mfsd5' (species 'Mus musculus')...
# Fetching 0 pages for 'mfsd5' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Cacna1h' (species 'Homo sapiens')...
# Fetching 1 pages for 'Cacna1h' (species 'Mus musculus')...
# Fetching 0 pages for 'Cacna1h' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'FCRL5' (species 'Homo sapiens')...
# Fetching 1 pages for 'FCRL5' (species 'Mus musculus')...
# Fetching 0 pages for 'FCRL5' (species 'Rattus norvegicus')...
# Fetching 7 pages for 'CACNA1C' (species 'Homo sapiens')...
# Fetching 10 pages for 'CACNA1C' (species 'Mus musculus')...
# Fetching 0 pages for 'CACNA1C' (species 'Rattus norvegicus')...
# Fetching 8 pages for 'STAB1' (species 'Homo sapiens')...
# Fetching 0 pages for 'STAB1' (species 'Mus musculus')...
# Fetching 0 pages for 'STAB1' (species 'Rattus norvegicus')...
# Fetching 5 pages for 'Cd47' (species 'Homo sapiens')...
# Fetching 1 pages for 'Cd47' (species 'Mus musculus')...
# Fetching 0 pages for 'Cd47' (species 'Rattus norvegicus')...
# Fetching 4 pages for 'CELSR3' (species 'Homo sapiens')...
# Fetching 1 pages for 'CELSR3' (species 'Mus musculus')...
# Fetching 0 pages for 'CELSR3' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'CACNA1H' (species 'Homo sapiens')...
# Fetching 1 pages for 'CACNA1H' (species 'Mus musculus')...
# Fetching 0 pages for 'CACNA1H' (species 'Rattus norvegicus')...
# Fetching 3 pages for 'MGAM' (species 'Homo sapiens')...
# Fetching 0 pages for 'MGAM' (species 'Mus musculus')...
# Fetching 0 pages for 'MGAM' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'ABCC5' (species 'Homo sapiens')...
# Fetching 1 pages for 'ABCC5' (species 'Mus musculus')...
# Fetching 0 pages for 'ABCC5' (species 'Rattus norvegicus')...
# Fetching 455 pages for 'heg' (species 'Homo sapiens')...
# Skipping...
# Fetching 225 pages for 'heg' (species 'Mus musculus')...
# Skipping...
# Fetching 0 pages for 'heg' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Chrm1' (species 'Homo sapiens')...
# Fetching 0 pages for 'Chrm1' (species 'Mus musculus')...
# Fetching 0 pages for 'Chrm1' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'Fpr-rs4' (species 'Homo sapiens')...
# Fetching 0 pages for 'Fpr-rs4' (species 'Mus musculus')...
# Fetching 0 pages for 'Fpr-rs4' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'GALR2' (species 'Homo sapiens')...
# Fetching 0 pages for 'GALR2' (species 'Mus musculus')...
# Fetching 0 pages for 'GALR2' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Sstr4' (species 'Homo sapiens')...
# Fetching 1 pages for 'Sstr4' (species 'Mus musculus')...
# Fetching 0 pages for 'Sstr4' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'OR4C46' (species 'Homo sapiens')...
# Fetching 0 pages for 'OR4C46' (species 'Mus musculus')...
# Fetching 0 pages for 'OR4C46' (species 'Rattus norvegicus')...
# Fetching 12 pages for 'Slc16a2' (species 'Homo sapiens')...
# Fetching 0 pages for 'Slc16a2' (species 'Mus musculus')...
# Fetching 0 pages for 'Slc16a2' (species 'Rattus norvegicus')...
# Fetching 10 pages for 'Ackr3' (species 'Homo sapiens')...
# Fetching 1 pages for 'Ackr3' (species 'Mus musculus')...
# Fetching 0 pages for 'Ackr3' (species 'Rattus norvegicus')...
# Fetching 20 pages for 'BAK1' (species 'Homo sapiens')...
# Fetching 4 pages for 'BAK1' (species 'Mus musculus')...
# Fetching 0 pages for 'BAK1' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Slc26a3' (species 'Homo sapiens')...
# Fetching 1 pages for 'Slc26a3' (species 'Mus musculus')...
# Fetching 0 pages for 'Slc26a3' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'GPR182' (species 'Homo sapiens')...
# Fetching 0 pages for 'GPR182' (species 'Mus musculus')...
# Fetching 0 pages for 'GPR182' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'Ldlrad3' (species 'Homo sapiens')...
# Fetching 0 pages for 'Ldlrad3' (species 'Mus musculus')...
# Fetching 0 pages for 'Ldlrad3' (species 'Rattus norvegicus')...
# Fetching 3 pages for 'Ackr2' (species 'Homo sapiens')...
# Fetching 0 pages for 'Ackr2' (species 'Mus musculus')...
# Fetching 0 pages for 'Ackr2' (species 'Rattus norvegicus')...
# Fetching 5 pages for 'NPC1' (species 'Homo sapiens')...
# Fetching 1 pages for 'NPC1' (species 'Mus musculus')...
# Fetching 0 pages for 'NPC1' (species 'Rattus norvegicus')...
# Fetching 5 pages for 'Chrm5' (species 'Homo sapiens')...
# Fetching 1 pages for 'Chrm5' (species 'Mus musculus')...
# Fetching 0 pages for 'Chrm5' (species 'Rattus norvegicus')...
# Fetching 12 pages for 'SLC16A2' (species 'Homo sapiens')...
# Fetching 0 pages for 'SLC16A2' (species 'Mus musculus')...
# Fetching 0 pages for 'SLC16A2' (species 'Rattus norvegicus')...
# Fetching 8 pages for 'Itpr3' (species 'Homo sapiens')...
# Fetching 2 pages for 'Itpr3' (species 'Mus musculus')...
# Fetching 0 pages for 'Itpr3' (species 'Rattus norvegicus')...
# Fetching 9 pages for 'Bace2' (species 'Homo sapiens')...
# Fetching 1 pages for 'Bace2' (species 'Mus musculus')...
# Fetching 0 pages for 'Bace2' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'SLC26A9' (species 'Homo sapiens')...
# Fetching 1 pages for 'SLC26A9' (species 'Mus musculus')...
# Fetching 0 pages for 'SLC26A9' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'Avpr2' (species 'Homo sapiens')...
# Fetching 0 pages for 'Avpr2' (species 'Mus musculus')...
# Fetching 0 pages for 'Avpr2' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Parm1' (species 'Homo sapiens')...
# Fetching 0 pages for 'Parm1' (species 'Mus musculus')...
# Fetching 0 pages for 'Parm1' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'AVPR2' (species 'Homo sapiens')...
# Fetching 0 pages for 'AVPR2' (species 'Mus musculus')...
# Fetching 0 pages for 'AVPR2' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'ABCG23' (species 'Homo sapiens')...
# Fetching 0 pages for 'ABCG23' (species 'Mus musculus')...
# Fetching 0 pages for 'ABCG23' (species 'Rattus norvegicus')...
# Fetching 3 pages for 'Slc39a8' (species 'Homo sapiens')...
# Fetching 0 pages for 'Slc39a8' (species 'Mus musculus')...
# Fetching 0 pages for 'Slc39a8' (species 'Rattus norvegicus')...
# Fetching 20 pages for 'CAT5' (species 'Homo sapiens')...
# Fetching 3 pages for 'CAT5' (species 'Mus musculus')...
# Fetching 0 pages for 'CAT5' (species 'Rattus norvegicus')...
# Fetching 4 pages for 'Abcg2' (species 'Homo sapiens')...
# Fetching 2 pages for 'Abcg2' (species 'Mus musculus')...
# Fetching 0 pages for 'Abcg2' (species 'Rattus norvegicus')...
# Fetching 3 pages for 'STP1' (species 'Homo sapiens')...
# Fetching 0 pages for 'STP1' (species 'Mus musculus')...
# Fetching 0 pages for 'STP1' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Abca4' (species 'Homo sapiens')...
# Fetching 0 pages for 'Abca4' (species 'Mus musculus')...
# Fetching 0 pages for 'Abca4' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Ptch2' (species 'Homo sapiens')...
# Fetching 0 pages for 'Ptch2' (species 'Mus musculus')...
# Fetching 0 pages for 'Ptch2' (species 'Rattus norvegicus')...
# Fetching 5 pages for 'PLXNB1' (species 'Homo sapiens')...
# Fetching 2 pages for 'PLXNB1' (species 'Mus musculus')...
# Fetching 0 pages for 'PLXNB1' (species 'Rattus norvegicus')...
# Fetching 6 pages for 'Slc16a3' (species 'Homo sapiens')...
# Fetching 1 pages for 'Slc16a3' (species 'Mus musculus')...
# Fetching 0 pages for 'Slc16a3' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'CALHM4' (species 'Homo sapiens')...
# Fetching 1 pages for 'CALHM4' (species 'Mus musculus')...
# Fetching 0 pages for 'CALHM4' (species 'Rattus norvegicus')...
# Fetching 166 pages for 'MIP' (species 'Homo sapiens')...
# Skipping...
# Fetching 8 pages for 'MIP' (species 'Mus musculus')...
# Fetching 0 pages for 'MIP' (species 'Rattus norvegicus')...
# Fetching 13 pages for 'OXER1' (species 'Homo sapiens')...
# Fetching 0 pages for 'OXER1' (species 'Mus musculus')...
# Fetching 0 pages for 'OXER1' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'SULTR4' (species 'Homo sapiens')...
# Fetching 0 pages for 'SULTR4' (species 'Mus musculus')...
# Fetching 0 pages for 'SULTR4' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'asic4b' (species 'Homo sapiens')...
# Fetching 0 pages for 'asic4b' (species 'Mus musculus')...
# Fetching 0 pages for 'asic4b' (species 'Rattus norvegicus')...
# Fetching 6 pages for 'SLC16A13' (species 'Homo sapiens')...
# Fetching 0 pages for 'SLC16A13' (species 'Mus musculus')...
# Fetching 0 pages for 'SLC16A13' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'SLC26A11' (species 'Homo sapiens')...
# Fetching 0 pages for 'SLC26A11' (species 'Mus musculus')...
# Fetching 0 pages for 'SLC26A11' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'SLC16A14' (species 'Homo sapiens')...
# Fetching 0 pages for 'SLC16A14' (species 'Mus musculus')...
# Fetching 0 pages for 'SLC16A14' (species 'Rattus norvegicus')...
# Fetching 5 pages for 'SYPL1' (species 'Homo sapiens')...
# Fetching 1 pages for 'SYPL1' (species 'Mus musculus')...
# Fetching 0 pages for 'SYPL1' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'At5g41800' (species 'Homo sapiens')...
# Fetching 0 pages for 'At5g41800' (species 'Mus musculus')...
# Fetching 0 pages for 'At5g41800' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'asic1c' (species 'Homo sapiens')...
# Fetching 0 pages for 'asic1c' (species 'Mus musculus')...
# Fetching 0 pages for 'asic1c' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'taar13c' (species 'Homo sapiens')...
# Fetching 0 pages for 'taar13c' (species 'Mus musculus')...
# Fetching 0 pages for 'taar13c' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'asic1b' (species 'Homo sapiens')...
# Fetching 0 pages for 'asic1b' (species 'Mus musculus')...
# Fetching 0 pages for 'asic1b' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'asic2' (species 'Homo sapiens')...
# Fetching 1 pages for 'asic2' (species 'Mus musculus')...
# Fetching 0 pages for 'asic2' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'OR10AC1' (species 'Homo sapiens')...
# Fetching 0 pages for 'OR10AC1' (species 'Mus musculus')...
# Fetching 0 pages for 'OR10AC1' (species 'Rattus norvegicus')...
# Fetching 4 pages for 'KIRREL3' (species 'Homo sapiens')...
# Fetching 1 pages for 'KIRREL3' (species 'Mus musculus')...
# Fetching 0 pages for 'KIRREL3' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'NRG4' (species 'Homo sapiens')...
# Fetching 0 pages for 'NRG4' (species 'Mus musculus')...
# Fetching 0 pages for 'NRG4' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'SLC2A6' (species 'Homo sapiens')...
# Fetching 0 pages for 'SLC2A6' (species 'Mus musculus')...
# Fetching 0 pages for 'SLC2A6' (species 'Rattus norvegicus')...
# Fetching 25 pages for 'slc39a1' (species 'Homo sapiens')...
# Fetching 2 pages for 'slc39a1' (species 'Mus musculus')...
# Fetching 0 pages for 'slc39a1' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'SLC16A11' (species 'Homo sapiens')...
# Fetching 0 pages for 'SLC16A11' (species 'Mus musculus')...
# Fetching 0 pages for 'SLC16A11' (species 'Rattus norvegicus')...
# Fetching 16 pages for 'ASIC4' (species 'Homo sapiens')...
# Fetching 0 pages for 'ASIC4' (species 'Mus musculus')...
# Fetching 0 pages for 'ASIC4' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'HGSNAT' (species 'Homo sapiens')...
# Fetching 0 pages for 'HGSNAT' (species 'Mus musculus')...
# Fetching 0 pages for 'HGSNAT' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'DUOXA1' (species 'Homo sapiens')...
# Fetching 0 pages for 'DUOXA1' (species 'Mus musculus')...
# Fetching 0 pages for 'DUOXA1' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'SV2B' (species 'Homo sapiens')...
# Fetching 1 pages for 'SV2B' (species 'Mus musculus')...
# Fetching 0 pages for 'SV2B' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'MRGPRX4' (species 'Homo sapiens')...
# Fetching 0 pages for 'MRGPRX4' (species 'Mus musculus')...
# Fetching 0 pages for 'MRGPRX4' (species 'Rattus norvegicus')...
# Fetching 3 pages for 'SLC39A8' (species 'Homo sapiens')...
# Fetching 0 pages for 'SLC39A8' (species 'Mus musculus')...
# Fetching 0 pages for 'SLC39A8' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'OR11H7' (species 'Homo sapiens')...
# Fetching 0 pages for 'OR11H7' (species 'Mus musculus')...
# Fetching 0 pages for 'OR11H7' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'AVP1' (species 'Homo sapiens')...
# Fetching 0 pages for 'AVP1' (species 'Mus musculus')...
# Fetching 0 pages for 'AVP1' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'DCST1' (species 'Homo sapiens')...
# Fetching 0 pages for 'DCST1' (species 'Mus musculus')...
# Fetching 0 pages for 'DCST1' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'SLC5A5' (species 'Homo sapiens')...
# Fetching 0 pages for 'SLC5A5' (species 'Mus musculus')...
# Fetching 0 pages for 'SLC5A5' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'SLC6A7' (species 'Homo sapiens')...
# Fetching 0 pages for 'SLC6A7' (species 'Mus musculus')...
# Fetching 0 pages for 'SLC6A7' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'KCNK15' (species 'Homo sapiens')...
# Fetching 0 pages for 'KCNK15' (species 'Mus musculus')...
# Fetching 0 pages for 'KCNK15' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'ASIC2' (species 'Homo sapiens')...
# Fetching 1 pages for 'ASIC2' (species 'Mus musculus')...
# Fetching 0 pages for 'ASIC2' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'Ttyh2' (species 'Homo sapiens')...
# Fetching 0 pages for 'Ttyh2' (species 'Mus musculus')...
# Fetching 0 pages for 'Ttyh2' (species 'Rattus norvegicus')...
# Fetching 64 pages for 'Erbb3' (species 'Homo sapiens')...
# Fetching 2 pages for 'Erbb3' (species 'Mus musculus')...
# Fetching 0 pages for 'Erbb3' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Asic2' (species 'Homo sapiens')...
# Fetching 1 pages for 'Asic2' (species 'Mus musculus')...
# Fetching 0 pages for 'Asic2' (species 'Rattus norvegicus')...
# Fetching 3 pages for 'ICAM4' (species 'Homo sapiens')...
# Fetching 0 pages for 'ICAM4' (species 'Mus musculus')...
# Fetching 0 pages for 'ICAM4' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'TRPC6' (species 'Homo sapiens')...
# Fetching 1 pages for 'TRPC6' (species 'Mus musculus')...
# Fetching 0 pages for 'TRPC6' (species 'Rattus norvegicus')...
# Fetching 9 pages for 'TRPC1' (species 'Homo sapiens')...
# Fetching 2 pages for 'TRPC1' (species 'Mus musculus')...
# Fetching 0 pages for 'TRPC1' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Slc7a9' (species 'Homo sapiens')...
# Fetching 0 pages for 'Slc7a9' (species 'Mus musculus')...
# Fetching 0 pages for 'Slc7a9' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'OPT3' (species 'Homo sapiens')...
# Fetching 0 pages for 'OPT3' (species 'Mus musculus')...
# Fetching 0 pages for 'OPT3' (species 'Rattus norvegicus')...
# Fetching 5 pages for 'Plxnb1' (species 'Homo sapiens')...
# Fetching 2 pages for 'Plxnb1' (species 'Mus musculus')...
# Fetching 0 pages for 'Plxnb1' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Slc16a14' (species 'Homo sapiens')...
# Fetching 0 pages for 'Slc16a14' (species 'Mus musculus')...
# Fetching 0 pages for 'Slc16a14' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Unc5a' (species 'Homo sapiens')...
# Fetching 1 pages for 'Unc5a' (species 'Mus musculus')...
# Fetching 0 pages for 'Unc5a' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Slc22a12' (species 'Homo sapiens')...
# Fetching 0 pages for 'Slc22a12' (species 'Mus musculus')...
# Fetching 0 pages for 'Slc22a12' (species 'Rattus norvegicus')...
# Fetching 4 pages for 'Kirrel3' (species 'Homo sapiens')...
# Fetching 1 pages for 'Kirrel3' (species 'Mus musculus')...
# Fetching 0 pages for 'Kirrel3' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Slc52a3' (species 'Homo sapiens')...
# Fetching 1 pages for 'Slc52a3' (species 'Mus musculus')...
# Fetching 0 pages for 'Slc52a3' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'RHAG' (species 'Homo sapiens')...
# Fetching 0 pages for 'RHAG' (species 'Mus musculus')...
# Fetching 0 pages for 'RHAG' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'Duoxa1' (species 'Homo sapiens')...
# Fetching 0 pages for 'Duoxa1' (species 'Mus musculus')...
# Fetching 0 pages for 'Duoxa1' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'ATP1A4' (species 'Homo sapiens')...
# Fetching 1 pages for 'ATP1A4' (species 'Mus musculus')...
# Fetching 0 pages for 'ATP1A4' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Adcy5' (species 'Homo sapiens')...
# Fetching 0 pages for 'Adcy5' (species 'Mus musculus')...
# Fetching 0 pages for 'Adcy5' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'Slc6a7' (species 'Homo sapiens')...
# Fetching 0 pages for 'Slc6a7' (species 'Mus musculus')...
# Fetching 0 pages for 'Slc6a7' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'asic1a' (species 'Homo sapiens')...
# Fetching 1 pages for 'asic1a' (species 'Mus musculus')...
# Fetching 0 pages for 'asic1a' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'ADCY1' (species 'Homo sapiens')...
# Fetching 1 pages for 'ADCY1' (species 'Mus musculus')...
# Fetching 0 pages for 'ADCY1' (species 'Rattus norvegicus')...
# Fetching 13 pages for 'SLAMF1' (species 'Homo sapiens')...
# Fetching 7 pages for 'SLAMF1' (species 'Mus musculus')...
# Fetching 0 pages for 'SLAMF1' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'asic4a' (species 'Homo sapiens')...
# Fetching 0 pages for 'asic4a' (species 'Mus musculus')...
# Fetching 0 pages for 'asic4a' (species 'Rattus norvegicus')...
# Fetching 9 pages for 'CHRM4' (species 'Homo sapiens')...
# Fetching 1 pages for 'CHRM4' (species 'Mus musculus')...
# Fetching 0 pages for 'CHRM4' (species 'Rattus norvegicus')...
# Fetching 13 pages for 'SLC1A5' (species 'Homo sapiens')...
# Fetching 2 pages for 'SLC1A5' (species 'Mus musculus')...
# Fetching 0 pages for 'SLC1A5' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'Marveld1' (species 'Homo sapiens')...
# Fetching 0 pages for 'Marveld1' (species 'Mus musculus')...
# Fetching 0 pages for 'Marveld1' (species 'Rattus norvegicus')...
# Fetching 3 pages for 'Slc43a2' (species 'Homo sapiens')...
# Fetching 0 pages for 'Slc43a2' (species 'Mus musculus')...
# Fetching 0 pages for 'Slc43a2' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'Otop1' (species 'Homo sapiens')...
# Fetching 0 pages for 'Otop1' (species 'Mus musculus')...
# Fetching 0 pages for 'Otop1' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Slc26a11' (species 'Homo sapiens')...
# Fetching 0 pages for 'Slc26a11' (species 'Mus musculus')...
# Fetching 0 pages for 'Slc26a11' (species 'Rattus norvegicus')...
# Fetching 8 pages for 'Stab1' (species 'Homo sapiens')...
# Fetching 0 pages for 'Stab1' (species 'Mus musculus')...
# Fetching 0 pages for 'Stab1' (species 'Rattus norvegicus')...
# Fetching 6 pages for 'Slc16a13' (species 'Homo sapiens')...
# Fetching 0 pages for 'Slc16a13' (species 'Mus musculus')...
# Fetching 0 pages for 'Slc16a13' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'Tmc6' (species 'Homo sapiens')...
# Fetching 0 pages for 'Tmc6' (species 'Mus musculus')...
# Fetching 0 pages for 'Tmc6' (species 'Rattus norvegicus')...
# Fetching 91 pages for 'Aqp6' (species 'Homo sapiens')...
# Fetching 0 pages for 'Aqp6' (species 'Mus musculus')...
# Fetching 0 pages for 'Aqp6' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'TMC6' (species 'Homo sapiens')...
# Fetching 0 pages for 'TMC6' (species 'Mus musculus')...
# Fetching 0 pages for 'TMC6' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'YSL3' (species 'Homo sapiens')...
# Fetching 0 pages for 'YSL3' (species 'Mus musculus')...
# Fetching 0 pages for 'YSL3' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'Abca7' (species 'Homo sapiens')...
# Fetching 1 pages for 'Abca7' (species 'Mus musculus')...
# Fetching 0 pages for 'Abca7' (species 'Rattus norvegicus')...
# Fetching 4 pages for 'Celsr3' (species 'Homo sapiens')...
# Fetching 1 pages for 'Celsr3' (species 'Mus musculus')...
# Fetching 0 pages for 'Celsr3' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'ASIC3' (species 'Homo sapiens')...
# Fetching 1 pages for 'ASIC3' (species 'Mus musculus')...
# Fetching 0 pages for 'ASIC3' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'MYMK' (species 'Homo sapiens')...
# Fetching 0 pages for 'MYMK' (species 'Mus musculus')...
# Fetching 0 pages for 'MYMK' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'HTR1F' (species 'Homo sapiens')...
# Fetching 0 pages for 'HTR1F' (species 'Mus musculus')...
# Fetching 0 pages for 'HTR1F' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'ASIC1' (species 'Homo sapiens')...
# Fetching 1 pages for 'ASIC1' (species 'Mus musculus')...
# Fetching 0 pages for 'ASIC1' (species 'Rattus norvegicus')...
# Fetching 12 pages for 'SLC22A1' (species 'Homo sapiens')...
# Fetching 0 pages for 'SLC22A1' (species 'Mus musculus')...
# Fetching 0 pages for 'SLC22A1' (species 'Rattus norvegicus')...
# Fetching 15 pages for 'Cxcr4' (species 'Homo sapiens')...
# Fetching 1 pages for 'Cxcr4' (species 'Mus musculus')...
# Fetching 0 pages for 'Cxcr4' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'Asic1' (species 'Homo sapiens')...
# Fetching 1 pages for 'Asic1' (species 'Mus musculus')...
# Fetching 0 pages for 'Asic1' (species 'Rattus norvegicus')...
# Fetching 12 pages for 'Slc22a1' (species 'Homo sapiens')...
# Fetching 0 pages for 'Slc22a1' (species 'Mus musculus')...
# Fetching 0 pages for 'Slc22a1' (species 'Rattus norvegicus')...
# Fetching 4 pages for 'Plpp1' (species 'Homo sapiens')...
# Fetching 1 pages for 'Plpp1' (species 'Mus musculus')...
# Fetching 0 pages for 'Plpp1' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Adcy1' (species 'Homo sapiens')...
# Fetching 1 pages for 'Adcy1' (species 'Mus musculus')...
# Fetching 0 pages for 'Adcy1' (species 'Rattus norvegicus')...
# Fetching 10 pages for 'SCAMP1' (species 'Homo sapiens')...
# Fetching 1 pages for 'SCAMP1' (species 'Mus musculus')...
# Fetching 0 pages for 'SCAMP1' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'GPR31' (species 'Homo sapiens')...
# Fetching 0 pages for 'GPR31' (species 'Mus musculus')...
# Fetching 0 pages for 'GPR31' (species 'Rattus norvegicus')...
# Fetching 3 pages for 'PLPP2' (species 'Homo sapiens')...
# Fetching 1 pages for 'PLPP2' (species 'Mus musculus')...
# Fetching 0 pages for 'PLPP2' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'Plxnb3' (species 'Homo sapiens')...
# Fetching 1 pages for 'Plxnb3' (species 'Mus musculus')...
# Fetching 0 pages for 'Plxnb3' (species 'Rattus norvegicus')...
# Fetching 6 pages for 'SLC16A3' (species 'Homo sapiens')...
# Fetching 1 pages for 'SLC16A3' (species 'Mus musculus')...
# Fetching 0 pages for 'SLC16A3' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'SLC5A10' (species 'Homo sapiens')...
# Fetching 0 pages for 'SLC5A10' (species 'Mus musculus')...
# Fetching 0 pages for 'SLC5A10' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'MSL6' (species 'Homo sapiens')...
# Fetching 0 pages for 'MSL6' (species 'Mus musculus')...
# Fetching 0 pages for 'MSL6' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'HTR1E' (species 'Homo sapiens')...
# Fetching 0 pages for 'HTR1E' (species 'Mus musculus')...
# Fetching 0 pages for 'HTR1E' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'TPK4' (species 'Homo sapiens')...
# Fetching 0 pages for 'TPK4' (species 'Mus musculus')...
# Fetching 0 pages for 'TPK4' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'MSL7' (species 'Homo sapiens')...
# Fetching 0 pages for 'MSL7' (species 'Mus musculus')...
# Fetching 0 pages for 'MSL7' (species 'Rattus norvegicus')...
# Fetching 13 pages for 'EPHA2' (species 'Homo sapiens')...
# Fetching 1 pages for 'EPHA2' (species 'Mus musculus')...
# Fetching 0 pages for 'EPHA2' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'DUR3' (species 'Homo sapiens')...
# Fetching 0 pages for 'DUR3' (species 'Mus musculus')...
# Fetching 0 pages for 'DUR3' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'IRT2' (species 'Homo sapiens')...
# Fetching 0 pages for 'IRT2' (species 'Mus musculus')...
# Fetching 0 pages for 'IRT2' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'ABCC6' (species 'Homo sapiens')...
# Fetching 0 pages for 'ABCC6' (species 'Mus musculus')...
# Fetching 0 pages for 'ABCC6' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'OPT7' (species 'Homo sapiens')...
# Fetching 0 pages for 'OPT7' (species 'Mus musculus')...
# Fetching 0 pages for 'OPT7' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'AVT1I' (species 'Homo sapiens')...
# Fetching 0 pages for 'AVT1I' (species 'Mus musculus')...
# Fetching 0 pages for 'AVT1I' (species 'Rattus norvegicus')...
# Fetching 14 pages for 'Epha1' (species 'Homo sapiens')...
# Fetching 1 pages for 'Epha1' (species 'Mus musculus')...
# Fetching 0 pages for 'Epha1' (species 'Rattus norvegicus')...
# Fetching 3 pages for 'Cckbr' (species 'Homo sapiens')...
# Fetching 1 pages for 'Cckbr' (species 'Mus musculus')...
# Fetching 0 pages for 'Cckbr' (species 'Rattus norvegicus')...
# Fetching 8 pages for 'Scarb1' (species 'Homo sapiens')...
# Fetching 0 pages for 'Scarb1' (species 'Mus musculus')...
# Fetching 0 pages for 'Scarb1' (species 'Rattus norvegicus')...
# Fetching 14 pages for 'ITGAV' (species 'Homo sapiens')...
# Fetching 1 pages for 'ITGAV' (species 'Mus musculus')...
# Fetching 0 pages for 'ITGAV' (species 'Rattus norvegicus')...
# Fetching 10 pages for 'C3ar1' (species 'Homo sapiens')...
# Fetching 0 pages for 'C3ar1' (species 'Mus musculus')...
# Fetching 0 pages for 'C3ar1' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'MLNR' (species 'Homo sapiens')...
# Fetching 0 pages for 'MLNR' (species 'Mus musculus')...
# Fetching 0 pages for 'MLNR' (species 'Rattus norvegicus')...
# Fetching 13 pages for 'Sirpa' (species 'Homo sapiens')...
# Fetching 1 pages for 'Sirpa' (species 'Mus musculus')...
# Fetching 0 pages for 'Sirpa' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Npc1l1' (species 'Homo sapiens')...
# Fetching 0 pages for 'Npc1l1' (species 'Mus musculus')...
# Fetching 0 pages for 'Npc1l1' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'Ano7' (species 'Homo sapiens')...
# Fetching 0 pages for 'Ano7' (species 'Mus musculus')...
# Fetching 0 pages for 'Ano7' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Slc52a2' (species 'Homo sapiens')...
# Fetching 1 pages for 'Slc52a2' (species 'Mus musculus')...
# Fetching 0 pages for 'Slc52a2' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'CHRM1' (species 'Homo sapiens')...
# Fetching 0 pages for 'CHRM1' (species 'Mus musculus')...
# Fetching 0 pages for 'CHRM1' (species 'Rattus norvegicus')...
# Fetching 10 pages for 'Tmem100' (species 'Homo sapiens')...
# Fetching 0 pages for 'Tmem100' (species 'Mus musculus')...
# Fetching 0 pages for 'Tmem100' (species 'Rattus norvegicus')...
# Fetching 117 pages for 'Erbb2' (species 'Homo sapiens')...
# Fetching 5 pages for 'Erbb2' (species 'Mus musculus')...
# Fetching 0 pages for 'Erbb2' (species 'Rattus norvegicus')...
# Fetching 5 pages for 'Gramd1a' (species 'Homo sapiens')...
# Fetching 1 pages for 'Gramd1a' (species 'Mus musculus')...
# Fetching 0 pages for 'Gramd1a' (species 'Rattus norvegicus')...
# Fetching 3 pages for 'ACKR2' (species 'Homo sapiens')...
# Fetching 0 pages for 'ACKR2' (species 'Mus musculus')...
# Fetching 0 pages for 'ACKR2' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'Abcc2' (species 'Homo sapiens')...
# Fetching 0 pages for 'Abcc2' (species 'Mus musculus')...
# Fetching 0 pages for 'Abcc2' (species 'Rattus norvegicus')...
# Fetching 6 pages for 'Cdh20' (species 'Homo sapiens')...
# Fetching 0 pages for 'Cdh20' (species 'Mus musculus')...
# Fetching 0 pages for 'Cdh20' (species 'Rattus norvegicus')...
# Fetching 14 pages for 'Amigo1' (species 'Homo sapiens')...
# Fetching 1 pages for 'Amigo1' (species 'Mus musculus')...
# Fetching 0 pages for 'Amigo1' (species 'Rattus norvegicus')...
# Fetching 3 pages for 'PIGN' (species 'Homo sapiens')...
# Fetching 1 pages for 'PIGN' (species 'Mus musculus')...
# Fetching 0 pages for 'PIGN' (species 'Rattus norvegicus')...
# Fetching 5 pages for 'Slc6a2' (species 'Homo sapiens')...
# Fetching 1 pages for 'Slc6a2' (species 'Mus musculus')...
# Fetching 0 pages for 'Slc6a2' (species 'Rattus norvegicus')...
# Fetching 3 pages for 'Adra1b' (species 'Homo sapiens')...
# Fetching 1 pages for 'Adra1b' (species 'Mus musculus')...
# Fetching 0 pages for 'Adra1b' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'Cdh22' (species 'Homo sapiens')...
# Fetching 0 pages for 'Cdh22' (species 'Mus musculus')...
# Fetching 0 pages for 'Cdh22' (species 'Rattus norvegicus')...
# Fetching 4 pages for 'CTLA4' (species 'Homo sapiens')...
# Fetching 1 pages for 'CTLA4' (species 'Mus musculus')...
# Fetching 0 pages for 'CTLA4' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'Slc4a9' (species 'Homo sapiens')...
# Fetching 0 pages for 'Slc4a9' (species 'Mus musculus')...
# Fetching 0 pages for 'Slc4a9' (species 'Rattus norvegicus')...
# Fetching 5 pages for 'ZP3' (species 'Homo sapiens')...
# Fetching 0 pages for 'ZP3' (species 'Mus musculus')...
# Fetching 0 pages for 'ZP3' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'ABCG1' (species 'Homo sapiens')...
# Fetching 1 pages for 'ABCG1' (species 'Mus musculus')...
# Fetching 0 pages for 'ABCG1' (species 'Rattus norvegicus')...
# Fetching 8 pages for 'Fgfr4' (species 'Homo sapiens')...
# Fetching 1 pages for 'Fgfr4' (species 'Mus musculus')...
# Fetching 0 pages for 'Fgfr4' (species 'Rattus norvegicus')...
# Fetching 3 pages for 'ADCY6' (species 'Homo sapiens')...
# Fetching 1 pages for 'ADCY6' (species 'Mus musculus')...
# Fetching 0 pages for 'ADCY6' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Dscam' (species 'Homo sapiens')...
# Fetching 3 pages for 'Dscam' (species 'Mus musculus')...
# Fetching 0 pages for 'Dscam' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Hrh2' (species 'Homo sapiens')...
# Fetching 0 pages for 'Hrh2' (species 'Mus musculus')...
# Fetching 0 pages for 'Hrh2' (species 'Rattus norvegicus')...
# Fetching 6 pages for 'Hcn4' (species 'Homo sapiens')...
# Fetching 1 pages for 'Hcn4' (species 'Mus musculus')...
# Fetching 0 pages for 'Hcn4' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'Chrne' (species 'Homo sapiens')...
# Fetching 0 pages for 'Chrne' (species 'Mus musculus')...
# Fetching 0 pages for 'Chrne' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Hcn1' (species 'Homo sapiens')...
# Fetching 9 pages for 'Hcn1' (species 'Mus musculus')...
# Fetching 0 pages for 'Hcn1' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'HCN3' (species 'Homo sapiens')...
# Fetching 1 pages for 'HCN3' (species 'Mus musculus')...
# Fetching 0 pages for 'HCN3' (species 'Rattus norvegicus')...
# Fetching 5 pages for 'Aqp8' (species 'Homo sapiens')...
# Fetching 0 pages for 'Aqp8' (species 'Mus musculus')...
# Fetching 0 pages for 'Aqp8' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Hcn3' (species 'Homo sapiens')...
# Fetching 1 pages for 'Hcn3' (species 'Mus musculus')...
# Fetching 0 pages for 'Hcn3' (species 'Rattus norvegicus')...
# Fetching 9 pages for 'HCN2' (species 'Homo sapiens')...
# Fetching 4 pages for 'HCN2' (species 'Mus musculus')...
# Fetching 0 pages for 'HCN2' (species 'Rattus norvegicus')...
# Fetching 466 pages for 'cftr' (species 'Homo sapiens')...
# Skipping...
# Fetching 4 pages for 'cftr' (species 'Mus musculus')...
# Fetching 0 pages for 'cftr' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'Klri1' (species 'Homo sapiens')...
# Fetching 0 pages for 'Klri1' (species 'Mus musculus')...
# Fetching 0 pages for 'Klri1' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'HVCN1' (species 'Homo sapiens')...
# Fetching 1 pages for 'HVCN1' (species 'Mus musculus')...
# Fetching 0 pages for 'HVCN1' (species 'Rattus norvegicus')...
# Fetching 9 pages for 'Hcn2' (species 'Homo sapiens')...
# Fetching 4 pages for 'Hcn2' (species 'Mus musculus')...
# Fetching 0 pages for 'Hcn2' (species 'Rattus norvegicus')...
# Fetching 4 pages for 'Drd1' (species 'Homo sapiens')...
# Fetching 0 pages for 'Drd1' (species 'Mus musculus')...
# Fetching 0 pages for 'Drd1' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'SLC11A1' (species 'Homo sapiens')...
# Fetching 0 pages for 'SLC11A1' (species 'Mus musculus')...
# Fetching 0 pages for 'SLC11A1' (species 'Rattus norvegicus')...
# Fetching 7 pages for 'SMPD2' (species 'Homo sapiens')...
# Fetching 0 pages for 'SMPD2' (species 'Mus musculus')...
# Fetching 0 pages for 'SMPD2' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Fcamr' (species 'Homo sapiens')...
# Fetching 0 pages for 'Fcamr' (species 'Mus musculus')...
# Fetching 0 pages for 'Fcamr' (species 'Rattus norvegicus')...
# Fetching 25 pages for 'Fcer1g' (species 'Homo sapiens')...
# Fetching 1 pages for 'Fcer1g' (species 'Mus musculus')...
# Fetching 0 pages for 'Fcer1g' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'Hvcn1' (species 'Homo sapiens')...
# Fetching 1 pages for 'Hvcn1' (species 'Mus musculus')...
# Fetching 0 pages for 'Hvcn1' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'At1g31820' (species 'Homo sapiens')...
# Fetching 0 pages for 'At1g31820' (species 'Mus musculus')...
# Fetching 0 pages for 'At1g31820' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'At1g31830' (species 'Homo sapiens')...
# Fetching 0 pages for 'At1g31830' (species 'Mus musculus')...
# Fetching 0 pages for 'At1g31830' (species 'Rattus norvegicus')...
# Fetching 10 pages for 'Abca1' (species 'Homo sapiens')...
# Fetching 1 pages for 'Abca1' (species 'Mus musculus')...
# Fetching 0 pages for 'Abca1' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'RST1' (species 'Homo sapiens')...
# Fetching 0 pages for 'RST1' (species 'Mus musculus')...
# Fetching 0 pages for 'RST1' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'SERK5' (species 'Homo sapiens')...
# Fetching 0 pages for 'SERK5' (species 'Mus musculus')...
# Fetching 0 pages for 'SERK5' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'SLC7A9' (species 'Homo sapiens')...
# Fetching 0 pages for 'SLC7A9' (species 'Mus musculus')...
# Fetching 0 pages for 'SLC7A9' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'CD34' (species 'Homo sapiens')...
# Fetching 0 pages for 'CD34' (species 'Mus musculus')...
# Fetching 0 pages for 'CD34' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'CCR7' (species 'Homo sapiens')...
# Fetching 1 pages for 'CCR7' (species 'Mus musculus')...
# Fetching 0 pages for 'CCR7' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'OR4A47' (species 'Homo sapiens')...
# Fetching 0 pages for 'OR4A47' (species 'Mus musculus')...
# Fetching 0 pages for 'OR4A47' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'CLDN6' (species 'Homo sapiens')...
# Fetching 1 pages for 'CLDN6' (species 'Mus musculus')...
# Fetching 0 pages for 'CLDN6' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'ABCA12' (species 'Homo sapiens')...
# Fetching 1 pages for 'ABCA12' (species 'Mus musculus')...
# Fetching 0 pages for 'ABCA12' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'MRGPRE' (species 'Homo sapiens')...
# Fetching 0 pages for 'MRGPRE' (species 'Mus musculus')...
# Fetching 0 pages for 'MRGPRE' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'KCNMB4' (species 'Homo sapiens')...
# Fetching 1 pages for 'KCNMB4' (species 'Mus musculus')...
# Fetching 0 pages for 'KCNMB4' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'SLC20A2' (species 'Homo sapiens')...
# Fetching 0 pages for 'SLC20A2' (species 'Mus musculus')...
# Fetching 0 pages for 'SLC20A2' (species 'Rattus norvegicus')...
# Fetching 9 pages for 'FPR2' (species 'Homo sapiens')...
# Fetching 0 pages for 'FPR2' (species 'Mus musculus')...
# Fetching 0 pages for 'FPR2' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'OR52E4' (species 'Homo sapiens')...
# Fetching 0 pages for 'OR52E4' (species 'Mus musculus')...
# Fetching 0 pages for 'OR52E4' (species 'Rattus norvegicus')...
# Fetching 6 pages for 'TACR1' (species 'Homo sapiens')...
# Fetching 0 pages for 'TACR1' (species 'Mus musculus')...
# Fetching 0 pages for 'TACR1' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'Ptprm' (species 'Homo sapiens')...
# Fetching 2 pages for 'Ptprm' (species 'Mus musculus')...
# Fetching 0 pages for 'Ptprm' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'ROM1' (species 'Homo sapiens')...
# Fetching 0 pages for 'ROM1' (species 'Mus musculus')...
# Fetching 0 pages for 'ROM1' (species 'Rattus norvegicus')...
# Fetching 10 pages for 'ABCA1' (species 'Homo sapiens')...
# ...
# Fetching 12 pages for 'LRP4' (species 'Homo sapiens')...
# Fetching 2 pages for 'LRP4' (species 'Mus musculus')...
# Fetching 0 pages for 'LRP4' (species 'Rattus norvegicus')...
# Fetching 8 pages for 'THBD' (species 'Homo sapiens')...
# Fetching 1 pages for 'THBD' (species 'Mus musculus')...
# Fetching 0 pages for 'THBD' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'Slc28a2' (species 'Homo sapiens')...
# Fetching 0 pages for 'Slc28a2' (species 'Mus musculus')...
# Fetching 0 pages for 'Slc28a2' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'TSPAN6' (species 'Homo sapiens')...
# Fetching 0 pages for 'TSPAN6' (species 'Mus musculus')...
# Fetching 0 pages for 'TSPAN6' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'At2g19210' (species 'Homo sapiens')...
# Fetching 0 pages for 'At2g19210' (species 'Mus musculus')...
# Fetching 0 pages for 'At2g19210' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'MSL5' (species 'Homo sapiens')...
# Fetching 0 pages for 'MSL5' (species 'Mus musculus')...
# Fetching 0 pages for 'MSL5' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'SLC17A1' (species 'Homo sapiens')...
# Fetching 1 pages for 'SLC17A1' (species 'Mus musculus')...
# Fetching 0 pages for 'SLC17A1' (species 'Rattus norvegicus')...
# Fetching 15 pages for 'CXCR4' (species 'Homo sapiens')...
# Fetching 1 pages for 'CXCR4' (species 'Mus musculus')...
# Fetching 0 pages for 'CXCR4' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Mpig6b' (species 'Homo sapiens')...
# Fetching 0 pages for 'Mpig6b' (species 'Mus musculus')...
# Fetching 0 pages for 'Mpig6b' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'At1g80640' (species 'Homo sapiens')...
# Fetching 0 pages for 'At1g80640' (species 'Mus musculus')...
# Fetching 0 pages for 'At1g80640' (species 'Rattus norvegicus')...
# Fetching 6 pages for 'CACNG1' (species 'Homo sapiens')...
# Fetching 0 pages for 'CACNG1' (species 'Mus musculus')...
# Fetching 0 pages for 'CACNG1' (species 'Rattus norvegicus')...
# Fetching 4 pages for 'ROS1' (species 'Homo sapiens')...
# Fetching 1 pages for 'ROS1' (species 'Mus musculus')...
# Fetching 0 pages for 'ROS1' (species 'Rattus norvegicus')...
# Fetching 11 pages for 'Shab' (species 'Homo sapiens')...
# Fetching 3 pages for 'Shab' (species 'Mus musculus')...
# Fetching 0 pages for 'Shab' (species 'Rattus norvegicus')...
# Fetching 62 pages for 'Emp2' (species 'Homo sapiens')...
# Fetching 24 pages for 'Emp2' (species 'Mus musculus')...
# Fetching 0 pages for 'Emp2' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Slc4a3' (species 'Homo sapiens')...
# Fetching 0 pages for 'Slc4a3' (species 'Mus musculus')...
# Fetching 0 pages for 'Slc4a3' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'hvcn1' (species 'Homo sapiens')...
# Fetching 1 pages for 'hvcn1' (species 'Mus musculus')...
# Fetching 0 pages for 'hvcn1' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Tmc4' (species 'Homo sapiens')...
# Fetching 0 pages for 'Tmc4' (species 'Mus musculus')...
# Fetching 0 pages for 'Tmc4' (species 'Rattus norvegicus')...
# Fetching 3 pages for 'Piezo1' (species 'Homo sapiens')...
# Fetching 3 pages for 'Piezo1' (species 'Mus musculus')...
# Fetching 0 pages for 'Piezo1' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'ETN8' (species 'Homo sapiens')...
# Fetching 0 pages for 'ETN8' (species 'Mus musculus')...
# Fetching 0 pages for 'ETN8' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'ldlrad3' (species 'Homo sapiens')...
# Fetching 0 pages for 'ldlrad3' (species 'Mus musculus')...
# Fetching 0 pages for 'ldlrad3' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'Uts2r' (species 'Homo sapiens')...
# Fetching 0 pages for 'Uts2r' (species 'Mus musculus')...
# Fetching 0 pages for 'Uts2r' (species 'Rattus norvegicus')...
# Fetching 40 pages for 'Pdgfrb' (species 'Homo sapiens')...
# Fetching 3 pages for 'Pdgfrb' (species 'Mus musculus')...
# Fetching 0 pages for 'Pdgfrb' (species 'Rattus norvegicus')...
# Fetching 25 pages for 'Slc30a8' (species 'Homo sapiens')...
# Fetching 0 pages for 'Slc30a8' (species 'Mus musculus')...
# Fetching 0 pages for 'Slc30a8' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Ano8' (species 'Homo sapiens')...
# Fetching 0 pages for 'Ano8' (species 'Mus musculus')...
# Fetching 0 pages for 'Ano8' (species 'Rattus norvegicus')...
# Fetching 4 pages for 'Thsd7a' (species 'Homo sapiens')...
# Fetching 1 pages for 'Thsd7a' (species 'Mus musculus')...
# Fetching 0 pages for 'Thsd7a' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'At3g47570' (species 'Homo sapiens')...
# Fetching 0 pages for 'At3g47570' (species 'Mus musculus')...
# Fetching 0 pages for 'At3g47570' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'HRD1B' (species 'Homo sapiens')...
# Fetching 0 pages for 'HRD1B' (species 'Mus musculus')...
# Fetching 0 pages for 'HRD1B' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'nAChRbeta1' (species 'Homo sapiens')...
# Fetching 0 pages for 'nAChRbeta1' (species 'Mus musculus')...
# Fetching 0 pages for 'nAChRbeta1' (species 'Rattus norvegicus')...
# Fetching 3 pages for 'Epcam' (species 'Homo sapiens')...
# Fetching 1 pages for 'Epcam' (species 'Mus musculus')...
# Fetching 0 pages for 'Epcam' (species 'Rattus norvegicus')...
# Fetching 7 pages for 'Notch4' (species 'Homo sapiens')...
# Fetching 2 pages for 'Notch4' (species 'Mus musculus')...
# Fetching 0 pages for 'Notch4' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'At5g10290' (species 'Homo sapiens')...
# Fetching 0 pages for 'At5g10290' (species 'Mus musculus')...
# Fetching 0 pages for 'At5g10290' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'TMK1' (species 'Homo sapiens')...
# Fetching 0 pages for 'TMK1' (species 'Mus musculus')...
# Fetching 0 pages for 'TMK1' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'slc38a6' (species 'Homo sapiens')...
# Fetching 0 pages for 'slc38a6' (species 'Mus musculus')...
# Fetching 0 pages for 'slc38a6' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Slc26a1' (species 'Homo sapiens')...
# Fetching 0 pages for 'Slc26a1' (species 'Mus musculus')...
# Fetching 0 pages for 'Slc26a1' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'At5g05160' (species 'Homo sapiens')...
# Fetching 0 pages for 'At5g05160' (species 'Mus musculus')...
# Fetching 0 pages for 'At5g05160' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'NRT2.3' (species 'Homo sapiens')...
# Fetching 0 pages for 'NRT2.3' (species 'Mus musculus')...
# Fetching 0 pages for 'NRT2.3' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'At5g47470' (species 'Homo sapiens')...
# Fetching 0 pages for 'At5g47470' (species 'Mus musculus')...
# Fetching 0 pages for 'At5g47470' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'CRK29' (species 'Homo sapiens')...
# Fetching 0 pages for 'CRK29' (species 'Mus musculus')...
# Fetching 0 pages for 'CRK29' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'K-CAM' (species 'Homo sapiens')...
# Fetching 0 pages for 'K-CAM' (species 'Mus musculus')...
# Fetching 0 pages for 'K-CAM' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'PSY1R' (species 'Homo sapiens')...
# Fetching 0 pages for 'PSY1R' (species 'Mus musculus')...
# Fetching 0 pages for 'PSY1R' (species 'Rattus norvegicus')...
# Fetching 19 pages for 'TPC1' (species 'Homo sapiens')...
# Fetching 2 pages for 'TPC1' (species 'Mus musculus')...
# Fetching 0 pages for 'TPC1' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'PHO1-H1' (species 'Homo sapiens')...
# Fetching 0 pages for 'PHO1-H1' (species 'Mus musculus')...
# Fetching 0 pages for 'PHO1-H1' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'At1g61480' (species 'Homo sapiens')...
# Fetching 0 pages for 'At1g61480' (species 'Mus musculus')...
# Fetching 0 pages for 'At1g61480' (species 'Rattus norvegicus')...
# Fetching 2 pages for 'SWEET1' (species 'Homo sapiens')...
# Fetching 0 pages for 'SWEET1' (species 'Mus musculus')...
# Fetching 0 pages for 'SWEET1' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'NPF2.9' (species 'Homo sapiens')...
# Fetching 0 pages for 'NPF2.9' (species 'Mus musculus')...
# Fetching 0 pages for 'NPF2.9' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'At2g23680' (species 'Homo sapiens')...
# Fetching 0 pages for 'At2g23680' (species 'Mus musculus')...
# Fetching 0 pages for 'At2g23680' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'At3g16300' (species 'Homo sapiens')...
# Fetching 0 pages for 'At3g16300' (species 'Mus musculus')...
# Fetching 0 pages for 'At3g16300' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'SLAH2' (species 'Homo sapiens')...
# Fetching 0 pages for 'SLAH2' (species 'Mus musculus')...
# Fetching 0 pages for 'SLAH2' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'PAT22' (species 'Homo sapiens')...
# Fetching 0 pages for 'PAT22' (species 'Mus musculus')...
# Fetching 0 pages for 'PAT22' (species 'Rattus norvegicus')...
# Fetching 11 pages for 'OCT1' (species 'Homo sapiens')...
# Fetching 0 pages for 'OCT1' (species 'Mus musculus')...
# Fetching 0 pages for 'OCT1' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'NPF2.14' (species 'Homo sapiens')...
# Fetching 0 pages for 'NPF2.14' (species 'Mus musculus')...
# Fetching 0 pages for 'NPF2.14' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'ABCG19' (species 'Homo sapiens')...
# Fetching 0 pages for 'ABCG19' (species 'Mus musculus')...
# Fetching 0 pages for 'ABCG19' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'FRO2' (species 'Homo sapiens')...
# Fetching 0 pages for 'FRO2' (species 'Mus musculus')...
# Fetching 0 pages for 'FRO2' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'CES101' (species 'Homo sapiens')...
# Fetching 0 pages for 'CES101' (species 'Mus musculus')...
# Fetching 0 pages for 'CES101' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'GTG2' (species 'Homo sapiens')...
# Fetching 0 pages for 'GTG2' (species 'Mus musculus')...
# Fetching 0 pages for 'GTG2' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'At3g18200' (species 'Homo sapiens')...
# Fetching 0 pages for 'At3g18200' (species 'Mus musculus')...
# Fetching 0 pages for 'At3g18200' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'At4g02900' (species 'Homo sapiens')...
# Fetching 0 pages for 'At4g02900' (species 'Mus musculus')...
# Fetching 0 pages for 'At4g02900' (species 'Rattus norvegicus')...
# Fetching 9 pages for 'STT3B' (species 'Homo sapiens')...
# Fetching 2 pages for 'STT3B' (species 'Mus musculus')...
# Fetching 0 pages for 'STT3B' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'At4g08290' (species 'Homo sapiens')...
# Fetching 0 pages for 'At4g08290' (species 'Mus musculus')...
# Fetching 0 pages for 'At4g08290' (species 'Rattus norvegicus')...
# Fetching 62 pages for 'ALA1' (species 'Homo sapiens')...
# Fetching 3 pages for 'ALA1' (species 'Mus musculus')...
# Fetching 0 pages for 'ALA1' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'COR413PM2' (species 'Homo sapiens')...
# Fetching 0 pages for 'COR413PM2' (species 'Mus musculus')...
# Fetching 0 pages for 'COR413PM2' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'CHX21' (species 'Homo sapiens')...
# Fetching 0 pages for 'CHX21' (species 'Mus musculus')...
# Fetching 0 pages for 'CHX21' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'DWF5' (species 'Homo sapiens')...
# Fetching 0 pages for 'DWF5' (species 'Mus musculus')...
# Fetching 0 pages for 'DWF5' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'PEPR2' (species 'Homo sapiens')...
# Fetching 0 pages for 'PEPR2' (species 'Mus musculus')...
# Fetching 0 pages for 'PEPR2' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'At1g69450' (species 'Homo sapiens')...
# Fetching 0 pages for 'At1g69450' (species 'Mus musculus')...
# Fetching 0 pages for 'At1g69450' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'SULTR2' (species 'Homo sapiens')...
# Fetching 0 pages for 'SULTR2' (species 'Mus musculus')...
# Fetching 0 pages for 'SULTR2' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'PIP2-7' (species 'Homo sapiens')...
# Fetching 0 pages for 'PIP2-7' (species 'Mus musculus')...
# Fetching 0 pages for 'PIP2-7' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'LECRK41' (species 'Homo sapiens')...
# Fetching 0 pages for 'LECRK41' (species 'Mus musculus')...
# Fetching 0 pages for 'LECRK41' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Trpc6' (species 'Homo sapiens')...
# Fetching 1 pages for 'Trpc6' (species 'Mus musculus')...
# Fetching 0 pages for 'Trpc6' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'mom-5' (species 'Homo sapiens')...
# Fetching 0 pages for 'mom-5' (species 'Mus musculus')...
# Fetching 0 pages for 'mom-5' (species 'Rattus norvegicus')...
# Fetching 3 pages for 'Trpc3' (species 'Homo sapiens')...
# Fetching 2 pages for 'Trpc3' (species 'Mus musculus')...
# Fetching 0 pages for 'Trpc3' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'At1g74360' (species 'Homo sapiens')...
# Fetching 0 pages for 'At1g74360' (species 'Mus musculus')...
# Fetching 0 pages for 'At1g74360' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'glc-2' (species 'Homo sapiens')...
# Fetching 0 pages for 'glc-2' (species 'Mus musculus')...
# Fetching 0 pages for 'glc-2' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'At3g55390' (species 'Homo sapiens')...
# Fetching 0 pages for 'At3g55390' (species 'Mus musculus')...
# Fetching 0 pages for 'At3g55390' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'At3g28130' (species 'Homo sapiens')...
# Fetching 0 pages for 'At3g28130' (species 'Mus musculus')...
# Fetching 0 pages for 'At3g28130' (species 'Rattus norvegicus')...
# Fetching 3 pages for 'TRPC3' (species 'Homo sapiens')...
# Fetching 2 pages for 'TRPC3' (species 'Mus musculus')...
# Fetching 0 pages for 'TRPC3' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'gab-1' (species 'Homo sapiens')...
# Fetching 0 pages for 'gab-1' (species 'Mus musculus')...
# Fetching 0 pages for 'gab-1' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'At3g06390' (species 'Homo sapiens')...
# Fetching 0 pages for 'At3g06390' (species 'Mus musculus')...
# Fetching 0 pages for 'At3g06390' (species 'Rattus norvegicus')...
# Fetching 4 pages for 'RLP1' (species 'Homo sapiens')...
# Fetching 0 pages for 'RLP1' (species 'Mus musculus')...
# Fetching 0 pages for 'RLP1' (species 'Rattus norvegicus')...
# Fetching 24 pages for 'ZIP1' (species 'Homo sapiens')...
# Fetching 1 pages for 'ZIP1' (species 'Mus musculus')...
# Fetching 0 pages for 'ZIP1' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'TRPC7' (species 'Homo sapiens')...
# Fetching 1 pages for 'TRPC7' (species 'Mus musculus')...
# Fetching 0 pages for 'TRPC7' (species 'Rattus norvegicus')...
# Fetching 0 pages for 'AAP1' (species 'Homo sapiens')...
# Fetching 0 pages for 'AAP1' (species 'Mus musculus')...
# Fetching 0 pages for 'AAP1' (species 'Rattus norvegicus')...
# Fetching 6 pages for 'TRPC4' (species 'Homo sapiens')...
# Fetching 1 pages for 'TRPC4' (species 'Mus musculus')...
# Fetching 0 pages for 'TRPC4' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Trpc5' (species 'Homo sapiens')...
# Fetching 1 pages for 'Trpc5' (species 'Mus musculus')...
# Fetching 0 pages for 'Trpc5' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'TRPC5' (species 'Homo sapiens')...
# Fetching 1 pages for 'TRPC5' (species 'Mus musculus')...
# Fetching 0 pages for 'TRPC5' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'TRPM6' (species 'Homo sapiens')...
# Fetching 0 pages for 'TRPM6' (species 'Mus musculus')...
# Fetching 0 pages for 'TRPM6' (species 'Rattus norvegicus')...
# Fetching 6 pages for 'Trpc4' (species 'Homo sapiens')...
# Fetching 1 pages for 'Trpc4' (species 'Mus musculus')...
# Fetching 0 pages for 'Trpc4' (species 'Rattus norvegicus')...
# Fetching 3 pages for 'CD200R1' (species 'Homo sapiens')...
# Fetching 1 pages for 'CD200R1' (species 'Mus musculus')...
# Fetching 0 pages for 'CD200R1' (species 'Rattus norvegicus')...
# Fetching 1 pages for 'Trpc7' (species 'Homo sapiens')...
# Fetching 1 pages for 'Trpc7' (species 'Mus musculus')...
# Fetching 0 pages for 'Trpc7' (species 'Rattus norvegicus')...

# %%
len(intact_interactions)
# Out:
# 13611

# %%
import pickle
with open("../data/intact_interactions_all.pkl", "wb") as f:
    pickle.dump(intact_interactions, f)

# %%
interactions = pd.DataFrame(intact_interactions.values())

# %%
interactions.to_csv("../data/intact_interactions_all.csv", index=None)

# %%
membrane_prot_interactions = interactions[interactions.apply(
    lambda x: x.uniqueIdA in gene_df["uniprot_ac"].unique() and\
              x.uniqueIdB in gene_df["uniprot_ac"].unique(), axis=1)]

# %%
membrane_prot_interactions
# Out:
#                  ac  binaryInteractionId documentType                 idA  \
# 1221   EBI-21284925              3897665  interaction  P35368 (uniprotkb)
# 1222   EBI-21284945              3897697  interaction  P35368 (uniprotkb)
# 1223   EBI-21284190              3896522  interaction  P35368 (uniprotkb)
# 1226   EBI-21298877              3911670  interaction  P35368 (uniprotkb)
# 1227   EBI-21298893              3911704  interaction  P35368 (uniprotkb)
# 1228   EBI-21298937              3911718  interaction  P35368 (uniprotkb)
# 1229   EBI-21288674              3902699  interaction  P61073 (uniprotkb)
# 1235   EBI-21283831              3896239  interaction  P35368 (uniprotkb)
# 1236   EBI-21283912              3896359  interaction  P35368 (uniprotkb)
# 1238   EBI-21282722              3894894  interaction  P35368 (uniprotkb)
# 2779   EBI-15726884              2341657  interaction  P55064 (uniprotkb)
# 2780   EBI-15726900              2341662  interaction  P55064 (uniprotkb)
# 2836    EBI-7056427              9886084  interaction  P29317 (uniprotkb)
# 4088   EBI-21292905              3903812  interaction  P25106 (uniprotkb)
# 4089   EBI-21294813              3904570  interaction  P25106 (uniprotkb)
# 4090   EBI-21294836              3904586  interaction  P25106 (uniprotkb)
# 4092   EBI-21294855              3904609  interaction  P25106 (uniprotkb)
# 4093   EBI-21284955              3897705  interaction  P25106 (uniprotkb)
# 4094   EBI-21294090              3904208  interaction  P25106 (uniprotkb)
# 4098   EBI-21299245              3912097  interaction  P25106 (uniprotkb)
# 4099   EBI-21299400              3912190  interaction  P25106 (uniprotkb)
# 4100   EBI-21299409              3912199  interaction  P25106 (uniprotkb)
# 4101   EBI-21299416              3912214  interaction  P25106 (uniprotkb)
# 4102   EBI-21292896              3903796  interaction  P61073 (uniprotkb)
# 4103   EBI-21293192              3903927  interaction  P61073 (uniprotkb)
# 4104   EBI-21283866              3896289  interaction  P61073 (uniprotkb)
# 4105   EBI-21283903              3896337  interaction  P61073 (uniprotkb)
# 4143   EBI-21292885              3903761  interaction  P25106 (uniprotkb)
# 6291   EBI-16730213              3047943  interaction  O88704 (uniprotkb)
# 6393   EBI-21292877              3903744  interaction  P61073 (uniprotkb)
# 6394   EBI-21397066              4006098  interaction  P61073 (uniprotkb)
# 8370    EBI-8767175             11369002  interaction  O88704 (uniprotkb)
# 8371    EBI-8767181             11369014  interaction  O88704 (uniprotkb)
# 8372    EBI-8766345             11368130  interaction  O88704 (uniprotkb)
# 8373    EBI-8766423             11368238  interaction  O88704 (uniprotkb)
# 8469    EBI-8767202             11369026  interaction  Q9UL51 (uniprotkb)
# 8470    EBI-8766395             11368194  interaction  Q9UL51 (uniprotkb)
# 8471    EBI-8766427             11368251  interaction  Q9UL51 (uniprotkb)
# 8512   EBI-15641685              2257770  interaction  O88703 (uniprotkb)
# 10917  EBI-16007909              2628617  interaction  Q8R007 (uniprotkb)
#
#                       idB           acA           acB uniqueIdA uniqueIdB  \
# 1221   P61073 (uniprotkb)    EBI-490017    EBI-489411    P35368    P61073
# 1222   P61073 (uniprotkb)    EBI-490017    EBI-489411    P35368    P61073
# 1223   P61073 (uniprotkb)    EBI-490017    EBI-489411    P35368    P61073
# 1226   P61073 (uniprotkb)    EBI-490017    EBI-489411    P35368    P61073
# 1227   P61073 (uniprotkb)    EBI-490017    EBI-489411    P35368    P61073
# 1228   P61073 (uniprotkb)    EBI-490017    EBI-489411    P35368    P61073
# 1229   P35368 (uniprotkb)    EBI-489411    EBI-490017    P61073    P35368
# 1235   P25106 (uniprotkb)    EBI-490017   EBI-1965291    P35368    P25106
# 1236   P25106 (uniprotkb)    EBI-490017   EBI-1965291    P35368    P25106
# 1238   P35368 (uniprotkb)    EBI-490017    EBI-490017    P35368    P35368
# 2779   P55064 (uniprotkb)    EBI-746103    EBI-746103    P55064    P55064
# 2780   P55064 (uniprotkb)    EBI-746103    EBI-746103    P55064    P55064
# 2836   P29317 (uniprotkb)    EBI-702104    EBI-702104    P29317    P29317
# 4088   P61073 (uniprotkb)   EBI-1965291    EBI-489411    P25106    P61073
# 4089   P61073 (uniprotkb)   EBI-1965291    EBI-489411    P25106    P61073
# 4090   P61073 (uniprotkb)   EBI-1965291    EBI-489411    P25106    P61073
# 4092   P61073 (uniprotkb)   EBI-1965291    EBI-489411    P25106    P61073
# 4093   P61073 (uniprotkb)   EBI-1965291    EBI-489411    P25106    P61073
# 4094   P61073 (uniprotkb)   EBI-1965291    EBI-489411    P25106    P61073
# 4098   P61073 (uniprotkb)   EBI-1965291    EBI-489411    P25106    P61073
# 4099   P61073 (uniprotkb)   EBI-1965291    EBI-489411    P25106    P61073
# 4100   P61073 (uniprotkb)   EBI-1965291    EBI-489411    P25106    P61073
# 4101   P61073 (uniprotkb)   EBI-1965291    EBI-489411    P25106    P61073
# 4102   P25106 (uniprotkb)    EBI-489411   EBI-1965291    P61073    P25106
# 4103   P25106 (uniprotkb)    EBI-489411   EBI-1965291    P61073    P25106
# 4104   P25106 (uniprotkb)    EBI-489411   EBI-1965291    P61073    P25106
# 4105   P25106 (uniprotkb)    EBI-489411   EBI-1965291    P61073    P25106
# 4143   P25106 (uniprotkb)   EBI-1965291   EBI-1965291    P25106    P25106
# 6291   O88703 (uniprotkb)   EBI-8766347    EBI-771231    O88704    O88703
# 6393   P61073 (uniprotkb)    EBI-489411    EBI-489411    P61073    P61073
# 6394   P61073 (uniprotkb)    EBI-489411    EBI-489411    P61073    P61073
# 8370   O88704 (uniprotkb)   EBI-8766347   EBI-8766347    O88704    O88704
# 8371   O88704 (uniprotkb)   EBI-8766347   EBI-8766347    O88704    O88704
# 8372   O88704 (uniprotkb)   EBI-8766347   EBI-8766347    O88704    O88704
# 8373   O88704 (uniprotkb)   EBI-8766347   EBI-8766347    O88704    O88704
# 8469   Q9UL51 (uniprotkb)   EBI-1751885   EBI-1751885    Q9UL51    Q9UL51
# 8470   Q9UL51 (uniprotkb)   EBI-1751885   EBI-1751885    Q9UL51    Q9UL51
# 8471   Q9UL51 (uniprotkb)   EBI-1751885   EBI-1751885    Q9UL51    Q9UL51
# 8512   O88703 (uniprotkb)    EBI-771231    EBI-771231    O88703    O88703
# 10917  Q8R007 (uniprotkb)  EBI-16007862  EBI-16007862    Q8R007    Q8R007
#
#       moleculeA  ...    releaseDate              intraTaxIdStyled  \
# 1221     ADRA1B  ...  1563812513148   9606__Homo sapiens__#335e94
# 1222     ADRA1B  ...  1563812513148   9606__Homo sapiens__#335e94
# 1223     ADRA1B  ...  1557403194233   9606__Homo sapiens__#335e94
# 1226     ADRA1B  ...  1563812506845   9606__Homo sapiens__#335e94
# 1227     ADRA1B  ...  1563812506845   9606__Homo sapiens__#335e94
# 1228     ADRA1B  ...  1563812506845   9606__Homo sapiens__#335e94
# 1229      CXCR4  ...  1563812513148   9606__Homo sapiens__#335e94
# 1235     ADRA1B  ...  1557403194233   9606__Homo sapiens__#335e94
# 1236     ADRA1B  ...  1557403194233   9606__Homo sapiens__#335e94
# 1238     ADRA1B  ...  1563812513834   9606__Homo sapiens__#335e94
# 2779       AQP5  ...  1504185276737   9606__Homo sapiens__#335e94
# 2780       AQP5  ...  1504185276737   9606__Homo sapiens__#335e94
# 2836      EPHA2  ...  1378123967262   9606__Homo sapiens__#335e94
# 4088      ACKR3  ...  1557403193387   9606__Homo sapiens__#335e94
# 4089      ACKR3  ...  1563812499270   9606__Homo sapiens__#335e94
# 4090      ACKR3  ...  1563812499270   9606__Homo sapiens__#335e94
# 4092      ACKR3  ...  1563812499270   9606__Homo sapiens__#335e94
# 4093      ACKR3  ...  1563812513148   9606__Homo sapiens__#335e94
# 4094      ACKR3  ...  1557403196248   9606__Homo sapiens__#335e94
# 4098      ACKR3  ...  1563812499058   9606__Homo sapiens__#335e94
# 4099      ACKR3  ...  1563812499058   9606__Homo sapiens__#335e94
# 4100      ACKR3  ...  1563812499058   9606__Homo sapiens__#335e94
# 4101      ACKR3  ...  1563812499058   9606__Homo sapiens__#335e94
# 4102      CXCR4  ...  1557403193387   9606__Homo sapiens__#335e94
# 4103      CXCR4  ...  1557403196248   9606__Homo sapiens__#335e94
# 4104      CXCR4  ...  1557403194233   9606__Homo sapiens__#335e94
# 4105      CXCR4  ...  1557403194233   9606__Homo sapiens__#335e94
# 4143      ACKR3  ...  1557403193387   9606__Homo sapiens__#335e94
# 6291       Hcn1  ...  1518622060395  10090__Mus musculus__#31336e
# 6393      CXCR4  ...  1557403193387   9606__Homo sapiens__#335e94
# 6394      CXCR4  ...  1563812510278   9606__Homo sapiens__#335e94
# 8370       Hcn1  ...  1382975268603  10090__Mus musculus__#31336e
# 8371       Hcn1  ...  1382975268603  10090__Mus musculus__#31336e
# 8372       Hcn1  ...  1382975268603  10090__Mus musculus__#31336e
# 8373       Hcn1  ...  1382975268603  10090__Mus musculus__#31336e
# 8469       HCN2  ...  1382975268603   9606__Homo sapiens__#335e94
# 8470       HCN2  ...  1382975268603   9606__Homo sapiens__#335e94
# 8471       HCN2  ...  1382975268603   9606__Homo sapiens__#335e94
# 8512       Hcn2  ...  1504185414374  10090__Mus musculus__#31336e
# 10917   Nectin4  ...  1504185425924  10090__Mus musculus__#31336e
#
#                        taxIdAStyled                  taxIdBStyled  \
# 1221    9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 1222    9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 1223    9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 1226    9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 1227    9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 1228    9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 1229    9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 1235    9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 1236    9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 1238    9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 2779    9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 2780    9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 2836    9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 4088    9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 4089    9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 4090    9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 4092    9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 4093    9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 4094    9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 4098    9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 4099    9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 4100    9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 4101    9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 4102    9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 4103    9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 4104    9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 4105    9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 4143    9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 6291   10090__Mus musculus__#31336e  10090__Mus musculus__#31336e
# 6393    9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 6394    9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 8370   10090__Mus musculus__#31336e  10090__Mus musculus__#31336e
# 8371   10090__Mus musculus__#31336e  10090__Mus musculus__#31336e
# 8372   10090__Mus musculus__#31336e  10090__Mus musculus__#31336e
# 8373   10090__Mus musculus__#31336e  10090__Mus musculus__#31336e
# 8469    9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 8470    9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 8471    9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 8512   10090__Mus musculus__#31336e  10090__Mus musculus__#31336e
# 10917  10090__Mus musculus__#31336e  10090__Mus musculus__#31336e
#
#                        typeMIIdentifierStyled              typeMIAStyled  \
# 1221              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 1222              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 1223              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 1226              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 1227              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 1228              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 1229            MI:0914__association__#bae4bc  MI:0326__protein__ELLIPSE
# 1235              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 1236              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 1238   MI:0915__physical association__#7bccc4  MI:0326__protein__ELLIPSE
# 2779     MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
# 2780     MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
# 2836     MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
# 4088              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 4089   MI:0915__physical association__#7bccc4  MI:0326__protein__ELLIPSE
# 4090   MI:0915__physical association__#7bccc4  MI:0326__protein__ELLIPSE
# 4092         MI:0403__colocalization__#d8d8d8  MI:0326__protein__ELLIPSE
# 4093              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 4094              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 4098              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 4099              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 4100              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 4101              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 4102              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 4103              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 4104              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 4105              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 4143              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 6291            MI:0914__association__#bae4bc  MI:0326__protein__ELLIPSE
# 6393              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 6394              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 8370     MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
# 8371     MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
# 8372     MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
# 8373     MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
# 8469     MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
# 8470     MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
# 8471     MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
# 8512     MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
# 10917    MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
#
#                    typeMIBStyled  \
# 1221   MI:0326__protein__ELLIPSE
# 1222   MI:0326__protein__ELLIPSE
# 1223   MI:0326__protein__ELLIPSE
# 1226   MI:0326__protein__ELLIPSE
# 1227   MI:0326__protein__ELLIPSE
# 1228   MI:0326__protein__ELLIPSE
# 1229   MI:0326__protein__ELLIPSE
# 1235   MI:0326__protein__ELLIPSE
# 1236   MI:0326__protein__ELLIPSE
# 1238   MI:0326__protein__ELLIPSE
# 2779   MI:0326__protein__ELLIPSE
# 2780   MI:0326__protein__ELLIPSE
# 2836   MI:0326__protein__ELLIPSE
# 4088   MI:0326__protein__ELLIPSE
# 4089   MI:0326__protein__ELLIPSE
# 4090   MI:0326__protein__ELLIPSE
# 4092   MI:0326__protein__ELLIPSE
# 4093   MI:0326__protein__ELLIPSE
# 4094   MI:0326__protein__ELLIPSE
# 4098   MI:0326__protein__ELLIPSE
# 4099   MI:0326__protein__ELLIPSE
# 4100   MI:0326__protein__ELLIPSE
# 4101   MI:0326__protein__ELLIPSE
# 4102   MI:0326__protein__ELLIPSE
# 4103   MI:0326__protein__ELLIPSE
# 4104   MI:0326__protein__ELLIPSE
# 4105   MI:0326__protein__ELLIPSE
# 4143   MI:0326__protein__ELLIPSE
# 6291   MI:0326__protein__ELLIPSE
# 6393   MI:0326__protein__ELLIPSE
# 6394   MI:0326__protein__ELLIPSE
# 8370   MI:0326__protein__ELLIPSE
# 8371   MI:0326__protein__ELLIPSE
# 8372   MI:0326__protein__ELLIPSE
# 8373   MI:0326__protein__ELLIPSE
# 8469   MI:0326__protein__ELLIPSE
# 8470   MI:0326__protein__ELLIPSE
# 8471   MI:0326__protein__ELLIPSE
# 8512   MI:0326__protein__ELLIPSE
# 10917  MI:0326__protein__ELLIPSE
#
#                                  hostOrganismTaxIdStyled  \
# 1221                         9606__Homo sapiens__#335e94
# 1222                         9606__Homo sapiens__#335e94
# 1223                         9606__Homo sapiens__#335e94
# 1226   9606__Homo sapiens 293 cells transformed with ...
# 1227   9606__Homo sapiens 293 cells transformed with ...
# 1228                         9606__Homo sapiens__#335e94
# 1229                         9606__Homo sapiens__#335e94
# 1235   9606__Homo sapiens 293 cells transformed with ...
# 1236                         9606__Homo sapiens__#335e94
# 1238   9606__Homo sapiens transformed primary embryon...
# 2779              4922__Pichia pastoris (Yeast)__#eb9000
# 2780              4922__Pichia pastoris (Yeast)__#eb9000
# 2836                               -1__In vitro__#8d6666
# 4088   9606__Homo sapiens 293 cells transformed with ...
# 4089   9606__Homo sapiens transformed primary embryon...
# 4090   9606__Homo sapiens transformed primary embryon...
# 4092   10090__Mus musculus albino neuroblastoma cell ...
# 4093                         9606__Homo sapiens__#335e94
# 4094                         9606__Homo sapiens__#335e94
# 4098                         9606__Homo sapiens__#335e94
# 4099                         9606__Homo sapiens__#335e94
# 4100                         9606__Homo sapiens__#335e94
# 4101                         9606__Homo sapiens__#335e94
# 4102   9606__Homo sapiens 293 cells transformed with ...
# 4103                         9606__Homo sapiens__#335e94
# 4104   9606__Homo sapiens 293 cells transformed with ...
# 4105                         9606__Homo sapiens__#335e94
# 4143   9606__Homo sapiens 293 cells transformed with ...
# 6291           10090__Mus musculus brain cortex__#31336e
# 6393   9606__Homo sapiens 293 cells transformed with ...
# 6394   9606__Homo sapiens 293 cells transformed with ...
# 8370                               -1__In vitro__#8d6666
# 8371                               -1__In vitro__#8d6666
# 8372                               -1__In vitro__#8d6666
# 8373                               -1__In vitro__#8d6666
# 8469                               -1__In vitro__#8d6666
# 8470                               -1__In vitro__#8d6666
# 8471                               -1__In vitro__#8d6666
# 8512                      562__Escherichia coli__#9a373a
# 10917                        9606__Homo sapiens__#335e94
#
#       affectedByMutationStyled  searchChildInteractors
# 1221      none__false__#7e8389                    None
# 1222      none__false__#7e8389                    None
# 1223      none__false__#7e8389                    None
# 1226      none__false__#7e8389                    None
# 1227      none__false__#7e8389                    None
# 1228      none__false__#7e8389                    None
# 1229      none__false__#7e8389                    None
# 1235      none__false__#7e8389                    None
# 1236      none__false__#7e8389                    None
# 1238      none__false__#7e8389                    None
# 2779      none__false__#7e8389                    None
# 2780      none__false__#7e8389                    None
# 2836      none__false__#7e8389                    None
# 4088      none__false__#7e8389                    None
# 4089      none__false__#7e8389                    None
# 4090      none__false__#7e8389                    None
# 4092      none__false__#7e8389                    None
# 4093      none__false__#7e8389                    None
# 4094      none__false__#7e8389                    None
# 4098      none__false__#7e8389                    None
# 4099      none__false__#7e8389                    None
# 4100      none__false__#7e8389                    None
# 4101      none__false__#7e8389                    None
# 4102      none__false__#7e8389                    None
# 4103      none__false__#7e8389                    None
# 4104      none__false__#7e8389                    None
# 4105      none__false__#7e8389                    None
# 4143      none__false__#7e8389                    None
# 6291      none__false__#7e8389                    None
# 6393      none__false__#7e8389                    None
# 6394      none__false__#7e8389                    None
# 8370      none__false__#7e8389                    None
# 8371      none__false__#7e8389                    None
# 8372       none__true__#ff00a1                    None
# 8373      none__false__#7e8389                    None
# 8469      none__false__#7e8389                    None
# 8470      none__false__#7e8389                    None
# 8471      none__false__#7e8389                    None
# 8512      none__false__#7e8389                    None
# 10917     none__false__#7e8389                    None
#
# [40 rows x 99 columns]

# %%
df = membrane_prot_interactions.merge(
    gene_nodes.reset_index()[["name", "uniprot_ac"]].rename(
        columns={"uniprot_ac": "uniqueIdA"}),
    on="uniqueIdA", how="left").rename(columns={"name": "nameA"}).merge(
        gene_nodes.reset_index()[["name", "uniprot_ac"]].rename(
         columns={"uniprot_ac": "uniqueIdB"}),
        on="uniqueIdB").rename(columns={"name": "nameB"})

# %%
df
# Out:
#               ac  binaryInteractionId documentType                 idA  \
# 0   EBI-21284925              3897665  interaction  P35368 (uniprotkb)
# 1   EBI-21284945              3897697  interaction  P35368 (uniprotkb)
# 2   EBI-21284190              3896522  interaction  P35368 (uniprotkb)
# 3   EBI-21298877              3911670  interaction  P35368 (uniprotkb)
# 4   EBI-21298893              3911704  interaction  P35368 (uniprotkb)
# 5   EBI-21298937              3911718  interaction  P35368 (uniprotkb)
# 6   EBI-21292905              3903812  interaction  P25106 (uniprotkb)
# 7   EBI-21294813              3904570  interaction  P25106 (uniprotkb)
# 8   EBI-21294836              3904586  interaction  P25106 (uniprotkb)
# 9   EBI-21294855              3904609  interaction  P25106 (uniprotkb)
# 10  EBI-21284955              3897705  interaction  P25106 (uniprotkb)
# 11  EBI-21294090              3904208  interaction  P25106 (uniprotkb)
# 12  EBI-21299245              3912097  interaction  P25106 (uniprotkb)
# 13  EBI-21299400              3912190  interaction  P25106 (uniprotkb)
# 14  EBI-21299409              3912199  interaction  P25106 (uniprotkb)
# 15  EBI-21299416              3912214  interaction  P25106 (uniprotkb)
# 16  EBI-21292877              3903744  interaction  P61073 (uniprotkb)
# 17  EBI-21397066              4006098  interaction  P61073 (uniprotkb)
# 18  EBI-21288674              3902699  interaction  P61073 (uniprotkb)
# 19  EBI-21282722              3894894  interaction  P35368 (uniprotkb)
# 20  EBI-21283831              3896239  interaction  P35368 (uniprotkb)
# 21  EBI-21283912              3896359  interaction  P35368 (uniprotkb)
# 22  EBI-21292896              3903796  interaction  P61073 (uniprotkb)
# 23  EBI-21293192              3903927  interaction  P61073 (uniprotkb)
# 24  EBI-21283866              3896289  interaction  P61073 (uniprotkb)
# 25  EBI-21283903              3896337  interaction  P61073 (uniprotkb)
# 26  EBI-21292885              3903761  interaction  P25106 (uniprotkb)
# 27  EBI-15726884              2341657  interaction  P55064 (uniprotkb)
# 28  EBI-15726900              2341662  interaction  P55064 (uniprotkb)
# 29   EBI-7056427              9886084  interaction  P29317 (uniprotkb)
# 30  EBI-16730213              3047943  interaction  O88704 (uniprotkb)
# 31  EBI-15641685              2257770  interaction  O88703 (uniprotkb)
# 32   EBI-8767175             11369002  interaction  O88704 (uniprotkb)
# 33   EBI-8767181             11369014  interaction  O88704 (uniprotkb)
# 34   EBI-8766345             11368130  interaction  O88704 (uniprotkb)
# 35   EBI-8766423             11368238  interaction  O88704 (uniprotkb)
# 36   EBI-8767202             11369026  interaction  Q9UL51 (uniprotkb)
# 37   EBI-8766395             11368194  interaction  Q9UL51 (uniprotkb)
# 38   EBI-8766427             11368251  interaction  Q9UL51 (uniprotkb)
# 39  EBI-16007909              2628617  interaction  Q8R007 (uniprotkb)
#
#                    idB           acA           acB uniqueIdA uniqueIdB  \
# 0   P61073 (uniprotkb)    EBI-490017    EBI-489411    P35368    P61073
# 1   P61073 (uniprotkb)    EBI-490017    EBI-489411    P35368    P61073
# 2   P61073 (uniprotkb)    EBI-490017    EBI-489411    P35368    P61073
# 3   P61073 (uniprotkb)    EBI-490017    EBI-489411    P35368    P61073
# 4   P61073 (uniprotkb)    EBI-490017    EBI-489411    P35368    P61073
# 5   P61073 (uniprotkb)    EBI-490017    EBI-489411    P35368    P61073
# 6   P61073 (uniprotkb)   EBI-1965291    EBI-489411    P25106    P61073
# 7   P61073 (uniprotkb)   EBI-1965291    EBI-489411    P25106    P61073
# 8   P61073 (uniprotkb)   EBI-1965291    EBI-489411    P25106    P61073
# 9   P61073 (uniprotkb)   EBI-1965291    EBI-489411    P25106    P61073
# 10  P61073 (uniprotkb)   EBI-1965291    EBI-489411    P25106    P61073
# 11  P61073 (uniprotkb)   EBI-1965291    EBI-489411    P25106    P61073
# 12  P61073 (uniprotkb)   EBI-1965291    EBI-489411    P25106    P61073
# 13  P61073 (uniprotkb)   EBI-1965291    EBI-489411    P25106    P61073
# 14  P61073 (uniprotkb)   EBI-1965291    EBI-489411    P25106    P61073
# 15  P61073 (uniprotkb)   EBI-1965291    EBI-489411    P25106    P61073
# 16  P61073 (uniprotkb)    EBI-489411    EBI-489411    P61073    P61073
# 17  P61073 (uniprotkb)    EBI-489411    EBI-489411    P61073    P61073
# 18  P35368 (uniprotkb)    EBI-489411    EBI-490017    P61073    P35368
# 19  P35368 (uniprotkb)    EBI-490017    EBI-490017    P35368    P35368
# 20  P25106 (uniprotkb)    EBI-490017   EBI-1965291    P35368    P25106
# 21  P25106 (uniprotkb)    EBI-490017   EBI-1965291    P35368    P25106
# 22  P25106 (uniprotkb)    EBI-489411   EBI-1965291    P61073    P25106
# 23  P25106 (uniprotkb)    EBI-489411   EBI-1965291    P61073    P25106
# 24  P25106 (uniprotkb)    EBI-489411   EBI-1965291    P61073    P25106
# 25  P25106 (uniprotkb)    EBI-489411   EBI-1965291    P61073    P25106
# 26  P25106 (uniprotkb)   EBI-1965291   EBI-1965291    P25106    P25106
# 27  P55064 (uniprotkb)    EBI-746103    EBI-746103    P55064    P55064
# 28  P55064 (uniprotkb)    EBI-746103    EBI-746103    P55064    P55064
# 29  P29317 (uniprotkb)    EBI-702104    EBI-702104    P29317    P29317
# 30  O88703 (uniprotkb)   EBI-8766347    EBI-771231    O88704    O88703
# 31  O88703 (uniprotkb)    EBI-771231    EBI-771231    O88703    O88703
# 32  O88704 (uniprotkb)   EBI-8766347   EBI-8766347    O88704    O88704
# 33  O88704 (uniprotkb)   EBI-8766347   EBI-8766347    O88704    O88704
# 34  O88704 (uniprotkb)   EBI-8766347   EBI-8766347    O88704    O88704
# 35  O88704 (uniprotkb)   EBI-8766347   EBI-8766347    O88704    O88704
# 36  Q9UL51 (uniprotkb)   EBI-1751885   EBI-1751885    Q9UL51    Q9UL51
# 37  Q9UL51 (uniprotkb)   EBI-1751885   EBI-1751885    Q9UL51    Q9UL51
# 38  Q9UL51 (uniprotkb)   EBI-1751885   EBI-1751885    Q9UL51    Q9UL51
# 39  Q8R007 (uniprotkb)  EBI-16007862  EBI-16007862    Q8R007    Q8R007
#
#    moleculeA  ...                  taxIdAStyled                  taxIdBStyled  \
# 0     ADRA1B  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 1     ADRA1B  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 2     ADRA1B  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 3     ADRA1B  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 4     ADRA1B  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 5     ADRA1B  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 6      ACKR3  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 7      ACKR3  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 8      ACKR3  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 9      ACKR3  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 10     ACKR3  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 11     ACKR3  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 12     ACKR3  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 13     ACKR3  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 14     ACKR3  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 15     ACKR3  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 16     CXCR4  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 17     CXCR4  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 18     CXCR4  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 19    ADRA1B  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 20    ADRA1B  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 21    ADRA1B  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 22     CXCR4  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 23     CXCR4  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 24     CXCR4  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 25     CXCR4  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 26     ACKR3  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 27      AQP5  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 28      AQP5  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 29     EPHA2  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 30      Hcn1  ...  10090__Mus musculus__#31336e  10090__Mus musculus__#31336e
# 31      Hcn2  ...  10090__Mus musculus__#31336e  10090__Mus musculus__#31336e
# 32      Hcn1  ...  10090__Mus musculus__#31336e  10090__Mus musculus__#31336e
# 33      Hcn1  ...  10090__Mus musculus__#31336e  10090__Mus musculus__#31336e
# 34      Hcn1  ...  10090__Mus musculus__#31336e  10090__Mus musculus__#31336e
# 35      Hcn1  ...  10090__Mus musculus__#31336e  10090__Mus musculus__#31336e
# 36      HCN2  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 37      HCN2  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 38      HCN2  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 39   Nectin4  ...  10090__Mus musculus__#31336e  10090__Mus musculus__#31336e
#
#                     typeMIIdentifierStyled              typeMIAStyled  \
# 0              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 1              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 2              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 3              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 4              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 5              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 6              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 7   MI:0915__physical association__#7bccc4  MI:0326__protein__ELLIPSE
# 8   MI:0915__physical association__#7bccc4  MI:0326__protein__ELLIPSE
# 9         MI:0403__colocalization__#d8d8d8  MI:0326__protein__ELLIPSE
# 10             MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 11             MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 12             MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 13             MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 14             MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 15             MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 16             MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 17             MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 18           MI:0914__association__#bae4bc  MI:0326__protein__ELLIPSE
# 19  MI:0915__physical association__#7bccc4  MI:0326__protein__ELLIPSE
# 20             MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 21             MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 22             MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 23             MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 24             MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 25             MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 26             MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 27    MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
# 28    MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
# 29    MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
# 30           MI:0914__association__#bae4bc  MI:0326__protein__ELLIPSE
# 31    MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
# 32    MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
# 33    MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
# 34    MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
# 35    MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
# 36    MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
# 37    MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
# 38    MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
# 39    MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
#
#                 typeMIBStyled  \
# 0   MI:0326__protein__ELLIPSE
# 1   MI:0326__protein__ELLIPSE
# 2   MI:0326__protein__ELLIPSE
# 3   MI:0326__protein__ELLIPSE
# 4   MI:0326__protein__ELLIPSE
# 5   MI:0326__protein__ELLIPSE
# 6   MI:0326__protein__ELLIPSE
# 7   MI:0326__protein__ELLIPSE
# 8   MI:0326__protein__ELLIPSE
# 9   MI:0326__protein__ELLIPSE
# 10  MI:0326__protein__ELLIPSE
# 11  MI:0326__protein__ELLIPSE
# 12  MI:0326__protein__ELLIPSE
# 13  MI:0326__protein__ELLIPSE
# 14  MI:0326__protein__ELLIPSE
# 15  MI:0326__protein__ELLIPSE
# 16  MI:0326__protein__ELLIPSE
# 17  MI:0326__protein__ELLIPSE
# 18  MI:0326__protein__ELLIPSE
# 19  MI:0326__protein__ELLIPSE
# 20  MI:0326__protein__ELLIPSE
# 21  MI:0326__protein__ELLIPSE
# 22  MI:0326__protein__ELLIPSE
# 23  MI:0326__protein__ELLIPSE
# 24  MI:0326__protein__ELLIPSE
# 25  MI:0326__protein__ELLIPSE
# 26  MI:0326__protein__ELLIPSE
# 27  MI:0326__protein__ELLIPSE
# 28  MI:0326__protein__ELLIPSE
# 29  MI:0326__protein__ELLIPSE
# 30  MI:0326__protein__ELLIPSE
# 31  MI:0326__protein__ELLIPSE
# 32  MI:0326__protein__ELLIPSE
# 33  MI:0326__protein__ELLIPSE
# 34  MI:0326__protein__ELLIPSE
# 35  MI:0326__protein__ELLIPSE
# 36  MI:0326__protein__ELLIPSE
# 37  MI:0326__protein__ELLIPSE
# 38  MI:0326__protein__ELLIPSE
# 39  MI:0326__protein__ELLIPSE
#
#                               hostOrganismTaxIdStyled  \
# 0                         9606__Homo sapiens__#335e94
# 1                         9606__Homo sapiens__#335e94
# 2                         9606__Homo sapiens__#335e94
# 3   9606__Homo sapiens 293 cells transformed with ...
# 4   9606__Homo sapiens 293 cells transformed with ...
# 5                         9606__Homo sapiens__#335e94
# 6   9606__Homo sapiens 293 cells transformed with ...
# 7   9606__Homo sapiens transformed primary embryon...
# 8   9606__Homo sapiens transformed primary embryon...
# 9   10090__Mus musculus albino neuroblastoma cell ...
# 10                        9606__Homo sapiens__#335e94
# 11                        9606__Homo sapiens__#335e94
# 12                        9606__Homo sapiens__#335e94
# 13                        9606__Homo sapiens__#335e94
# 14                        9606__Homo sapiens__#335e94
# 15                        9606__Homo sapiens__#335e94
# 16  9606__Homo sapiens 293 cells transformed with ...
# 17  9606__Homo sapiens 293 cells transformed with ...
# 18                        9606__Homo sapiens__#335e94
# 19  9606__Homo sapiens transformed primary embryon...
# 20  9606__Homo sapiens 293 cells transformed with ...
# 21                        9606__Homo sapiens__#335e94
# 22  9606__Homo sapiens 293 cells transformed with ...
# 23                        9606__Homo sapiens__#335e94
# 24  9606__Homo sapiens 293 cells transformed with ...
# 25                        9606__Homo sapiens__#335e94
# 26  9606__Homo sapiens 293 cells transformed with ...
# 27             4922__Pichia pastoris (Yeast)__#eb9000
# 28             4922__Pichia pastoris (Yeast)__#eb9000
# 29                              -1__In vitro__#8d6666
# 30          10090__Mus musculus brain cortex__#31336e
# 31                     562__Escherichia coli__#9a373a
# 32                              -1__In vitro__#8d6666
# 33                              -1__In vitro__#8d6666
# 34                              -1__In vitro__#8d6666
# 35                              -1__In vitro__#8d6666
# 36                              -1__In vitro__#8d6666
# 37                              -1__In vitro__#8d6666
# 38                              -1__In vitro__#8d6666
# 39                        9606__Homo sapiens__#335e94
#
#    affectedByMutationStyled searchChildInteractors    nameA    nameB
# 0      none__false__#7e8389                   None   ADRA1B    CXCR4
# 1      none__false__#7e8389                   None   ADRA1B    CXCR4
# 2      none__false__#7e8389                   None   ADRA1B    CXCR4
# 3      none__false__#7e8389                   None   ADRA1B    CXCR4
# 4      none__false__#7e8389                   None   ADRA1B    CXCR4
# 5      none__false__#7e8389                   None   ADRA1B    CXCR4
# 6      none__false__#7e8389                   None    ACKR3    CXCR4
# 7      none__false__#7e8389                   None    ACKR3    CXCR4
# 8      none__false__#7e8389                   None    ACKR3    CXCR4
# 9      none__false__#7e8389                   None    ACKR3    CXCR4
# 10     none__false__#7e8389                   None    ACKR3    CXCR4
# 11     none__false__#7e8389                   None    ACKR3    CXCR4
# 12     none__false__#7e8389                   None    ACKR3    CXCR4
# 13     none__false__#7e8389                   None    ACKR3    CXCR4
# 14     none__false__#7e8389                   None    ACKR3    CXCR4
# 15     none__false__#7e8389                   None    ACKR3    CXCR4
# 16     none__false__#7e8389                   None    CXCR4    CXCR4
# 17     none__false__#7e8389                   None    CXCR4    CXCR4
# 18     none__false__#7e8389                   None    CXCR4   ADRA1B
# 19     none__false__#7e8389                   None   ADRA1B   ADRA1B
# 20     none__false__#7e8389                   None   ADRA1B    ACKR3
# 21     none__false__#7e8389                   None   ADRA1B    ACKR3
# 22     none__false__#7e8389                   None    CXCR4    ACKR3
# 23     none__false__#7e8389                   None    CXCR4    ACKR3
# 24     none__false__#7e8389                   None    CXCR4    ACKR3
# 25     none__false__#7e8389                   None    CXCR4    ACKR3
# 26     none__false__#7e8389                   None    ACKR3    ACKR3
# 27     none__false__#7e8389                   None     AQP5     AQP5
# 28     none__false__#7e8389                   None     AQP5     AQP5
# 29     none__false__#7e8389                   None    EPHA2    EPHA2
# 30     none__false__#7e8389                   None     Hcn1     Hcn2
# 31     none__false__#7e8389                   None     Hcn2     Hcn2
# 32     none__false__#7e8389                   None     Hcn1     Hcn1
# 33     none__false__#7e8389                   None     Hcn1     Hcn1
# 34      none__true__#ff00a1                   None     Hcn1     Hcn1
# 35     none__false__#7e8389                   None     Hcn1     Hcn1
# 36     none__false__#7e8389                   None     HCN2     HCN2
# 37     none__false__#7e8389                   None     HCN2     HCN2
# 38     none__false__#7e8389                   None     HCN2     HCN2
# 39     none__false__#7e8389                   None  Nectin4  Nectin4
#
# [40 rows x 101 columns]

# %%
df.to_csv("../data/intact_membrate_ppi.csv", index=None)

# %%
import itables
import pandas as pd

# %%
from itables import init_notebook_mode
init_notebook_mode(all_interactive=True)

# %%
intact_df = pd.read_csv("../data/intact_membrate_ppi.csv")

# %%
interactions_df["pA"] = interactions_df["participant"].apply(
    lambda x: x[0]["protein"]["id"])
interactions_df["pB"] = interactions_df["participant"].apply(
    lambda x: x[1]["protein"]["id"])

# %%
df = interactions_df[["pA", "pB"]].merge(
    protein_df.rename(columns={"id": "pA"}),
    on="pA",
    how="left").merge(
        protein_df.rename(columns={"id": "pB"}),
        on="pB",
        how="left"
    )

# %%
existing = [list(el) for el in intact_df[["uniqueIdA", "uniqueIdB"]].values]

# %%
for k, v in df[["identifier_x", "identifier_y"]].values:
    if (k, v) in existing:
        print(k, v)
    if (v, k) in existing:
        print(v, k)

# %%
intact_df
# Out:
# WARNING:itables.downsample:showing 40x20 of 40x101 as maxColumns=20. See https://mwouts.github.io/itables/#downsampling
#               ac  binaryInteractionId documentType                 idA  \
# 0   EBI-21284925              3897665  interaction  P35368 (uniprotkb)
# 1   EBI-21284945              3897697  interaction  P35368 (uniprotkb)
# 2   EBI-21284190              3896522  interaction  P35368 (uniprotkb)
# 3   EBI-21298877              3911670  interaction  P35368 (uniprotkb)
# 4   EBI-21298893              3911704  interaction  P35368 (uniprotkb)
# 5   EBI-21298937              3911718  interaction  P35368 (uniprotkb)
# 6   EBI-21292905              3903812  interaction  P25106 (uniprotkb)
# 7   EBI-21294813              3904570  interaction  P25106 (uniprotkb)
# 8   EBI-21294836              3904586  interaction  P25106 (uniprotkb)
# 9   EBI-21294855              3904609  interaction  P25106 (uniprotkb)
# 10  EBI-21284955              3897705  interaction  P25106 (uniprotkb)
# 11  EBI-21294090              3904208  interaction  P25106 (uniprotkb)
# 12  EBI-21299245              3912097  interaction  P25106 (uniprotkb)
# 13  EBI-21299400              3912190  interaction  P25106 (uniprotkb)
# 14  EBI-21299409              3912199  interaction  P25106 (uniprotkb)
# 15  EBI-21299416              3912214  interaction  P25106 (uniprotkb)
# 16  EBI-21292877              3903744  interaction  P61073 (uniprotkb)
# 17  EBI-21397066              4006098  interaction  P61073 (uniprotkb)
# 18  EBI-21288674              3902699  interaction  P61073 (uniprotkb)
# 19  EBI-21282722              3894894  interaction  P35368 (uniprotkb)
# 20  EBI-21283831              3896239  interaction  P35368 (uniprotkb)
# 21  EBI-21283912              3896359  interaction  P35368 (uniprotkb)
# 22  EBI-21292896              3903796  interaction  P61073 (uniprotkb)
# 23  EBI-21293192              3903927  interaction  P61073 (uniprotkb)
# 24  EBI-21283866              3896289  interaction  P61073 (uniprotkb)
# 25  EBI-21283903              3896337  interaction  P61073 (uniprotkb)
# 26  EBI-21292885              3903761  interaction  P25106 (uniprotkb)
# 27  EBI-15726884              2341657  interaction  P55064 (uniprotkb)
# 28  EBI-15726900              2341662  interaction  P55064 (uniprotkb)
# 29   EBI-7056427              9886084  interaction  P29317 (uniprotkb)
# 30  EBI-16730213              3047943  interaction  O88704 (uniprotkb)
# 31  EBI-15641685              2257770  interaction  O88703 (uniprotkb)
# 32   EBI-8767175             11369002  interaction  O88704 (uniprotkb)
# 33   EBI-8767181             11369014  interaction  O88704 (uniprotkb)
# 34   EBI-8766345             11368130  interaction  O88704 (uniprotkb)
# 35   EBI-8766423             11368238  interaction  O88704 (uniprotkb)
# 36   EBI-8767202             11369026  interaction  Q9UL51 (uniprotkb)
# 37   EBI-8766395             11368194  interaction  Q9UL51 (uniprotkb)
# 38   EBI-8766427             11368251  interaction  Q9UL51 (uniprotkb)
# 39  EBI-16007909              2628617  interaction  Q8R007 (uniprotkb)
#
#                    idB           acA           acB uniqueIdA uniqueIdB  \
# 0   P61073 (uniprotkb)    EBI-490017    EBI-489411    P35368    P61073
# 1   P61073 (uniprotkb)    EBI-490017    EBI-489411    P35368    P61073
# 2   P61073 (uniprotkb)    EBI-490017    EBI-489411    P35368    P61073
# 3   P61073 (uniprotkb)    EBI-490017    EBI-489411    P35368    P61073
# 4   P61073 (uniprotkb)    EBI-490017    EBI-489411    P35368    P61073
# 5   P61073 (uniprotkb)    EBI-490017    EBI-489411    P35368    P61073
# 6   P61073 (uniprotkb)   EBI-1965291    EBI-489411    P25106    P61073
# 7   P61073 (uniprotkb)   EBI-1965291    EBI-489411    P25106    P61073
# 8   P61073 (uniprotkb)   EBI-1965291    EBI-489411    P25106    P61073
# 9   P61073 (uniprotkb)   EBI-1965291    EBI-489411    P25106    P61073
# 10  P61073 (uniprotkb)   EBI-1965291    EBI-489411    P25106    P61073
# 11  P61073 (uniprotkb)   EBI-1965291    EBI-489411    P25106    P61073
# 12  P61073 (uniprotkb)   EBI-1965291    EBI-489411    P25106    P61073
# 13  P61073 (uniprotkb)   EBI-1965291    EBI-489411    P25106    P61073
# 14  P61073 (uniprotkb)   EBI-1965291    EBI-489411    P25106    P61073
# 15  P61073 (uniprotkb)   EBI-1965291    EBI-489411    P25106    P61073
# 16  P61073 (uniprotkb)    EBI-489411    EBI-489411    P61073    P61073
# 17  P61073 (uniprotkb)    EBI-489411    EBI-489411    P61073    P61073
# 18  P35368 (uniprotkb)    EBI-489411    EBI-490017    P61073    P35368
# 19  P35368 (uniprotkb)    EBI-490017    EBI-490017    P35368    P35368
# 20  P25106 (uniprotkb)    EBI-490017   EBI-1965291    P35368    P25106
# 21  P25106 (uniprotkb)    EBI-490017   EBI-1965291    P35368    P25106
# 22  P25106 (uniprotkb)    EBI-489411   EBI-1965291    P61073    P25106
# 23  P25106 (uniprotkb)    EBI-489411   EBI-1965291    P61073    P25106
# 24  P25106 (uniprotkb)    EBI-489411   EBI-1965291    P61073    P25106
# 25  P25106 (uniprotkb)    EBI-489411   EBI-1965291    P61073    P25106
# 26  P25106 (uniprotkb)   EBI-1965291   EBI-1965291    P25106    P25106
# 27  P55064 (uniprotkb)    EBI-746103    EBI-746103    P55064    P55064
# 28  P55064 (uniprotkb)    EBI-746103    EBI-746103    P55064    P55064
# 29  P29317 (uniprotkb)    EBI-702104    EBI-702104    P29317    P29317
# 30  O88703 (uniprotkb)   EBI-8766347    EBI-771231    O88704    O88703
# 31  O88703 (uniprotkb)    EBI-771231    EBI-771231    O88703    O88703
# 32  O88704 (uniprotkb)   EBI-8766347   EBI-8766347    O88704    O88704
# 33  O88704 (uniprotkb)   EBI-8766347   EBI-8766347    O88704    O88704
# 34  O88704 (uniprotkb)   EBI-8766347   EBI-8766347    O88704    O88704
# 35  O88704 (uniprotkb)   EBI-8766347   EBI-8766347    O88704    O88704
# 36  Q9UL51 (uniprotkb)   EBI-1751885   EBI-1751885    Q9UL51    Q9UL51
# 37  Q9UL51 (uniprotkb)   EBI-1751885   EBI-1751885    Q9UL51    Q9UL51
# 38  Q9UL51 (uniprotkb)   EBI-1751885   EBI-1751885    Q9UL51    Q9UL51
# 39  Q8R007 (uniprotkb)  EBI-16007862  EBI-16007862    Q8R007    Q8R007
#
#    moleculeA  ...                  taxIdAStyled                  taxIdBStyled  \
# 0     ADRA1B  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 1     ADRA1B  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 2     ADRA1B  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 3     ADRA1B  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 4     ADRA1B  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 5     ADRA1B  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 6      ACKR3  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 7      ACKR3  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 8      ACKR3  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 9      ACKR3  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 10     ACKR3  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 11     ACKR3  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 12     ACKR3  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 13     ACKR3  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 14     ACKR3  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 15     ACKR3  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 16     CXCR4  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 17     CXCR4  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 18     CXCR4  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 19    ADRA1B  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 20    ADRA1B  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 21    ADRA1B  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 22     CXCR4  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 23     CXCR4  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 24     CXCR4  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 25     CXCR4  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 26     ACKR3  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 27      AQP5  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 28      AQP5  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 29     EPHA2  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 30      Hcn1  ...  10090__Mus musculus__#31336e  10090__Mus musculus__#31336e
# 31      Hcn2  ...  10090__Mus musculus__#31336e  10090__Mus musculus__#31336e
# 32      Hcn1  ...  10090__Mus musculus__#31336e  10090__Mus musculus__#31336e
# 33      Hcn1  ...  10090__Mus musculus__#31336e  10090__Mus musculus__#31336e
# 34      Hcn1  ...  10090__Mus musculus__#31336e  10090__Mus musculus__#31336e
# 35      Hcn1  ...  10090__Mus musculus__#31336e  10090__Mus musculus__#31336e
# 36      HCN2  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 37      HCN2  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 38      HCN2  ...   9606__Homo sapiens__#335e94   9606__Homo sapiens__#335e94
# 39   Nectin4  ...  10090__Mus musculus__#31336e  10090__Mus musculus__#31336e
#
#                     typeMIIdentifierStyled              typeMIAStyled  \
# 0              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 1              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 2              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 3              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 4              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 5              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 6              MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 7   MI:0915__physical association__#7bccc4  MI:0326__protein__ELLIPSE
# 8   MI:0915__physical association__#7bccc4  MI:0326__protein__ELLIPSE
# 9         MI:0403__colocalization__#d8d8d8  MI:0326__protein__ELLIPSE
# 10             MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 11             MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 12             MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 13             MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 14             MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 15             MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 16             MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 17             MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 18           MI:0914__association__#bae4bc  MI:0326__protein__ELLIPSE
# 19  MI:0915__physical association__#7bccc4  MI:0326__protein__ELLIPSE
# 20             MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 21             MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 22             MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 23             MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 24             MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 25             MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 26             MI:2364__proximity__#bae4bc  MI:0326__protein__ELLIPSE
# 27    MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
# 28    MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
# 29    MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
# 30           MI:0914__association__#bae4bc  MI:0326__protein__ELLIPSE
# 31    MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
# 32    MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
# 33    MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
# 34    MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
# 35    MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
# 36    MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
# 37    MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
# 38    MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
# 39    MI:0407__direct interaction__#43a2ca  MI:0326__protein__ELLIPSE
#
#                 typeMIBStyled  \
# 0   MI:0326__protein__ELLIPSE
# 1   MI:0326__protein__ELLIPSE
# 2   MI:0326__protein__ELLIPSE
# 3   MI:0326__protein__ELLIPSE
# 4   MI:0326__protein__ELLIPSE
# 5   MI:0326__protein__ELLIPSE
# 6   MI:0326__protein__ELLIPSE
# 7   MI:0326__protein__ELLIPSE
# 8   MI:0326__protein__ELLIPSE
# 9   MI:0326__protein__ELLIPSE
# 10  MI:0326__protein__ELLIPSE
# 11  MI:0326__protein__ELLIPSE
# 12  MI:0326__protein__ELLIPSE
# 13  MI:0326__protein__ELLIPSE
# 14  MI:0326__protein__ELLIPSE
# 15  MI:0326__protein__ELLIPSE
# 16  MI:0326__protein__ELLIPSE
# 17  MI:0326__protein__ELLIPSE
# 18  MI:0326__protein__ELLIPSE
# 19  MI:0326__protein__ELLIPSE
# 20  MI:0326__protein__ELLIPSE
# 21  MI:0326__protein__ELLIPSE
# 22  MI:0326__protein__ELLIPSE
# 23  MI:0326__protein__ELLIPSE
# 24  MI:0326__protein__ELLIPSE
# 25  MI:0326__protein__ELLIPSE
# 26  MI:0326__protein__ELLIPSE
# 27  MI:0326__protein__ELLIPSE
# 28  MI:0326__protein__ELLIPSE
# 29  MI:0326__protein__ELLIPSE
# 30  MI:0326__protein__ELLIPSE
# 31  MI:0326__protein__ELLIPSE
# 32  MI:0326__protein__ELLIPSE
# 33  MI:0326__protein__ELLIPSE
# 34  MI:0326__protein__ELLIPSE
# 35  MI:0326__protein__ELLIPSE
# 36  MI:0326__protein__ELLIPSE
# 37  MI:0326__protein__ELLIPSE
# 38  MI:0326__protein__ELLIPSE
# 39  MI:0326__protein__ELLIPSE
#
#                               hostOrganismTaxIdStyled  \
# 0                         9606__Homo sapiens__#335e94
# 1                         9606__Homo sapiens__#335e94
# 2                         9606__Homo sapiens__#335e94
# 3   9606__Homo sapiens 293 cells transformed with ...
# 4   9606__Homo sapiens 293 cells transformed with ...
# 5                         9606__Homo sapiens__#335e94
# 6   9606__Homo sapiens 293 cells transformed with ...
# 7   9606__Homo sapiens transformed primary embryon...
# 8   9606__Homo sapiens transformed primary embryon...
# 9   10090__Mus musculus albino neuroblastoma cell ...
# 10                        9606__Homo sapiens__#335e94
# 11                        9606__Homo sapiens__#335e94
# 12                        9606__Homo sapiens__#335e94
# 13                        9606__Homo sapiens__#335e94
# 14                        9606__Homo sapiens__#335e94
# 15                        9606__Homo sapiens__#335e94
# 16  9606__Homo sapiens 293 cells transformed with ...
# 17  9606__Homo sapiens 293 cells transformed with ...
# 18                        9606__Homo sapiens__#335e94
# 19  9606__Homo sapiens transformed primary embryon...
# 20  9606__Homo sapiens 293 cells transformed with ...
# 21                        9606__Homo sapiens__#335e94
# 22  9606__Homo sapiens 293 cells transformed with ...
# 23                        9606__Homo sapiens__#335e94
# 24  9606__Homo sapiens 293 cells transformed with ...
# 25                        9606__Homo sapiens__#335e94
# 26  9606__Homo sapiens 293 cells transformed with ...
# 27             4922__Pichia pastoris (Yeast)__#eb9000
# 28             4922__Pichia pastoris (Yeast)__#eb9000
# 29                              -1__In vitro__#8d6666
# 30          10090__Mus musculus brain cortex__#31336e
# 31                     562__Escherichia coli__#9a373a
# 32                              -1__In vitro__#8d6666
# 33                              -1__In vitro__#8d6666
# 34                              -1__In vitro__#8d6666
# 35                              -1__In vitro__#8d6666
# 36                              -1__In vitro__#8d6666
# 37                              -1__In vitro__#8d6666
# 38                              -1__In vitro__#8d6666
# 39                        9606__Homo sapiens__#335e94
#
#    affectedByMutationStyled searchChildInteractors    nameA    nameB
# 0      none__false__#7e8389                    NaN   ADRA1B    CXCR4
# 1      none__false__#7e8389                    NaN   ADRA1B    CXCR4
# 2      none__false__#7e8389                    NaN   ADRA1B    CXCR4
# 3      none__false__#7e8389                    NaN   ADRA1B    CXCR4
# 4      none__false__#7e8389                    NaN   ADRA1B    CXCR4
# 5      none__false__#7e8389                    NaN   ADRA1B    CXCR4
# 6      none__false__#7e8389                    NaN    ACKR3    CXCR4
# 7      none__false__#7e8389                    NaN    ACKR3    CXCR4
# 8      none__false__#7e8389                    NaN    ACKR3    CXCR4
# 9      none__false__#7e8389                    NaN    ACKR3    CXCR4
# 10     none__false__#7e8389                    NaN    ACKR3    CXCR4
# 11     none__false__#7e8389                    NaN    ACKR3    CXCR4
# 12     none__false__#7e8389                    NaN    ACKR3    CXCR4
# 13     none__false__#7e8389                    NaN    ACKR3    CXCR4
# 14     none__false__#7e8389                    NaN    ACKR3    CXCR4
# 15     none__false__#7e8389                    NaN    ACKR3    CXCR4
# 16     none__false__#7e8389                    NaN    CXCR4    CXCR4
# 17     none__false__#7e8389                    NaN    CXCR4    CXCR4
# 18     none__false__#7e8389                    NaN    CXCR4   ADRA1B
# 19     none__false__#7e8389                    NaN   ADRA1B   ADRA1B
# 20     none__false__#7e8389                    NaN   ADRA1B    ACKR3
# 21     none__false__#7e8389                    NaN   ADRA1B    ACKR3
# 22     none__false__#7e8389                    NaN    CXCR4    ACKR3
# 23     none__false__#7e8389                    NaN    CXCR4    ACKR3
# 24     none__false__#7e8389                    NaN    CXCR4    ACKR3
# 25     none__false__#7e8389                    NaN    CXCR4    ACKR3
# 26     none__false__#7e8389                    NaN    ACKR3    ACKR3
# 27     none__false__#7e8389                    NaN     AQP5     AQP5
# 28     none__false__#7e8389                    NaN     AQP5     AQP5
# 29     none__false__#7e8389                    NaN    EPHA2    EPHA2
# 30     none__false__#7e8389                    NaN     Hcn1     Hcn2
# 31     none__false__#7e8389                    NaN     Hcn2     Hcn2
# 32     none__false__#7e8389                    NaN     Hcn1     Hcn1
# 33     none__false__#7e8389                    NaN     Hcn1     Hcn1
# 34      none__true__#ff00a1                    NaN     Hcn1     Hcn1
# 35     none__false__#7e8389                    NaN     Hcn1     Hcn1
# 36     none__false__#7e8389                    NaN     HCN2     HCN2
# 37     none__false__#7e8389                    NaN     HCN2     HCN2
# 38     none__false__#7e8389                    NaN     HCN2     HCN2
# 39     none__false__#7e8389                    NaN  Nectin4  Nectin4
#
# [40 rows x 101 columns]
