# %% [markdown]
# # Experiment with text generation for BMO

# %%
import getpass
import json
import random
import rdflib
import re
import requests
import wikipedia
import urllib

from bs4 import BeautifulSoup
from collections import Counter, defaultdict

import numpy as np
import networkx as nx

import spacy

from sklearn.model_selection import train_test_split

from bmo_tools.ontologies import subontology_from_term

from bluegraph import PandasPGFrame
from bluegraph.backends.networkx import pgframe_to_networkx

from kgforge.core.forge import KnowledgeGraphForge
from kgforge.core.resource import Resource
from kgforge.specializations.resources import Dataset

# %%
TOKEN = getpass.getpass()
# Out:
# ········

# %%
ENDPOINT = "https://bbp.epfl.ch/nexus/v1"

# %%
forge = KnowledgeGraphForge(
    "https://raw.githubusercontent.com/BlueBrain/nexus-forge/master/examples/notebooks/use-cases/prod-forge-nexus.yml",
    endpoint=ENDPOINT,
    token=TOKEN,
    bucket="bbp/kg-to-text")

# %%
def is_nan(el):
    try:
        if np.isnan(el):
            return True
    except Exception as e:
        pass
    return False

def search_wiki(query):
    url = "https://en.wikipedia.org/w/api.php"
    
    params = {
        "action": "opensearch",
        "namespace": "0",
        "limit": "5",
        "format": "json",
        "search": query
    }

    result = requests.get(url, params=params).json()
    _, titles, _, uris = result
    if len(titles) > 0:
        return titles[0], uris[0]
    
def query_dbpedia(wiki_url):
    suffix = wiki_url.split("/")[-1]
    dbpedia_id = f"http://dbpedia.org/data/{suffix}.json"

    res = requests.get(dbpedia_id).json()
    incoming_links = []
    for k, v in res.items():
        if k != f"http://dbpedia.org/resource/{suffix}":
            incoming_links.append(k)
    data = res[f"http://dbpedia.org/resource/{suffix}"]

    return data, incoming_links


def search_dbpedia(query):
    url = "https://lookup.dbpedia.org/api/search"
    
    params = {
        "format": "json",
        "query": query
    }
    
    result = requests.get(url, params=params).json()
    results = []
    for el in result["docs"]:
        record = {}
        record["url"] = el['resource'][0]
        record["redirecredLabels"] = set([
            l.replace("<B>", "").replace("</B>", "")
            for l in el.get('redirectlabel', [])
        ])
        record["label"] = [
            l.replace("<B>", "").replace("</B>", "")
            for l in el.get('label', [])
        ]
        record["type"] = el.get("type", None)
        results.append(record)
    return results


def dbpedia_uri_to_wiki(uri):
    suffix = uri.split("/")[-1]
    return f"https://en.wikipedia.org/wiki/{suffix}"
    return wikipedia_uri


def wikipedia_uri_to_db(uri):
    suffix = wiki_url.split("/")[-1]
    return f"http://dbpedia.org/resource/{suffix}"


def extract_wiki_abstract(wiki_url):
    suffix = wiki_url.split("/")[-1]
    dbpedia_id = f"http://dbpedia.org/data/{suffix}.json"

    res = requests.get(dbpedia_id)
    data = res.json()[f"http://dbpedia.org/resource/{suffix}"]

    vals = [
        el["value"]
        for el in data.get("http://dbpedia.org/ontology/abstract", [])
        if el["lang"] == "en"
    ]
    return vals[0] if len(vals) > 0 else None


def extract_full_wiki_text(wiki_url):
    """Adapted from https://levelup.gitconnected.com/two-simple-ways-to-scrape-text-from-wikipedia-in-python-9ce07426579b."""
    html_source = requests.get(wiki_url).text
    soup = BeautifulSoup(html_source,'lxml')

    # Extract the plain text content from paragraphs
    paras = []
    for paragraph in soup.find_all('p'):
        paras.append(str(paragraph.text))

    # Interleave paragraphs & headers
    text = ' '.join(paras)

    # Drop footnote superscripts in brackets
    text = re.sub(r"\[.*?\]+", '', text)

    # Replace '\n' (a new line) with '' and end the string at $1000.
    text = text.replace('\n', '')[:-11]
    return text


def annotate_text(nlp, text):
    url = "https://api.dbpedia-spotlight.org/en/annotate"
    params={
        "text": nlp.make_doc(text)
    }
    params = urllib.parse.urlencode(params, quote_via=urllib.parse.quote)
    result = requests.get(url, params=params, headers={"accept": "application/json"})
    try:
        json_data = result.json()
    except:
        json_data = None

    return json_data


def text_to_batches(text, max_batch_length):
    text_length = len(text)
    if text_length <= max_batch_length:
        yield text
    else:
        start = 0
        end = 0
        while True:
            if start + max_batch_length > text_length or end == -1:
                break
            end = text.rfind(" ", start, start + max_batch_length + 1)
            yield text[start:end]
            start = end + 1
        yield text[start:]
        

def wiki_url_from_wikidata(wikidata_id, lang):
    result =requests.get(
        "https://www.wikidata.org/w/api.php",
        params={
            "action": "wbgetentities",
            "format": "json",
            "props": "sitelinks",
            "ids": wikidata_id,
            "sitefilter": lang + "wiki"
        })
    entities = result.json().get("entities")
    if entities:
        entity = entities.get(wikidata_id)
        record = entity["sitelinks"].get(f"{lang}wiki")
        if record:
            title = record["title"]
            return f"https://en.wikipedia.org/wiki/{title.replace(' ', '_')}"


def get_id_by_label(graph, label):
    uri = None
    for s in graph.subjects(
            rdflib.RDFS.label,
            rdflib.Literal(label, lang="en")):
        uri = s
        break
    if uri is None:
        for s in graph.subjects(
                rdflib.RDFS.label,
                rdflib.Literal(label, datatype=rdflib.XSD.string)):
            uri = s
            break
    if uri is None:
        for s in graph.subjects(
                rdflib.RDFS.label,
                rdflib.Literal(label)):
            uri = s
            break
    return s


def add_annotation(record, label, text, local_start, local_end):
    span = {}

    span["start"] = local_start + len(record["text"]) + 1
    span["end"] = local_end + len(record["text"]) + 1
    record["text"] += " " + text

    span["text"] = label
    span["label"] = str(get_id_by_label(rdf_graph, label))
    
    record["spans"].append(span)

# %% [markdown]
# # 1. Generate simple sentences from BMO
#
# Here we generate simple sentences from triples of the ontology:
# - definition
# - synonyms
# - subClassOf relationships

# %%
frame = PandasPGFrame.from_ontology(
        filepath="../../ontologies/bbp/bmo.ttl",
        format="turtle", remove_prop_uris=True)

# %%
rdf_graph = rdflib.Graph()
rdf_graph.parse("../../ontologies/bbp/bmo.ttl", format="turtle")
# Out:
# <Graph identifier=N90fdd4275711483ea73b4a87e92cf682 (<class 'rdflib.graph.Graph'>)>

# %%
BMO_URI = "https://bbp.epfl.ch/ontologies/core/bmo/"

# %%
graph = pgframe_to_networkx(frame)

# %%
COMMON_EDGE_ALIASES = {
    "IS_SUBCLASS_OF": "is a",
    "isPartOf": "is a part of",
    "hasParameter": "has parameter",
    "modelOf": "is a model of",
    "hasFeature": "has feature",
    "hasType": "has type"
}

# %%
graph = pgframe_to_networkx(frame)

# %%
synthetic_text = []

# %%
for n in graph.nodes():
    print("Node: ", n)
    label = graph.nodes[n]["label"]
    definition = graph.nodes[n]["definition"]
    
    record = {"text": "", "spans": []}
    
    if not is_nan(definition):
        text = f"{label} is {definition}."
        print("\t [D]", text)
        add_annotation(record, label, text, 0, len(label))
    
    synonyms = []

    synonym = graph.nodes[n]["synonym"]
    if not is_nan(synonym):
        if isinstance(synonym, list):
            synonyms += synonym
        else:
            synonyms.append(synonym)
    
    altLabel = graph.nodes[n]["altLabel"]
    if not is_nan(altLabel):
        if isinstance(altLabel, list):
            synonyms += altLabel
        else:
            synonyms.append(altLabel)
            
    prefLabel = graph.nodes[n]["prefLabel"]
    if not is_nan(prefLabel):
        if isinstance(prefLabel, list):
            synonyms += prefLabel
        else:
            synonyms.append(prefLabel)
        
    for synonym in synonyms:
        text = f"{label} is also know as {synonym}."
        print("\t [S]", text)
        add_annotation(record, label, text, 0, len(label))
        
        text = f"{label} is referred to as {synonym}."
        print("\t [S]", text)
        add_annotation(record, label, text, 0, len(label))
    
    example = graph.nodes[n]["example"]
    if not is_nan(example):
        if isinstance(example, list):
            example = ", ".join(example)
        
        text = f"Examples of {label} include {example}."
        print("\t [E]", text)
        add_annotation(record, label, text, 12, 12 + len(label))
        
        text = f"{example} is an example of {label}."
        print("\t [E]", text)
        local_start = len(example) + 18
        add_annotation(record, label, text, local_start, local_start + len(label))
    
        text = f"Different examples of {label} such as {example}."
        print("\t [E]", text)
        local_start = 22
        add_annotation(record, label, text, local_start, local_start + len(label))
        
    for _, neighbor in graph.out_edges(n):
        for r_type in graph.edges[n, neighbor]["@type"]:
            if r_type in COMMON_EDGE_ALIASES:
                r_type = COMMON_EDGE_ALIASES[r_type]
            text = f"{label} {r_type} {neighbor}."
            print("\t [R]", text)
            add_annotation(record, label, text, 0, len(label))
            
    synthetic_text.append(record)
        
    print()
# Out:
# Node:  EModel Hyperparameter
# 	 [D] EModel Hyperparameter is A parameter used to represent a specific value used in the settings of the EModel building pipeline..
# 	 [R] EModel Hyperparameter is a Hyperparameter.
#
# Node:  Hyperparameter
# 	 [R] Hyperparameter is a Entity.
#
# Node:  EModel Parameter Optimization Workflow
# 	 [R] EModel Parameter Optimization Workflow is a Parameter Optimization Workflow.
# 	 [R] EModel Parameter Optimization Workflow is a part of EModel Building Workflow.
# 	 [R] EModel Parameter Optimization Workflow generates Ion Channel Density.
# 	 [R] EModel Parameter Optimization Workflow generates Ion Dynamics Feature.
# 	 [R] EModel Parameter Optimization Workflow has parameter EModel Hyperparameter.
# 	 [R] EModel Parameter Optimization Workflow hasTarget Neuron Electrophysiological Feature.
# 	 [R] EModel Parameter Optimization Workflow uses Ion Channel Density Constraint.
# 	 [R] EModel Parameter Optimization Workflow uses Model Ionic Mechanism.
# 	 [R] EModel Parameter Optimization Workflow uses Neuron Morphology.
#
# Node:  Parameter Optimization Workflow
# 	 [R] Parameter Optimization Workflow is a Workflow.
# 	 [R] Parameter Optimization Workflow is a part of Model Building Workflow.
# 	 [R] Parameter Optimization Workflow generates Model Brain Parameter.
# 	 [R] Parameter Optimization Workflow has parameter Model Brain Parameter.
# 	 [R] Parameter Optimization Workflow hasTarget Brain Component Feature.
# 	 [R] Parameter Optimization Workflow uses Dataset.
# 	 [R] Parameter Optimization Workflow uses Model Brain Component.
#
# Node:  EModel Building Workflow
# 	 [R] EModel Building Workflow is a Neuron Building Workflow.
# 	 [R] EModel Building Workflow generates EModel.
# 	 [R] EModel Building Workflow about Neuron Electrical Type.
# 	 [R] EModel Building Workflow hasTarget Neuron Electrophysiological Feature.
# 	 [R] EModel Building Workflow qualifiedAssociation Association.
# 	 [R] EModel Building Workflow uses Ion Channel Density.
# 	 [R] EModel Building Workflow uses Ion Dynamics Feature.
# 	 [R] EModel Building Workflow uses Model Ionic Mechanism.
# 	 [R] EModel Building Workflow uses Neuron Morphology.
#
# Node:  Ion Channel Density
# 	 [D] Ion Channel Density is Density of ion channels in a subcellular component of a neuron..
# 	 [R] Ion Channel Density is a EModel Parameter.
# 	 [R] Ion Channel Density is a Neuron Part Feature.
# 	 [R] Ion Channel Density compartment Neuron Part.
# 	 [R] Ion Channel Density brainRegion Brain Region.
# 	 [R] Ion Channel Density ionChannel Ion Channel.
#
# Node:  Ion Dynamics Feature
# 	 [D] Ion Dynamics Feature is Kinetics of the conductance mechanism of an ion..
# 	 [R] Ion Dynamics Feature is a EModel Parameter.
# 	 [R] Ion Dynamics Feature is a Neuron Part Feature.
# 	 [R] Ion Dynamics Feature compartment Neuron Part.
# 	 [R] Ion Dynamics Feature ion Ion.
#
# Node:  Neuron Electrophysiological Feature
# 	 [D] Neuron Electrophysiological Feature is An electrical property of a neuron that characterizes a cell's ability to control transmembrane ion flux to enable the generation of action potentials (APs)..
# 	 [R] Neuron Electrophysiological Feature is a Neuron Feature.
# 	 [R] Neuron Electrophysiological Feature stimulusType Electrical Stimulus.
#
# Node:  Ion Channel Density Constraint
# 	 [R] Ion Channel Density Constraint is a EModel Parameter Constraint.
# 	 [R] Ion Channel Density Constraint constraints Ion Channel Density.
#
# Node:  Model Ionic Mechanism
# 	 [R] Model Ionic Mechanism is a Model Brain Activity.
# 	 [R] Model Ionic Mechanism is a model of Ionic Mechanism.
#
# Node:  Neuron Morphology
# 	 [R] Neuron Morphology is a Dataset.
# 	 [R] Neuron Morphology hasMType Neuron Morphological Type.
#
# Node:  Synaptic Connection Feature
# 	 [R] Synaptic Connection Feature is a Brain Component Feature.
#
# Node:  Brain Component Feature
# 	 [D] Brain Component Feature is A measurable property or feature of a biological or model brain component..
# 	 [R] Brain Component Feature is a Entity.
#
# Node:  Ca_HVA2
# 	 [D] Ca_HVA2 is High-voltage-gaterd calcium current.
# 	 [R] Ca_HVA2 is a Ionic Mechanism.
# 	 [R] Ca_HVA2 ion Ca.
#
# Node:  Ionic Mechanism
# 	 [D] Ionic Mechanism is A mechanism underlying the dynamics of specific ion current type..
# 	 [R] Ionic Mechanism is a Biological Brain Activity.
# 	 [R] Ionic Mechanism associatedIon Ion.
#
# Node:  Ca
# 	 [S] Ca is also know as Calcium.
# 	 [S] Ca is referred to as Calcium.
# 	 [R] Ca is a Ion.
#
# Node:  Query
# 	 [R] Query is a Entity.
#
# Node:  Entity
# 	 [D] Entity is A Brain Modeling Entity is any entity (biological or modeled) that can be used or generated in the process of digitally reconstructing brain tissue.
#
# Node:  Model Mitochondrion Metabolism
# 	 [R] Model Mitochondrion Metabolism is a Model Subcellular Part Metabolism.
# 	 [R] Model Mitochondrion Metabolism is a model of Mitochondrion.
#
# Node:  Model Subcellular Part Metabolism
# 	 [R] Model Subcellular Part Metabolism is a Model Subcellular Part.
# 	 [R] Model Subcellular Part Metabolism is a part of Model Glia Metabolism.
# 	 [R] Model Subcellular Part Metabolism is a part of Model Neuron Metabolism.
# 	 [R] Model Subcellular Part Metabolism is a model of Subcellular Part.
#
# Node:  Mitochondrion
# 	 [R] Mitochondrion is a Organelle.
#
# Node:  EModel Validation Threshold
# 	 [D] EModel Validation Threshold is Threshold under which each score of the EModel has to be for it to pass validation (used by the default validation function)..
# 	 [R] EModel Validation Threshold is a EModel Hyperparameter.
#
# Node:  Model kv11
# 	 [R] Model kv11 is a Model Ion Channel.
# 	 [R] Model kv11 is a model of Kv11.
#
# Node:  Model Ion Channel
# 	 [R] Model Ion Channel is a Model Brain Component.
# 	 [R] Model Ion Channel is a model of Ion Channel.
#
# Node:  Kv11
#
# Node:  Brain Volume Blueprint Building Workflow
# 	 [R] Brain Volume Blueprint Building Workflow is a Blueprint Building Workflow.
# 	 [R] Brain Volume Blueprint Building Workflow generates Brain Volume Blueprint.
# 	 [R] Brain Volume Blueprint Building Workflow uses Cell Density.
# 	 [R] Brain Volume Blueprint Building Workflow uses Cell Type Mapping.
#
# Node:  Blueprint Building Workflow
# 	 [R] Blueprint Building Workflow is a Workflow.
# 	 [R] Blueprint Building Workflow generates Brain Component Blueprint.
#
# Node:  Brain Volume Blueprint
# 	 [R] Brain Volume Blueprint is a Brain Component Blueprint.
#
# Node:  Cell Density
# 	 [R] Cell Density is a Brain Volume Feature.
# 	 [R] Cell Density is a Model Brain Volume Parameter.
# 	 [R] Cell Density brainLocation Brain Location.
# 	 [R] Cell Density cellType Brain Cell Type.
#
# Node:  Cell Type Mapping
# 	 [R] Cell Type Mapping is a Entity.
# 	 [R] Cell Type Mapping sourceType Brain Cell Type.
# 	 [R] Cell Type Mapping targetType Brain Cell Type.
#
# Node:  Subcellular Part Feature
# 	 [D] Subcellular Part Feature is Feature of a subcellular component of a biological brain cell.
# 	 [R] Subcellular Part Feature is a Brain Component Feature.
#
# Node:  Model Brain Component
# 	 [D] Model Brain Component is A Model Brain Component is a digital replica of a Biological Brain Component.
# 	 [S] Model Brain Component is also know as Model Brain Component.
# 	 [S] Model Brain Component is referred to as Model Brain Component.
# 	 [R] Model Brain Component is a Entity.
# 	 [R] Model Brain Component is a model of Biological Brain Component.
# 	 [R] Model Brain Component is a model of Brain Component Type.
#
# Node:  Ion Channel
# 	 [D] Ion Channel is Ion channels are proteins in the membrane that provide a passageway for charged ions..
# 	 [R] Ion Channel is a Biological Brain Component.
# 	 [R] Ion Channel is a part of Subcellular Part.
# 	 [R] Ion Channel associatedIon Ion.
#
# Node:  Workflow
# 	 [D] Workflow is A workflow represents a set of actions or steps intended by one or more agents to achieve some goals. A workflow is a specification or a plan and is instantiated by activities..
# 	 [R] Workflow is a Entity.
# 	 [R] Workflow uses Entity.
# 	 [R] Workflow generates Entity.
# 	 [R] Workflow about Entity.
# 	 [R] Workflow is a part of Workflow.
# 	 [R] Workflow hasWorkflowDefinition WorkflowDefinition.
# 	 [R] Workflow isAssociatedWith SoftwareAgent.
#
# Node:  Brain Component Blueprint
# 	 [R] Brain Component Blueprint is a Entity.
# 	 [R] Brain Component Blueprint is a model of Biological Brain Component.
#
# Node:  Synapse Plasticity Type
# 	 [R] Synapse Plasticity Type is a Synapse Type.
#
# Node:  Synapse Type
# 	 [R] Synapse Type is a Brain Component Type.
# 	 [R] Synapse Type has feature Synapse Feature.
#
# Node:  Astrocyte
# 	 [S] Astrocyte is also know as Astrocyte.
# 	 [S] Astrocyte is referred to as Astrocyte.
# 	 [R] Astrocyte is a Glia.
#
# Node:  Glia
# 	 [S] Glia is also know as Glia.
# 	 [S] Glia is referred to as Glia.
# 	 [R] Glia is a Brain Cell.
# 	 [R] Glia is a part of NGV Unit.
#
# Node:  GABA
# 	 [R] GABA is a Classical Neurotransmitter.
# 	 [R] GABA is a Inhibitory Transmitter.
#
# Node:  Classical Neurotransmitter
# 	 [R] Classical Neurotransmitter is a Neurotransmitter.
#
# Node:  Inhibitory Transmitter
# 	 [R] Inhibitory Transmitter is a Neurotransmitter.
#
# Node:  SoftwareAgent
# 	 [D] SoftwareAgent is ['A software agent is running software.', 'A software application'].
# 	 [R] SoftwareAgent is a Brain Modeling Agent.
# 	 [R] SoftwareAgent algorithm Algorithm.
#
# Node:  Brain Modeling Agent
# 	 [D] Brain Modeling Agent is A Brain Modeling Agent is an organization, a person or a software agent that is engaged in the process of digitally reconstructing brain tissue..
#
# Node:  Algorithm
# 	 [D] Algorithm is In mathematics and computer science, an algorithm is a finite sequence of well-defined, computer-implementable instructions, typically to solve a class of specific problems or to perform a computation..
# 	 [R] Algorithm is a Entity.
# 	 [R] Algorithm has parameter Model Brain Parameter.
#
# Node:  Number Of Synapses Per Connection
# 	 [R] Number Of Synapses Per Connection is a Model Connectivity Parameter.
# 	 [R] Number Of Synapses Per Connection is a Synaptic Pathway Feature.
#
# Node:  Model Connectivity Parameter
# 	 [R] Model Connectivity Parameter is a Model Brain Parameter.
#
# Node:  Synaptic Pathway Feature
# 	 [R] Synaptic Pathway Feature is a Brain Component Feature.
#
# Node:  Neuron Feature
# 	 [D] Neuron Feature is A measurable property or feature of a biological or model neuron..
# 	 [R] Neuron Feature is a Brain Cell Feature.
#
# Node:  Brain Cell Feature
# 	 [D] Brain Cell Feature is A measurable property or feature of a biological or model brain cell..
# 	 [R] Brain Cell Feature is a Brain Component Feature.
#
# Node:  Synaptic Pathway
# 	 [D] Synaptic Pathway is A set of synaptic connections from one cell type to another cell type..
# 	 [R] Synaptic Pathway is a Biological Brain Component.
# 	 [R] Synaptic Pathway has type Synaptic Pathway Type.
# 	 [R] Synaptic Pathway has feature Synaptic Pathway Feature.
#
# Node:  Biological Brain Component
# 	 [D] Biological Brain Component is A Biological Brain Component is a biological entity part of a brain.
# 	 [E] Examples of Biological Brain Component include A Brain Region is a brain component, A Neuron is a brain component, Synaptic Conductance is not a brain component.
# 	 [E] A Brain Region is a brain component, A Neuron is a brain component, Synaptic Conductance is not a brain component is an example of Biological Brain Component.
# 	 [E] Different examples of Biological Brain Component such as A Brain Region is a brain component, A Neuron is a brain component, Synaptic Conductance is not a brain component.
# 	 [R] Biological Brain Component is a Entity.
# 	 [R] Biological Brain Component componentType Brain Component Type.
# 	 [R] Biological Brain Component has feature Brain Component Feature.
#
# Node:  Synaptic Pathway Type
# 	 [R] Synaptic Pathway Type is a Brain Component Type.
# 	 [R] Synaptic Pathway Type postsynapticNeuronType Neuron Type.
# 	 [R] Synaptic Pathway Type presynapticNeuronType Neuron Type.
# 	 [R] Synaptic Pathway Type has feature Synaptic Pathway Feature.
#
# Node:  Acetylcholine
# 	 [D] Acetylcholine is An ester of choline and acetic acid that serves as a transmitter substance of nerve impulses within the central and peripheral nervous systems. Acetylcholine is the chief neurotransmitter of the parasympathetic nervous system, the part of the autonomic nervous system (a branch of the peripheral nervous system) that contracts smooth muscles, dilates blood vessels, increases bodily secretions, and slows heart rate. Acetylcholine can stimulate a response or block a response and thus can have excitatory or inhibitory effects..
# 	 [R] Acetylcholine is a Neuromodulator.
#
# Node:  Neuromodulator
# 	 [D] Neuromodulator is A chemical uses by neurons to regulate diverse populations of neurons. Neuromodulators typically bind to metabotropic, G-protein coupled receptors (GPCRs) to initiate a second messenger signaling cascade that induces a broad, long-lasting signal. This modulation can last for hundreds of milliseconds to several minutes. Some of the effects of neuromodulators include: alter intrinsic firing activity, increase or decrease voltage-dependent currents, alter synaptic efficacy, increase bursting activity and reconfiguration of synaptic connectivity. Major neuromodulators in the central nervous system include: dopamine, serotonin, acetylcholine, histamine, norepinephrine, nitric oxide, and several neuropeptides..
# 	 [R] Neuromodulator is a Neurotransmitter.
#
# Node:  Model Reaction Validation Workflow
# 	 [R] Model Reaction Validation Workflow is a Model Validation Workflow.
# 	 [R] Model Reaction Validation Workflow hasTarget Steady State Molecular Concentration.
# 	 [R] Model Reaction Validation Workflow uses Molecular Concentration Series.
#
# Node:  Model Validation Workflow
# 	 [R] Model Validation Workflow is a Workflow.
# 	 [R] Model Validation Workflow hasTarget Brain Component Feature.
# 	 [R] Model Validation Workflow uses Dataset.
#
# Node:  Steady State Molecular Concentration
# 	 [R] Steady State Molecular Concentration is a Molecular Compartment Feature.
# 	 [R] Steady State Molecular Concentration molecule Molecule.
#
# Node:  Molecular Concentration Series
# 	 [D] Molecular Concentration Series is Time series representing change of molecular concentration value of a given molecule in a given molecular compartment..
# 	 [R] Molecular Concentration Series is a Time Series.
#
# Node:  Histamine
# 	 [D] Histamine is Histamine is an organic nitrogenous compound involved in local immune responses, as well as regulating physiological functions in the gut and acting as a neurotransmitter for the brain, spinal cord, and uterus. In recent years, histamine has been recognized as a central neurotransmitter. It consists of an imidazole ring attached to an ethylamine chain; under physiological conditions, the amino group of the side-chain is protonated..
# 	 [R] Histamine is a Excitatory Transmitter.
# 	 [R] Histamine is a Neuromodulator.
#
# Node:  Excitatory Transmitter
# 	 [R] Excitatory Transmitter is a Neurotransmitter.
#
# Node:  Brain Area
# 	 [D] Brain Area is A Brain Area is a part of a Brain Region that is anatomically and functionally distinguishable. A Brain Region is made up of multiple Brain Areas..
# 	 [E] Examples of Brain Area include An example of Brain Areas include V1, V2, V3,V4, etc of the Visual Cortex Brain Region or S1,S2, etc of the Somatosensory Cortex Brain Region.
# 	 [E] An example of Brain Areas include V1, V2, V3,V4, etc of the Visual Cortex Brain Region or S1,S2, etc of the Somatosensory Cortex Brain Region is an example of Brain Area.
# 	 [E] Different examples of Brain Area such as An example of Brain Areas include V1, V2, V3,V4, etc of the Visual Cortex Brain Region or S1,S2, etc of the Somatosensory Cortex Brain Region.
# 	 [R] Brain Area is a Biological Brain Component.
# 	 [R] Brain Area is a Brain Volume.
# 	 [R] Brain Area is a part of Brain Region.
#
# Node:  Brain Volume
# 	 [D] Brain Volume is Any bounded space in the brain where neurons can reside.
# 	 [R] Brain Volume is a Biological Brain Component.
#
# Node:  Brain Region
# 	 [D] Brain Region is Anatomical divisons of the brain according to one or more criteria, e.g. cytoarchitectural, gross anatomy. Parts may be contiguous in 3D or not, e.g., basal ganglia..
# 	 [S] Brain Region is also know as regional part of the brain.
# 	 [S] Brain Region is referred to as regional part of the brain.
# 	 [R] Brain Region is a Biological Brain Component.
# 	 [R] Brain Region is a Brain Volume.
# 	 [R] Brain Region is a part of Brain System.
# 	 [R] Brain Region species Species.
#
# Node:  Model Biochemical Reaction Parameter
# 	 [D] Model Biochemical Reaction Parameter is Parameter used to represent a specific biological or theoretical value that is used in the modeling of biochemical reactions..
# 	 [R] Model Biochemical Reaction Parameter is a Model Brain Parameter.
#
# Node:  Model Brain Parameter
# 	 [D] Model Brain Parameter is A brain parameter is a parameter used to represent a specific biological or theoretical value that is used in the construction of a brain model..
# 	 [R] Model Brain Parameter is a Entity.
# 	 [R] Model Brain Parameter value Quantitative Value.
#
# Node:  Brain Volume Feature
# 	 [R] Brain Volume Feature is a Brain Component Feature.
#
# Node:  Modulatory Neuron
# 	 [D] Modulatory Neuron is A nueron that releases modulatory neurotransmitters. These neurotransmitters, often referred to as neuromodulators, are capable of affecting a larger number of neurons at the same time. These neuromodulators also influence the effects of other chemical messengers. Where synaptic neurotransmitters are released by axon terminals to have a fast-acting impact on other receptor neurons, neuromodulators diffuse across a larger area and are more slow-acting..
# 	 [S] Modulatory Neuron is also know as Modulatory Neuron.
# 	 [S] Modulatory Neuron is referred to as Modulatory Neuron.
# 	 [R] Modulatory Neuron is a Neurotransmitter Type.
#
# Node:  Neurotransmitter Type
# 	 [S] Neurotransmitter Type is also know as Neurotransmitter Type.
# 	 [S] Neurotransmitter Type is referred to as Neurotransmitter Type.
# 	 [R] Neurotransmitter Type is a Neuron Type.
#
# Node:  Inhibitory Neuron
# 	 [D] Inhibitory Neuron is A neuron that releases inhibitory neurotransmitters. These types of neurotransmitters have inhibitory effects on the neuron; they decrease the likelihood that the neuron will fire an action potential. Some of the major inhibitory neurotransmitters include serotonin and gamma-aminobutyric acid (GABA)..
# 	 [S] Inhibitory Neuron is also know as Inhibitory Neuron.
# 	 [S] Inhibitory Neuron is referred to as Inhibitory Neuron.
# 	 [R] Inhibitory Neuron is a Neurotransmitter Type.
#
# Node:  Glia Metabolism Building Workflow
# 	 [R] Glia Metabolism Building Workflow is a Glia Building Workflow.
# 	 [R] Glia Metabolism Building Workflow generates Model Glia Metabolism.
# 	 [R] Glia Metabolism Building Workflow uses Model Biochemical Reaction.
# 	 [R] Glia Metabolism Building Workflow uses Model Subcellular Part Metabolism.
#
# Node:  Glia Building Workflow
# 	 [R] Glia Building Workflow is a Cell Building Workflow.
# 	 [R] Glia Building Workflow generates Model Glia.
# 	 [R] Glia Building Workflow about Glia.
#
# Node:  Model Glia Metabolism
# 	 [R] Model Glia Metabolism is a Model Glia.
# 	 [R] Model Glia Metabolism is a part of Model NGV Unit Metabolism.
# 	 [R] Model Glia Metabolism is a model of Glia.
#
# Node:  Model Biochemical Reaction
# 	 [D] Model Biochemical Reaction is A computational model of a biochemical reaction, a chemical process of transformation of some molecules (substrates) into the other molecules (products)..
# 	 [R] Model Biochemical Reaction is a Model Brain Activity.
# 	 [R] Model Biochemical Reaction is a model of Biochemical Reaction.
#
# Node:  Model Neuron
# 	 [R] Model Neuron is a Model Cell.
# 	 [R] Model Neuron is a model of Neuron.
#
# Node:  Model Cell
# 	 [R] Model Cell is a Model Brain Component.
# 	 [R] Model Cell is a model of Brain Cell.
#
# Node:  Neuron
# 	 [R] Neuron is a Brain Cell.
# 	 [R] Neuron is a part of NGV Unit.
# 	 [R] Neuron has type Neuron Type.
# 	 [R] Neuron has feature Neuron Feature.
#
# Node:  IBEA
# 	 [D] IBEA is Indicator-based evolutionary algorithm..
# 	 [R] IBEA is a EModel Parameter Optimizer.
# 	 [R] IBEA is a Evolutionary Algorithm.
#
# Node:  EModel Parameter Optimizer
# 	 [D] EModel Parameter Optimizer is Algorithm used for optimization..
# 	 [R] EModel Parameter Optimizer is a EModel Hyperparameter.
#
# Node:  Evolutionary Algorithm
# 	 [D] Evolutionary Algorithm is In computational intelligence, an evolutionary algorithm is a subset of evolutionary computation, a generic population-based metaheuristic optimization algorithm..
# 	 [R] Evolutionary Algorithm is a Algorithm.
#
# Node:  K
# 	 [S] K is also know as Potassium.
# 	 [S] K is referred to as Potassium.
# 	 [R] K is a Ion.
#
# Node:  Ion
# 	 [D] Ion is An ion is a particle, atom or molecule with a net electrical charge. The movement of ions through the membrane of neurons underlies their signalling mechanism..
# 	 [R] Ion is a Biological Brain Component.
#
# Node:  Synaptic Connection
# 	 [D] Synaptic Connection is A set of synapses connecting one concrete cell to another..
# 	 [R] Synaptic Connection is a Biological Brain Component.
# 	 [R] Synaptic Connection is a part of Synaptic Pathway.
# 	 [R] Synaptic Connection postsynapticNeuron Neuron.
# 	 [R] Synaptic Connection presynapticNeuron Neuron.
# 	 [R] Synaptic Connection has feature Synaptic Connection Feature.
#
# Node:  Vector3D
# 	 [R] Vector3D is a Entity.
#
# Node:  Time Series
# 	 [R] Time Series is a Dataset.
#
# Node:  Dataset
# 	 [R] Dataset is a Entity.
# 	 [R] Dataset brainLocation Brain Location.
# 	 [R] Dataset generationModality Data Generation Modality.
# 	 [R] Dataset object Object Of Study.
# 	 [R] Dataset subject Subject.
#
# Node:  Synapse
# 	 [D] Synapse is A structure that permits a neuron to pass an electrical or chemical signal to another neuron or to the target effector cell. Synapse is formed by a presynaptic and postsynaptic part with a space between the two parts. Different structural proteins connect the pre- and postsynaptic parts of the synapse..
# 	 [R] Synapse is a Biological Brain Component.
# 	 [R] Synapse is a part of Synaptic Connection.
# 	 [R] Synapse has type Synapse Type.
# 	 [R] Synapse postsynapticNeuron Neuron.
# 	 [R] Synapse presynapticNeuron Neuron.
# 	 [R] Synapse has feature Synapse Feature.
#
# Node:  Synapse Feature
# 	 [R] Synapse Feature is a Brain Component Feature.
#
# Node:  Model Brain Vascular Component
# 	 [R] Model Brain Vascular Component is a Model Brain Component.
# 	 [R] Model Brain Vascular Component is a model of Brain Vascular Component.
#
# Node:  Brain Vascular Component
# 	 [D] Brain Vascular Component is A Brain Vascular Component is a biological entity part of the brain vasculature..
# 	 [E] Examples of Brain Vascular Component include A brain artery is an example of a brain vascular component..
# 	 [E] A brain artery is an example of a brain vascular component. is an example of Brain Vascular Component.
# 	 [E] Different examples of Brain Vascular Component such as A brain artery is an example of a brain vascular component..
# 	 [R] Brain Vascular Component is a Biological Brain Component.
# 	 [R] Brain Vascular Component is a Molecular Compartment.
# 	 [R] Brain Vascular Component is a part of Microcircuit.
# 	 [R] Brain Vascular Component is a part of NGV Unit.
#
# Node:  Basal Dendrite
# 	 [R] Basal Dendrite is a Dendrite.
#
# Node:  Dendrite
# 	 [R] Dendrite is a Neuron Part.
# 	 [R] Dendrite is a part of Neuron.
#
# Node:  Neurotransmitter Synapse Type
# 	 [R] Neurotransmitter Synapse Type is a Synapse Type.
#
# Node:  Cell Building Workflow
# 	 [R] Cell Building Workflow is a Model Building Workflow.
# 	 [R] Cell Building Workflow generates Model Cell.
# 	 [R] Cell Building Workflow about Brain Cell.
#
# Node:  Model Glia
# 	 [R] Model Glia is a Model Cell.
# 	 [R] Model Glia is a model of Glia.
#
# Node:  Homo Sapiens
# 	 [S] Homo Sapiens is also know as Human.
# 	 [S] Homo Sapiens is referred to as Human.
# 	 [R] Homo Sapiens is a Species.
#
# Node:  Species
# 	 [D] Species is In biology, a species is a basic unit of classification and a taxonomic rank of an organism, as well as a unit of biodiversity..
# 	 [R] Species is a Entity.
#
# Node:  Activity
# 	 [D] Activity is An activity is something that occurs over a period of time and acts upon or with entities; it may include consuming, processing, transforming, modifying, relocating, using, or generating entities..
# 	 [R] Activity generated Entity.
# 	 [R] Activity used Entity.
# 	 [R] Activity hadPlan Workflow.
# 	 [R] Activity wasAssociatedWith Brain Modeling Agent.
#
# Node:  Brain Component Type
# 	 [D] Brain Component Type is Classification of Brain Components whether biological or model..
# 	 [R] Brain Component Type is a Entity.
# 	 [R] Brain Component Type has feature Brain Component Feature.
#
# Node:  Gamma CaDynamics DC0
# 	 [D] Gamma CaDynamics DC0 is The inverse of the calcium ion buffer's binding ratio..
# 	 [R] Gamma CaDynamics DC0 is a Calcium Dynamics.
#
# Node:  Calcium Dynamics
# 	 [D] Calcium Dynamics is Kinetics of the conductance mechanism of calcium ion..
# 	 [R] Calcium Dynamics is a Ion Dynamics Feature.
# 	 [R] Calcium Dynamics ion Ca.
#
# Node:  Model Basal Lamina Metabolism
# 	 [R] Model Basal Lamina Metabolism is a Model Extracellular Part Metabolism.
# 	 [R] Model Basal Lamina Metabolism is a model of Basal Lamina.
#
# Node:  Model Extracellular Part Metabolism
# 	 [R] Model Extracellular Part Metabolism is a Model Extracellular Part.
# 	 [R] Model Extracellular Part Metabolism is a part of Model NGV Unit Metabolism.
# 	 [R] Model Extracellular Part Metabolism is a model of Extracellular Part.
#
# Node:  Basal Lamina
# 	 [D] Basal Lamina is A Basal Lamina is a specialised sheet of extracellular matrix..
# 	 [R] Basal Lamina is a Extracellular Part.
#
# Node:  Neuron Type
# 	 [R] Neuron Type is a Brain Cell Type.
# 	 [R] Neuron Type has feature Neuron Feature.
#
# Node:  Neurotransmitter
# 	 [D] Neurotransmitter is Blue Brain considers a neurotransmitter as any chemical agent that is produced by one cell in any part of the body and targets one or more cells in the Brain.
# 	 [R] Neurotransmitter is a Biological Brain Component.
#
# Node:  BACFiringFeature
# 	 [D] BACFiringFeature is Back-propagating action potential activated Ca2+ spike firing feature..
# 	 [R] BACFiringFeature is a Neuron Electrophysiological Feature.
# 	 [R] BACFiringFeature compartment Soma.
# 	 [R] BACFiringFeature compartment Dendrite.
#
# Node:  Soma
# 	 [R] Soma is a Neuron Part.
# 	 [R] Soma is a part of Neuron.
#
# Node:  Neuron Projection Type
# 	 [S] Neuron Projection Type is also know as PType.
# 	 [S] Neuron Projection Type is referred to as PType.
# 	 [R] Neuron Projection Type is a Neuron Type.
#
# Node:  Leaf Regions
# 	 [R] Leaf Regions is a Neurite Location Feature.
#
# Node:  Neurite Location Feature
# 	 [R] Neurite Location Feature is a Neuron Feature.
#
# Node:  Brain System
# 	 [D] Brain System is A Brain system is a system made up of at least two brain regions, including the anatomical and/or functional connections  between these brain regions..
# 	 [E] Examples of Brain System include Neocortical Thalamic System.
# 	 [E] Neocortical Thalamic System is an example of Brain System.
# 	 [E] Different examples of Brain System such as Neocortical Thalamic System.
# 	 [R] Brain System is a Biological Brain Component.
# 	 [R] Brain System is a Brain Volume.
# 	 [R] Brain System is a part of Whole Brain.
#
# Node:  Whole Brain
# 	 [D] Whole Brain is The brain is the center of the nervous system in all vertebrate, and most invertebrate, animals. Some primitive animals such as jellyfish and starfish have a decentralized nervous system without a brain, while sponges lack any nervous system at all. In vertebrates, the brain is located in the head, protected by the skull and close to the primary sensory apparatus of vision, hearing, balance, taste, and smell.
# 	 [R] Whole Brain is a Biological Brain Component.
# 	 [R] Whole Brain is a Brain Volume.
#
# Node:  Angiotensin
# 	 [R] Angiotensin is a Hormone.
#
# Node:  Hormone
# 	 [R] Hormone is a Neurotransmitter.
#
# Node:  Brain Cell
# 	 [D] Brain Cell is Blue Brain considers as brain cells neurons, glia, endothelial cells as well as externally invading cells e.g. from the immune system.
# 	 [R] Brain Cell is a Biological Brain Component.
# 	 [R] Brain Cell is a Molecular Compartment.
# 	 [R] Brain Cell is a part of Microcircuit.
# 	 [R] Brain Cell has type Brain Cell Type.
# 	 [R] Brain Cell has feature Brain Cell Feature.
#
# Node:  Molecular Compartment
# 	 [D] Molecular Compartment is A compartment in which molecular species live and in which biochemical reactions can take place..
# 	 [R] Molecular Compartment is a Biological Brain Component.
# 	 [R] Molecular Compartment has feature Molecular Compartment Feature.
#
# Node:  Microcircuit
# 	 [D] Microcircuit is A microcircuit is a minimal volume of brain tissue where the cell numbers are sufficient to saturate the volume of the dendritic neuropil. A number of microcircuits make up a Brain Area..
# 	 [S] Microcircuit is also know as Neuronal Microcircuit.
# 	 [S] Microcircuit is referred to as Neuronal Microcircuit.
# 	 [S] Microcircuit is also know as Microcircuit.
# 	 [S] Microcircuit is referred to as Microcircuit.
# 	 [R] Microcircuit is a Biological Brain Component.
# 	 [R] Microcircuit is a Brain Volume.
# 	 [R] Microcircuit is a part of Brain Area.
#
# Node:  Brain Cell Type
# 	 [R] Brain Cell Type is a Brain Component Type.
# 	 [R] Brain Cell Type has feature Brain Cell Feature.
#
# Node:  Brain Modeling Activity
# 	 [D] Brain Modeling Activity is A Brain Modeling Activity is any activity involved the process of digitally reconstructing brain tissue. This includes but not limited to collecting values from literature, db and generated from experiment..
# 	 [R] Brain Modeling Activity is a Activity.
#
# Node:  Model Circuit Building Workflow
# 	 [R] Model Circuit Building Workflow is a Model Building Workflow.
# 	 [R] Model Circuit Building Workflow generates Model Circuit.
# 	 [R] Model Circuit Building Workflow uses Model Brain Volume.
# 	 [R] Model Circuit Building Workflow uses Model Circuit Connectivity.
#
# Node:  Model Building Workflow
# 	 [R] Model Building Workflow is a Workflow.
# 	 [R] Model Building Workflow uses Model Brain Component.
# 	 [R] Model Building Workflow generates Model Brain Component.
# 	 [R] Model Building Workflow has parameter Model Brain Parameter.
# 	 [R] Model Building Workflow isAssociatedWith SoftwareAgent.
# 	 [R] Model Building Workflow hasTarget Brain Component Feature.
# 	 [R] Model Building Workflow uses Dataset.
# 	 [R] Model Building Workflow uses Equation.
#
# Node:  Model Circuit
# 	 [R] Model Circuit is a Model Brain Component.
# 	 [R] Model Circuit is a model of Brain Volume.
#
# Node:  Model Brain Volume
# 	 [R] Model Brain Volume is a Model Brain Component.
# 	 [R] Model Brain Volume is a model of Brain Volume.
#
# Node:  Model Circuit Connectivity
# 	 [R] Model Circuit Connectivity is a Model Brain Component.
# 	 [R] Model Circuit Connectivity is a model of Brain Volume.
#
# Node:  Model Interstitial Space Metabolism
# 	 [R] Model Interstitial Space Metabolism is a Model Extracellular Part Metabolism.
# 	 [R] Model Interstitial Space Metabolism is a model of Interstitial Space.
#
# Node:  Interstitial Space
# 	 [D] Interstitial Space is The Interstitial Space is a narrow space between neural cells and blood vessels..
# 	 [R] Interstitial Space is a Extracellular Part.
#
# Node:  Extracellular Part
# 	 [D] Extracellular Part is An Extracellular Part is a biological brain component situated outside brain cells..
# 	 [E] Examples of Extracellular Part include The brain's extracellular matrix is an extracellular part..
# 	 [E] The brain's extracellular matrix is an extracellular part. is an example of Extracellular Part.
# 	 [E] Different examples of Extracellular Part such as The brain's extracellular matrix is an extracellular part..
# 	 [R] Extracellular Part is a Biological Brain Component.
# 	 [R] Extracellular Part is a Molecular Compartment.
#
# Node:  NGV Unit Metabolism Building Workflow
# 	 [R] NGV Unit Metabolism Building Workflow is a NGV Unit Building Workflow.
# 	 [R] NGV Unit Metabolism Building Workflow generates Model NGV Unit Metabolism.
# 	 [R] NGV Unit Metabolism Building Workflow about NGV Unit.
# 	 [R] NGV Unit Metabolism Building Workflow uses Model Basal Lamina Metabolism.
# 	 [R] NGV Unit Metabolism Building Workflow uses Model Biochemical Reaction.
# 	 [R] NGV Unit Metabolism Building Workflow uses Model Glia Metabolism.
# 	 [R] NGV Unit Metabolism Building Workflow uses Model Interstitial Space Metabolism.
# 	 [R] NGV Unit Metabolism Building Workflow uses Model Neuron Metabolism.
#
# Node:  NGV Unit Building Workflow
# 	 [R] NGV Unit Building Workflow is a Model Building Workflow.
# 	 [R] NGV Unit Building Workflow generates Model NGV Unit.
# 	 [R] NGV Unit Building Workflow about NGV Unit.
#
# Node:  Model NGV Unit Metabolism
# 	 [D] Model NGV Unit Metabolism is Model of a metabolic system of a Neuron/Glia/Vasculature unit.
# 	 [R] Model NGV Unit Metabolism is a Model NGV Unit.
# 	 [R] Model NGV Unit Metabolism is a model of NGV Unit.
#
# Node:  NGV Unit
# 	 [D] NGV Unit is An NGV Unit at Blue Brain refers to a "minimal" neuro-glia-vasculatur unit including metabolism of a capillary, neuron and astrocyte. The Molecular Systems team at Blue Brain reconstructs and simulates such an NGV Unit. Multiple NGV Units are put together to form an NGV Column which is used to enhance the neocortical column with metabolism..
# 	 [R] NGV Unit is a Biological Brain Component.
# 	 [R] NGV Unit is a Molecular Compartment.
#
# Node:  Model Neuron Metabolism
# 	 [D] Model Neuron Metabolism is Model of a metabolic network of a neuron..
# 	 [R] Model Neuron Metabolism is a Model Neuron.
# 	 [R] Model Neuron Metabolism is a part of Model NGV Unit Metabolism.
# 	 [R] Model Neuron Metabolism is a model of Neuron.
#
# Node:  I2 Synapse Type
# 	 [R] I2 Synapse Type is a Depressing Synapse Type.
# 	 [R] I2 Synapse Type is a Inhibitory Synapse Type.
#
# Node:  Depressing Synapse Type
# 	 [R] Depressing Synapse Type is a Synapse Plasticity Type.
#
# Node:  Inhibitory Synapse Type
# 	 [R] Inhibitory Synapse Type is a Neurotransmitter Synapse Type.
#
# Node:  EModel Parameter Constraint Generation Workflow
# 	 [R] EModel Parameter Constraint Generation Workflow is a Parameter Constraint Generation Workflow.
# 	 [R] EModel Parameter Constraint Generation Workflow generates EModel Parameter Constraint.
#
# Node:  Parameter Constraint Generation Workflow
# 	 [R] Parameter Constraint Generation Workflow is a Workflow.
# 	 [R] Parameter Constraint Generation Workflow generates Model Brain Parameter Constraint.
#
# Node:  EModel Parameter Constraint
# 	 [R] EModel Parameter Constraint is a Model Brain Parameter Constraint.
#
# Node:  EModel Simulation Workflow
# 	 [R] EModel Simulation Workflow is a Brain Component Simulation Workflow.
# 	 [R] EModel Simulation Workflow generates Trace.
# 	 [R] EModel Simulation Workflow uses EModel.
#
# Node:  Brain Component Simulation Workflow
# 	 [R] Brain Component Simulation Workflow is a Workflow.
# 	 [R] Brain Component Simulation Workflow generates Dataset.
# 	 [R] Brain Component Simulation Workflow about Biological Brain Component.
# 	 [R] Brain Component Simulation Workflow uses Model Brain Component.
#
# Node:  Trace
# 	 [R] Trace is a Electrical Series.
# 	 [R] Trace hasMType Neuron Morphological Type.
#
# Node:  EModel
# 	 [R] EModel is a Model Neuron.
# 	 [R] EModel is a model of Neuron Electrical Type.
#
# Node:  EModel Parameter
# 	 [R] EModel Parameter is a Model Brain Parameter.
#
# Node:  Neuron Part Feature
# 	 [R] Neuron Part Feature is a Subcellular Part Feature.
#
# Node:  Neuron Part
# 	 [R] Neuron Part is a Subcellular Part.
# 	 [R] Neuron Part is a part of Neuron.
# 	 [R] Neuron Part has feature Neuron Part Feature.
#
# Node:  Electrical Stimulus
# 	 [R] Electrical Stimulus is a Entity.
#
# Node:  Model Extracellular Part
# 	 [R] Model Extracellular Part is a Model Brain Component.
# 	 [R] Model Extracellular Part is a model of Extracellular Part.
#
# Node:  Persistent K+ Current
# 	 [D] Persistent K+ Current is The persistent component of the potassium current.
# 	 [S] Persistent K+ Current is also know as Persistent potassium current.
# 	 [S] Persistent K+ Current is referred to as Persistent potassium current.
# 	 [S] Persistent K+ Current is also know as K_Pst.
# 	 [S] Persistent K+ Current is referred to as K_Pst.
# 	 [R] Persistent K+ Current is a Ionic Mechanism.
# 	 [R] Persistent K+ Current ion K.
#
# Node:  Subcellular Part Metabolism Building Workflow
# 	 [R] Subcellular Part Metabolism Building Workflow is a Subcellular Part Building Workflow.
# 	 [R] Subcellular Part Metabolism Building Workflow generates Model Subcellular Part Metabolism.
# 	 [R] Subcellular Part Metabolism Building Workflow about Subcellular Part.
# 	 [R] Subcellular Part Metabolism Building Workflow uses Model Biochemical Reaction.
#
# Node:  Subcellular Part Building Workflow
# 	 [R] Subcellular Part Building Workflow is a Model Building Workflow.
# 	 [R] Subcellular Part Building Workflow generates Model Subcellular Part.
# 	 [R] Subcellular Part Building Workflow about Subcellular Part.
#
# Node:  Subcellular Part
# 	 [D] Subcellular Part is A Subcellular Part is a biological brain component with a level of organisation lower than the cellular..
# 	 [E] Examples of Subcellular Part include A mitochondrion is a subcellular part..
# 	 [E] A mitochondrion is a subcellular part. is an example of Subcellular Part.
# 	 [E] Different examples of Subcellular Part such as A mitochondrion is a subcellular part..
# 	 [R] Subcellular Part is a Biological Brain Component.
# 	 [R] Subcellular Part is a Molecular Compartment.
# 	 [R] Subcellular Part is a part of Brain Cell.
# 	 [R] Subcellular Part has feature Subcellular Part Feature.
#
# Node:  Model Reaction Parameter Optimization Workflow
# 	 [R] Model Reaction Parameter Optimization Workflow is a Parameter Optimization Workflow.
# 	 [R] Model Reaction Parameter Optimization Workflow is a part of Model Reaction Building Workflow.
# 	 [R] Model Reaction Parameter Optimization Workflow generates Model Biochemical Reaction Parameter.
# 	 [R] Model Reaction Parameter Optimization Workflow hasTarget Steady State Molecular Concentration.
# 	 [R] Model Reaction Parameter Optimization Workflow uses Reaction Rate Equation.
# 	 [R] Model Reaction Parameter Optimization Workflow uses Molecular Concentration.
#
# Node:  Model Reaction Building Workflow
# 	 [R] Model Reaction Building Workflow is a Model Building Workflow.
# 	 [R] Model Reaction Building Workflow generates Model Biochemical Reaction.
# 	 [R] Model Reaction Building Workflow has parameter Model Biochemical Reaction Parameter.
# 	 [R] Model Reaction Building Workflow about Biochemical Reaction.
# 	 [R] Model Reaction Building Workflow hasTarget Steady State Molecular Concentration.
# 	 [R] Model Reaction Building Workflow uses Reaction Rate Equation.
# 	 [R] Model Reaction Building Workflow uses Molecular Concentration.
#
# Node:  Reaction Rate Equation
# 	 [D] Reaction Rate Equation is A rate equation or rate law is a mathematical expression used in chemical kinetics to link the rate of a reaction to the concentration of each reactant..
# 	 [R] Reaction Rate Equation is a Equation.
#
# Node:  Molecular Concentration
# 	 [D] Molecular Concentration is Concentration value of a given molecule in a given molecular compartment.
# 	 [S] Molecular Concentration is also know as Molecular Concentration Value.
# 	 [S] Molecular Concentration is referred to as Molecular Concentration Value.
# 	 [R] Molecular Concentration is a Dataset.
#
# Node:  Predicted Data
# 	 [R] Predicted Data is a Data Generation Modality.
#
# Node:  Data Generation Modality
# 	 [R] Data Generation Modality is a Entity.
#
# Node:  Feature Extraction Workflow
# 	 [R] Feature Extraction Workflow is a Workflow.
# 	 [R] Feature Extraction Workflow is a part of Model Building Workflow.
# 	 [R] Feature Extraction Workflow generates Brain Component Feature.
# 	 [R] Feature Extraction Workflow uses Dataset.
#
# Node:  Protein Protein Interaction
# 	 [R] Protein Protein Interaction is a Biochemical Reaction.
#
# Node:  Biochemical Reaction
# 	 [D] Biochemical Reaction is A chemical process of transformation of some molecules (substrates) into the other molecules (products)..
# 	 [R] Biochemical Reaction is a Biological Brain Activity.
#
# Node:  Neuron Building Workflow
# 	 [R] Neuron Building Workflow is a Cell Building Workflow.
# 	 [R] Neuron Building Workflow generates Model Neuron.
# 	 [R] Neuron Building Workflow about Neuron.
#
# Node:  Neuron Electrical Type
# 	 [R] Neuron Electrical Type is a Neuron Type.
# 	 [R] Neuron Electrical Type has feature Neuron Electrophysiological Feature.
#
# Node:  Association
# 	 [D] Association is An activity association is an assignment of responsibility to an agent for an activity, indicating that the agent had a role in the activity. It further allows for a plan to be specified, which is the plan intended by the agent to achieve some goals in the context of this activity..
# 	 [R] Association is a Data Provenance.
#
# Node:  SO-CMA
# 	 [D] SO-CMA is Single-objective covariance matrix adaptation evolution strategy..
# 	 [R] SO-CMA is a EModel Parameter Optimizer.
# 	 [R] SO-CMA is a Evolutionary Algorithm.
#
# Node:  lateral geniculate nucleus parvocellular layer
# 	 [R] lateral geniculate nucleus parvocellular layer is a Brain Area.
#
# Node:  Serotonin
# 	 [D] Serotonin is A monoamine neurotransmitter. Its biological function is complex and multifaceted, modulating mood, cognition, reward, learning, memory, and numerous physiological processes such as vomiting and vasoconstriction. Biochemically, the indoleamine molecule derives from the amino acid tryptophan, via the (rate-limiting) hydroxylation of the 5 position on the ring (forming the intermediate 5-hydroxytryptophan), and then decarboxylation to produce serotonin. Serotonin is primarily found in the enteric nervous system located in the gastrointestinal tract (GI tract). However, it is also produced in the central nervous system (CNS), specifically in the raphe nuclei located in the brainstem, Merkel cells located in the skin, pulmonary neuroendocrine cells and taste receptor cells in the tongue. Additionally, serotonin is stored in blood platelets and is released during agitation and vasoconstriction, where it then acts as an agonist to other platelets..
# 	 [R] Serotonin is a Excitatory Transmitter.
# 	 [R] Serotonin is a Neuromodulator.
#
# Node:  Model Brain Activity
# 	 [D] Model Brain Activity is A computational model of any measurable electrical or chemical activity in the real brain..
# 	 [R] Model Brain Activity is a Entity.
# 	 [R] Model Brain Activity is a model of Biological Brain Activity.
#
# Node:  Reconstructing Model Brain
# 	 [R] Reconstructing Model Brain is a Brain Modeling Activity.
#
# Node:  Model NGV Unit
# 	 [R] Model NGV Unit is a Model Brain Component.
# 	 [R] Model NGV Unit is a model of NGV Unit.
#
# Node:  Vein
# 	 [D] Vein is Veins are blood vessels that carry blood towards the heart..
# 	 [R] Vein is a Blood Vessel.
#
# Node:  Blood Vessel
# 	 [D] Blood Vessel is A blood vessel is a component of the vascular system that carries blood throughout in the body.
# 	 [R] Blood Vessel is a Brain Vascular Component.
#
# Node:  Subject
# 	 [R] Subject is a Entity.
# 	 [R] Subject species Species.
#
# Node:  Testosterone
# 	 [R] Testosterone is a Hormone.
#
# Node:  Excitatory Neuron
# 	 [D] Excitatory Neuron is A neuron that releases excitatory neurotransmitters. These types of neurotransmitters have excitatory effects on the neuron, meaning they increase the likelihood that the neuron will fire an action potential. Some of the major excitatory neurotransmitters include epinephrine and norepinephrine..
# 	 [S] Excitatory Neuron is also know as Excitatory Neuron.
# 	 [S] Excitatory Neuron is referred to as Excitatory Neuron.
# 	 [R] Excitatory Neuron is a Neurotransmitter Type.
#
# Node:  Organization
# 	 [D] Organization is An organization is a social or legal institution such as a company, society, etc..
# 	 [R] Organization is a Brain Modeling Agent.
#
# Node:  Model Brain Volume Building Workflow
# 	 [R] Model Brain Volume Building Workflow is a Model Building Workflow.
# 	 [R] Model Brain Volume Building Workflow generates Model Brain Volume.
# 	 [R] Model Brain Volume Building Workflow uses Brain Volume Blueprint.
# 	 [R] Model Brain Volume Building Workflow uses Model Neuron.
#
# Node:  Metabolite
# 	 [R] Metabolite is a Molecule.
#
# Node:  Molecule
# 	 [D] Molecule is A molecule is an electrically neutral group of two or more atoms held together by chemical bonds..
# 	 [R] Molecule is a Biological Brain Component.
#
# Node:  Model Brain Volume Parameter
# 	 [R] Model Brain Volume Parameter is a Model Brain Parameter.
#
# Node:  Molecular Compartment Feature
# 	 [R] Molecular Compartment Feature is a Brain Component Feature.
#
# Node:  Model Brain Parameter Constraint
# 	 [R] Model Brain Parameter Constraint is a Entity.
# 	 [R] Model Brain Parameter Constraint constraints Model Brain Parameter.
#
# Node:  Neuron ME Type
# 	 [S] Neuron ME Type is also know as METype.
# 	 [S] Neuron ME Type is referred to as METype.
# 	 [R] Neuron ME Type is a Neuron Type.
#
# Node:  Gene
# 	 [D] Gene is In biology, a gene is a basic unit of heredity and a sequence of nucleotides in DNA or RNA that encodes the synthesis of a gene product, either RNA or protein..
# 	 [R] Gene is a Biological Brain Component.
#
# Node:  Model Subcellular Part
# 	 [R] Model Subcellular Part is a Model Brain Component.
# 	 [R] Model Subcellular Part is a model of Subcellular Part.
#
# Node:  Sodium Channel
# 	 [R] Sodium Channel is a Ion Channel.
# 	 [R] Sodium Channel associatedIon Na.
#
# Node:  Na
# 	 [S] Na is also know as Sodium.
# 	 [S] Na is referred to as Sodium.
# 	 [R] Na is a Ion.
#
# Node:  Model Cytosol Metabolism
# 	 [R] Model Cytosol Metabolism is a Model Subcellular Part Metabolism.
# 	 [R] Model Cytosol Metabolism is a model of Cytosol.
#
# Node:  Cytosol
# 	 [R] Cytosol is a Subcellular Part.
#
# Node:  Inferred Data
# 	 [R] Inferred Data is a Data Generation Modality.
#
# Node:  Glutamate
# 	 [R] Glutamate is a Classical Neurotransmitter.
# 	 [R] Glutamate is a Excitatory Transmitter.
#
# Node:  Cellular Component
# 	 [D] Cellular Component is A location, relative to cellular compartments and structures, occupied by a macromolecular machine when it carries out a molecular function. There are two ways in which the gene ontology describes locations of gene products: (1) relative to cellular structures (e.g., cytoplasmic side of plasma membrane) or compartments (e.g., mitochondrion), and (2) the stable macromolecular complexes of which they are parts (e.g., the ribosome)..
# 	 [S] Cellular Component is also know as cell or subcellular entity.
# 	 [S] Cellular Component is referred to as cell or subcellular entity.
# 	 [S] Cellular Component is also know as cellular component.
# 	 [S] Cellular Component is referred to as cellular component.
# 	 [R] Cellular Component http://www.w3.org/2002/07/owl#equivalentClass Subcellular Part.
#
# Node:  Brain Atlas Spatial Reference System
# 	 [D] Brain Atlas Spatial Reference System is The Atlas Spatial Reference System is an entity which is the spatial reference system used as reference for a brain atlas. It can be described by information about the point of origin of the reference system, the orientation of the refernece system, the bounding box usde and the dimension unit of the brain atlas space..
# 	 [R] Brain Atlas Spatial Reference System is a Entity.
#
# Node:  Circuit Connectivity Blueprint
# 	 [R] Circuit Connectivity Blueprint is a Brain Component Blueprint.
#
# Node:  Person
# 	 [D] Person is Person agents are people..
# 	 [R] Person is a Brain Modeling Agent.
#
# Node:  Neocortical Thalamic System
# 	 [D] Neocortical Thalamic System is The Neocortical Thalamic system is a brain system composed of two brain regions, the Neocortex and Thalamus with all the connections between them. The Neocortical Thalamic System includes all Brain Areas of the Neocortex and Thalamus and their intrinsic, afferent and efferent connections..
# 	 [S] Neocortical Thalamic System is also know as NCT System.
# 	 [S] Neocortical Thalamic System is referred to as NCT System.
# 	 [R] Neocortical Thalamic System is a Brain System.
#
# Node:  Non-specific Channel
# 	 [R] Non-specific Channel is a Ion Channel.
#
# Node:  Brain Location
# 	 [R] Brain Location is a Entity.
# 	 [R] Brain Location brainLayer Brain Layer.
# 	 [R] Brain Location brainRegion Brain Region.
# 	 [R] Brain Location coordinatesInAtlas Vector3D.
#
# Node:  Object Of Study
# 	 [R] Object Of Study is a Entity.
#
# Node:  Neuron Morphological Type
# ...
#
# Node:  Principle
# 	 [R] Principle is a Entity.
#
# Node:  Neuron Metabolism Building Workflow
# 	 [R] Neuron Metabolism Building Workflow is a Neuron Building Workflow.
# 	 [R] Neuron Metabolism Building Workflow generates Model Neuron Metabolism.
# 	 [R] Neuron Metabolism Building Workflow uses Model Biochemical Reaction.
# 	 [R] Neuron Metabolism Building Workflow uses Model Subcellular Part Metabolism.
#
# Node:  WorkflowDefinition
# 	 [R] WorkflowDefinition is a Entity.
#
# Node:  H Current
# 	 [D] H Current is Hyperpolarization-activated current..
# 	 [S] H Current is also know as Ih.
# 	 [S] H Current is referred to as Ih.
# 	 [R] H Current is a Ionic Mechanism.
#
# Node:  CA1 field of hippocampus
# 	 [R] CA1 field of hippocampus is a Brain Area.
#
# Node:  Tau decay CaDynamics DC0
# 	 [D] Tau decay CaDynamics DC0 is Time constant of calcium ion diffusion..
# 	 [R] Tau decay CaDynamics DC0 is a Calcium Dynamics.
#
# Node:  Neuron Molecular Type
# 	 [R] Neuron Molecular Type is a Neuron Type.
#
# Node:  Ca2+ Activated K+ Current
# 	 [D] Ca2+ Activated K+ Current is Small-conductance calcium-activated potassium current..
# 	 [S] Ca2+ Activated K+ Current is also know as SK_E2.
# 	 [S] Ca2+ Activated K+ Current is referred to as SK_E2.
# 	 [R] Ca2+ Activated K+ Current is a Ionic Mechanism.
# 	 [R] Ca2+ Activated K+ Current ion K.
#
# Node:  VIP+
# 	 [R] VIP+ is a Neuron Molecular Type.
#
# Node:  cAD
# 	 [R] cAD is a Neuron Electrical Type.
#
# Node:  Data Generalization Rule
# 	 [R] Data Generalization Rule is a Rule.
# 	 [R] Data Generalization Rule premise Premise.
# 	 [R] Data Generalization Rule searchQuery Query.
#
# Node:  Premise
# 	 [R] Premise is a Entity.
#
# Node:  Circuit Connectivity Blueprint Building Workflow
# 	 [R] Circuit Connectivity Blueprint Building Workflow is a Blueprint Building Workflow.
# 	 [R] Circuit Connectivity Blueprint Building Workflow generates Circuit Connectivity Blueprint.
# 	 [R] Circuit Connectivity Blueprint Building Workflow uses Bouton Density.
# 	 [R] Circuit Connectivity Blueprint Building Workflow uses Model Brain Volume.
# 	 [R] Circuit Connectivity Blueprint Building Workflow uses Number Of Synapses Per Connection.
#
# Node:  Bouton Density
# 	 [R] Bouton Density is a Brain Volume Feature.
# 	 [R] Bouton Density is a Model Connectivity Parameter.
# 	 [R] Bouton Density brainLocation Brain Location.
# 	 [R] Bouton Density cellType Brain Cell Type.
#
# Node:  Estrogen
# 	 [R] Estrogen is a Hormone.
#
# Node:  PV+
# 	 [R] PV+ is a Neuron Molecular Type.
#
# Node:  SST+
# 	 [R] SST+ is a Neuron Molecular Type.
#
# Node:  Brain Atlas Release
# 	 [D] Brain Atlas Release is The Atlas Release is an entity which describes the release of a brain atlas. An atlas release can be described by the release date and the template volume, parcellation volume, parcellation ontology and spatial reference system used..
# 	 [R] Brain Atlas Release is a Entity.
#
# Node:  Oligodendrocyte
# 	 [S] Oligodendrocyte is also know as Oligodendrocyte.
# 	 [S] Oligodendrocyte is referred to as Oligodendrocyte.
# 	 [R] Oligodendrocyte is a Glia.
#
# Node:  Facilitating Synapse Type
# 	 [R] Facilitating Synapse Type is a Synapse Plasticity Type.
#
# Node:  Persistent Na+ Current
# 	 [D] Persistent Na+ Current is Persistent sodium current..
# 	 [R] Persistent Na+ Current is a Ionic Mechanism.
# 	 [R] Persistent Na+ Current ion Na.
#
# Node:  Pyramidal Neuron
# 	 [D] Pyramidal Neuron is A neuron with a pyramidal shaped soma and two distinct dendritic trees. The basal dendrites emerge from the base and the apical dendrites from the apex of the pyramidal cell body..
# 	 [S] Pyramidal Neuron is also know as Pyramidal cell.
# 	 [S] Pyramidal Neuron is referred to as Pyramidal cell.
# 	 [R] Pyramidal Neuron is a Neuron Morphological Type.
#
# Node:  Brain Layer
# 	 [D] Brain Layer is A Brain Layer is a layer of a laminar region in the brain. Laminar regions include e.g. the Neocortex or the Hippocampus..
# 	 [E] Examples of Brain Layer include CA1 stratum oriens is an example of a brain layer in the Hippocampus., Layer 1 is an example of a brain layer in the Neocortex..
# 	 [E] CA1 stratum oriens is an example of a brain layer in the Hippocampus., Layer 1 is an example of a brain layer in the Neocortex. is an example of Brain Layer.
# 	 [E] Different examples of Brain Layer such as CA1 stratum oriens is an example of a brain layer in the Hippocampus., Layer 1 is an example of a brain layer in the Neocortex..
# 	 [R] Brain Layer is a Biological Brain Component.
# 	 [R] Brain Layer is a Brain Volume.
# 	 [R] Brain Layer is a part of Brain Area.
# 	 [R] Brain Layer is a part of Brain Region.
#
# Node:  Synaptic Strength
# 	 [R] Synaptic Strength is a Synapse Feature.
#
# Node:  Axon
# 	 [R] Axon is a Neuron Part.
# 	 [R] Axon is a part of Neuron.
#
# Node:  Endoplasmic Reticulum
# 	 [R] Endoplasmic Reticulum is a Organelle.
#
# Node:  Neocortical Layer
# 	 [D] Neocortical Layer is One of the layers of the neocortex..
# 	 [S] Neocortical Layer is also know as layer of neocortex.
# 	 [S] Neocortical Layer is referred to as layer of neocortex.
# 	 [S] Neocortical Layer is also know as Neocortical Layer.
# 	 [S] Neocortical Layer is referred to as Neocortical Layer.
# 	 [R] Neocortical Layer is a Brain Layer.
#
# Node:  Number Of Synapses
# 	 [R] Number Of Synapses is a Synaptic Connection Feature.
#
# Node:  I1 Synapse Type
# 	 [R] I1 Synapse Type is a Facilitating Synapse Type.
# 	 [R] I1 Synapse Type is a Inhibitory Synapse Type.
#
# Node:  Transient Na+ Current
# 	 [D] Transient Na+ Current is Transient sodium current..
# 	 [R] Transient Na+ Current is a Ionic Mechanism.
# 	 [R] Transient Na+ Current ion Na.
#
# Node:  Experimental Activity
# 	 [D] Experimental Activity is An experimental activity is any activity associated with generating data from a biological brain in a lab or a digital tissue in silico..
# 	 [R] Experimental Activity is a Activity.
#
# Node:  EModel Parameter Optimization Batch Size
# 	 [D] EModel Parameter Optimization Batch Size is The number of optimization seeds to run in parallel for each batch of optimization launched by the Luigi pipeline..
# 	 [R] EModel Parameter Optimization Batch Size is a EModel Hyperparameter.
#
# Node:  Capillary
# 	 [D] Capillary is A capillary is the smallest blood vessel in the body..
# 	 [R] Capillary is a Blood Vessel.
#
# Node:  Microglia
# 	 [S] Microglia is also know as Microglia.
# 	 [S] Microglia is referred to as Microglia.
# 	 [R] Microglia is a Glia.
#
# Node:  MO-CMA
# 	 [D] MO-CMA is Multi-objective covariance matrix adaptation evolution strategy..
# 	 [R] MO-CMA is a EModel Parameter Optimizer.
# 	 [R] MO-CMA is a Evolutionary Algorithm.
#
# Node:  Electrical Series
# 	 [R] Electrical Series is a Time Series.
#
# Node:  Section Regions
# 	 [R] Section Regions is a Neurite Location Feature.
#
# Node:  Neuron Morphological Feature
# 	 [R] Neuron Morphological Feature is a Neuron Feature.
#
# Node:  Data Provenance
# 	 [D] Data Provenance is Data provenance refers to records of the inputs, entities, systems, and processes that influence data of interest, providing a historical record of the data and its origins..
#
# Node:  Max Generations
# 	 [D] Max Generations is Maximum number of generation in the genetic algorithm for optimization..
# 	 [R] Max Generations is a EModel Hyperparameter.
#
# Node:  EModel Parameter Optimization Stochasticity
# 	 [D] EModel Parameter Optimization Stochasticity is A flag indicating whether stochasticity should be enabled for the channels that can be stochastic..
# 	 [R] EModel Parameter Optimization Stochasticity is a EModel Hyperparameter.
#
# Node:  Lamp+
# 	 [R] Lamp+ is a Neuron Molecular Type.
#
# Node:  Ca_LVAst
# 	 [D] Ca_LVAst is Low-voltage-gaterd calcium current.
# 	 [R] Ca_LVAst is a Ionic Mechanism.
# 	 [R] Ca_LVAst ion Ca.
#
# Node:  Glia Type
# 	 [R] Glia Type is a Brain Cell Type.
#
# Node:  PerisomaticCurrentFiringFeature
# 	 [D] PerisomaticCurrentFiringFeature is Feature of perisomatic firing response to current steps.
# 	 [R] PerisomaticCurrentFiringFeature is a Neuron Electrophysiological Feature.
# 	 [R] PerisomaticCurrentFiringFeature compartment Soma.
#
# Node:  EModel Validation Workflow
# 	 [R] EModel Validation Workflow is a Model Validation Workflow.
# 	 [R] EModel Validation Workflow hasTarget Neuron Electrophysiological Feature.
# 	 [R] EModel Validation Workflow uses Trace.
#
# Node:  Extracellular Part Building Workflow
# 	 [R] Extracellular Part Building Workflow is a Model Building Workflow.
# 	 [R] Extracellular Part Building Workflow generates Model Extracellular Part.
#
# Node:  E1 Synapse Type
# 	 [R] E1 Synapse Type is a Facilitating Synapse Type.
# 	 [R] E1 Synapse Type is a Excitatory Synapse Type.
#
# Node:  Electrophysiological Feature Extraction Workflow
# 	 [R] Electrophysiological Feature Extraction Workflow is a Feature Extraction Workflow.
# 	 [R] Electrophysiological Feature Extraction Workflow is a part of EModel Building Workflow.
# 	 [R] Electrophysiological Feature Extraction Workflow generates Neuron Electrophysiological Feature.
# 	 [R] Electrophysiological Feature Extraction Workflow uses Trace.
#
# Node:  Mus Musculus
# 	 [S] Mus Musculus is also know as M. musculus.
# 	 [S] Mus Musculus is referred to as M. musculus.
# 	 [S] Mus Musculus is also know as Mouse.
# 	 [S] Mus Musculus is referred to as Mouse.
# 	 [S] Mus Musculus is also know as house mouse.
# 	 [S] Mus Musculus is referred to as house mouse.
# 	 [R] Mus Musculus is a Species.
#
# Node:  Extracellular Part Metabolism Building Workflow
# 	 [R] Extracellular Part Metabolism Building Workflow is a Extracellular Part Building Workflow.
# 	 [R] Extracellular Part Metabolism Building Workflow generates Model Extracellular Part Metabolism.
# 	 [R] Extracellular Part Metabolism Building Workflow about Extracellular Part.
# 	 [R] Extracellular Part Metabolism Building Workflow uses Model Biochemical Reaction.
#
# Node:  Model Reaction Simulation Workflow
# 	 [R] Model Reaction Simulation Workflow is a Brain Component Simulation Workflow.
# 	 [R] Model Reaction Simulation Workflow generates Molecular Concentration Series.
# 	 [R] Model Reaction Simulation Workflow uses Model Biochemical Reaction.
#
# Node:  Experimental Data
# 	 [R] Experimental Data is a Data Generation Modality.
#
# Node:  Neuron Transcriptome Type
# 	 [R] Neuron Transcriptome Type is a Neuron Type.
# 	 [R] Neuron Transcriptome Type expressionProfile Gene Expression Profile.
# 	 [R] Neuron Transcriptome Type gene Gene.
#
# Node:  Gene Expression Profile
# 	 [R] Gene Expression Profile is a Dataset.
#
# Node:  Reaction Kinetic Parameter
# 	 [D] Reaction Kinetic Parameter is Kinetic parameter is a parameter in the rate equation of the chemical process (reaction, transport, diffusion)..
# 	 [R] Reaction Kinetic Parameter is a Model Biochemical Reaction Parameter.
#
# Node:  Noradrenaline
# 	 [D] Noradrenaline is An organic chemical in the catecholamine family that functions in the brain and body as both a hormone and neurotransmitter. The general function of norepinephrine is to mobilize the brain and body for action. Norepinephrine release is lowest during sleep, rises during wakefulness, and reaches much higher levels during situations of stress or danger, in the so-called fight-or-flight response. In the brain, norepinephrine increases arousal and alertness, promotes vigilance, enhances formation and retrieval of memory, and focuses attention; it also increases restlessness and anxiety. In the rest of the body, norepinephrine increases heart rate and blood pressure, triggers the release of glucose from energy stores, increases blood flow to skeletal muscle, reduces blood flow to the gastrointestinal system, and inhibits voiding of the bladder and gastrointestinal motility..
# 	 [S] Noradrenaline is also know as NA.
# 	 [S] Noradrenaline is referred to as NA.
# 	 [S] Noradrenaline is also know as NE.
# 	 [S] Noradrenaline is referred to as NE.
# 	 [S] Noradrenaline is also know as Noradrenalin.
# 	 [S] Noradrenaline is referred to as Noradrenalin.
# 	 [S] Noradrenaline is also know as Norepinephrine.
# 	 [S] Noradrenaline is referred to as Norepinephrine.
# 	 [R] Noradrenaline is a Neuromodulator.
#
# Node:  Ionic Mechanism Building Workflow
# 	 [R] Ionic Mechanism Building Workflow is a Model Building Workflow.
# 	 [R] Ionic Mechanism Building Workflow generates Model Ionic Mechanism.
# 	 [R] Ionic Mechanism Building Workflow about Ionic Mechanism.
#
# Node:  Apical Dendrite
# 	 [R] Apical Dendrite is a Dendrite.
#
# Node:  regional part of brain
# 	 [D] regional part of brain is Anatomical divisons of the brain according to one or more criteria, e.g. cytoarchitectural, gross anatomy. Parts may be contiguous in 3D or not, e.g., basal ganglia..
# 	 [S] regional part of brain is also know as regional part of brain.
# 	 [S] regional part of brain is referred to as regional part of brain.
# 	 [R] regional part of brain http://www.w3.org/2002/07/owl#equivalentClass Brain Region.
#
# Node:  Quantitative Value
# 	 [R] Quantitative Value is a Entity.
#
# Node:  Steady State Concentration Extraction Workflow
# 	 [R] Steady State Concentration Extraction Workflow is a Feature Extraction Workflow.
# 	 [R] Steady State Concentration Extraction Workflow is a part of Model Reaction Building Workflow.
# 	 [R] Steady State Concentration Extraction Workflow generates Steady State Molecular Concentration.
# 	 [R] Steady State Concentration Extraction Workflow uses Molecular Concentration Series.
#
# Node:  Neuron Projection Feature
# 	 [D] Neuron Projection Feature is A feature associated with a neuron projection, a process extending from a neural cell, such as axons or dendrites (collectively called neurites)..
# 	 [R] Neuron Projection Feature is a Neuron Feature.
#
# Node:  Modulatory Synapse Type
# 	 [R] Modulatory Synapse Type is a Neurotransmitter Synapse Type.
#
# Node:  I3 Synapse Type
# 	 [R] I3 Synapse Type is a Inhibitory Synapse Type.
# 	 [R] I3 Synapse Type is a Pseudo-Linear Synapse Type.
#
# Node:  Interneuron
# 	 [S] Interneuron is also know as Interneuron.
# 	 [S] Interneuron is referred to as Interneuron.
# 	 [R] Interneuron is a Neuron.
#
# Node:  Cl
# 	 [S] Cl is also know as Chloride.
# 	 [S] Cl is referred to as Chloride.
# 	 [R] Cl is a Ion.
#
# Node:  SKv3_1
# 	 [D] SKv3_1 is Small-conductance voltage-gated Kv3.1 potassium current.
# 	 [R] SKv3_1 is a Ionic Mechanism.
# 	 [R] SKv3_1 ion K.
#
# Node:  IC Selector-Based Ion Channel Density Constraint Generation Workflow
# 	 [R] IC Selector-Based Ion Channel Density Constraint Generation Workflow is a Ion Density Constraint Generation Workflow.
# 	 [R] IC Selector-Based Ion Channel Density Constraint Generation Workflow uses Ion Channel Density Constraint.
# 	 [R] IC Selector-Based Ion Channel Density Constraint Generation Workflow generates Ion Channel Density Constraint.
#
# Node:  Dopamine
# 	 [D] Dopamine is A neuromodulatory molecule that plays several important roles in cells. It is an organic chemical of the catecholamine and phenethylamine families. In the brain, dopamine functions as a neurotransmitter—a chemical released by neurons (nerve cells) to send signals to other nerve cells. Neurotransmitters are synthesized in specific regions of the brain, but affect many regions systemically. The brain includes several distinct dopamine pathways, one of which plays a major role in the motivational component of reward-motivated behavior. The anticipation of most types of rewards increases the level of dopamine in the brain, and many addictive drugs increase dopamine release or block its reuptake into neurons following release..
# 	 [R] Dopamine is a Excitatory Transmitter.
# 	 [R] Dopamine is a Neuromodulator.
#
# Node:  CA2 field of hippocampus
# 	 [R] CA2 field of hippocampus is a Brain Area.
#
# Node:  Complex
# 	 [D] Complex is A protein complex or multiprotein complex is a group of two or more associated polypeptide chains..
# 	 [R] Complex is a Molecule.
#
# Node:  Default Ion Channel Density Constraint Generation Workflow
# 	 [R] Default Ion Channel Density Constraint Generation Workflow is a Ion Density Constraint Generation Workflow.
# 	 [R] Default Ion Channel Density Constraint Generation Workflow generates Ion Channel Density Constraint.
#
# Node:  Model Synapse Building Workflow
# 	 [R] Model Synapse Building Workflow is a Model Building Workflow.
# 	 [R] Model Synapse Building Workflow generates Model Synapse.

# %%
with open("../data/synthetic_texts.json", "w") as f:
    json.dump(synthetic_text, f)

# %%
dataset = Dataset(
    forge,
    name="Synthetic Sentences from BMO",
    description="This dataset contains a set of annotated synthetic texts generated from the BMO.")
dataset.add_distribution(
    "../data/synthetic_texts.json",
    content_type="application/json")
forge.register(dataset)
# Out:
# <action> _register_one
# <succeeded> True

# %% [markdown]
# # 2. Use Wikipedia to extract some more text

# %%
MANUAL_MAP = {
    "EModel": "https://en.wikipedia.org/wiki/Biological_neuron_model",
    "GABA": "https://en.wikipedia.org/wiki/GABA_receptor",
    "Whole Brain": "https://en.wikipedia.org/wiki/Brain",
    "K": "https://en.wikipedia.org/wiki/Potassium",
    "Na": "https://en.wikipedia.org/wiki/Sodium",
    "Ca": "https://en.wikipedia.org/wiki/Calcium"
}

# %%
TERMS_TO_IGNORE = {
    "Kv11",
    "Interstitial Space",
    "Brain Area",
    "IBEA",
    "NGV Unit",
    "MO-CMA",
    "SO-CMA",
    "Model Cell",
    "Quantitative Value",
    "Vector3D",
    "Trace",
    "Subject",
    "Brain Layer",
    "Model Glia",
    "Lamp+",
    "SST+",
    "VIP+",
    "cAD",
    "PV+",
    "MEModel",
    "Neuron Part"
}

# %%
WIKI_SEARCH_MAPPING = {}
for node in graph.nodes():
    if node not in TERMS_TO_IGNORE and node not in MANUAL_MAP:
        res = search_wiki(node.lower())
        if res is not None:
            WIKI_SEARCH_MAPPING[node] = res[1]

# %%
ALL_MAPPED_ENTITIES = {**WIKI_SEARCH_MAPPING, **MANUAL_MAP}

# %% [markdown]
# Create a reverse mapping of wiki pages to BMO terms

# %%
wiki_to_bmo = {
    v: f"https://bbp.epfl.ch/ontologies/core/bmo/{k.replace(' ', '')}"
    for k, v in ALL_MAPPED_ENTITIES.items()
}

# %% [markdown]
# ## 2.2. Get Wiki texts for mapped articles

# %%
corpus = []
for k, v in ALL_MAPPED_ENTITIES.items():
    corpus.append(extract_full_wiki_text(v))

# %%
print("Random extracted text:\n")
index = random.randint(0, len(corpus))
print(corpus[index])
# Out:
# Random extracted text:
#
# A hormone (from the Greek participle ὁρμῶν, "setting in motion") is any member of a class of signaling molecules in multicellular organisms, that are transported by intricate biological processes to distant organs to regulate physiology and behavior. Hormones are required for the correct development of animals, plants and fungi. The lax definition of a hormone (as a signalling molecule that acts distant from its site of production) means that many different classes of molecule can be defined as hormones. Among the substances that can be considered hormones, are eicosanoids (e.g. prostaglandins and thromboxanes), steroids (e.g. oestrogen and brassinosteroid), amino acid derivatives (e.g. epinephrine and auxin), protein / peptides (e.g. insulin and CLE peptides) and gases (e.g ethylene and nitric oxide). Hormones are used to communicate between organs and tissues. In vertebrates, hormones are responsible for the regulation of many physiological processes and behavioral activities such as digestion, metabolism, respiration, sensory perception, sleep, excretion, lactation, stress induction, growth and development, movement, reproduction, and mood manipulation. In plants, hormones modulate almost all aspects of development, from germination to senescence. Hormones affect distant cells by binding to specific receptor proteins in the target cell, resulting in a change in cell function. When a hormone binds to the receptor, it results in the activation of a signal transduction pathway that typically activates gene transcription, resulting in increased expression of target proteins. Hormones can also act in rapid, non-genomic pathways that can be synergistic with genomic effects. Water-soluble hormones (such as peptides and amines) generally act on the surface of target cells via second messengers. Lipid soluble hormones, (such as steroids) generally pass through the plasma membranes of target cells (both cytoplasmic and nuclear) to act within their nuclei. A notable exception to this are brassinosteroids  (Brassinosteroids are a class of polyhydroxysteroids that have been recognized as a sixth class of plant hormones and may have utility as an anticancer drug for endocrine-responsive cancers to induce apoptosis and inhibit growth in plants) which despite being lipid soluble, still bind to their receptor at the cell surface. In vertebrates, endocrine glands are specialized organs that secrete hormones into the endocrine signaling system. Hormone secretion occurs in response to specific biochemical signals and is often subject to negative feedback regulation. For instance, high blood sugar (serum glucose concentration) promotes insulin synthesis. Insulin then acts to reduce glucose levels and maintain homeostasis, leading to reduced insulin levels.  Upon secretion, water soluble hormones are readily transported through the circulatory system. Lipid-soluble hormones must bond to carrier plasma glycoproteins (e.g., thyroxine-binding globulin (TBG)) to form ligand-protein complexes. Completely active hormones can be released into the bloodstream (as seen in insulin and growth hormones), but some travel as prohormones that must be activated in specific cells through a series of activation steps that are commonly highly regulated. The endocrine system secretes hormones directly into the bloodstream, typically via fenestrated capillaries, whereas the exocrine system secretes its hormones indirectly using ducts. Hormones with paracrine function diffuse through the interstitial spaces to nearby target tissue. Plants lack specialized organs for the secretion of hormones, although there is spatial distribution of hormone production. For example, the hormone auxin is produced mainly at the tips of young leaves and in the shoot apical meristem. The lack of specialised glands means that the main site of hormone production can change throughout the life of a plant, and the site of production is dependent on the plant's age and environment. Hormonal s ...

# %% [markdown]
# Extract 'related' articles

# %%
unique_articles = set()
for k in wiki_to_bmo:
    unique_articles.add(k)
    data, incoming_links = query_dbpedia(k)
    print(k)
#     print("In docs: ", len(incoming_links))
    out_links = data.get("http://dbpedia.org/ontology/wikiPageWikiLink", [])
    out_links = [
        el["value"]
        for el in out_links
    ]
#     unique_articles.update(incoming_links)
    unique_articles.update(out_links)

# %%
print("If we want to extract related acticles, could retrieve articles: ", len(unique_articles))
# Out:
# If we want to extract related acticles, could retrieve articles:  5845

# %%
# for el in unique_articles:
#     url_wiki = dbpedia_uri_to_wiki(el)
#     corpus.append(extract_full_wiki_text(url_wiki))

# %% [markdown]
# ## 2.3. Use an existing pre-trained ER model
#
# https://github.com/egerber/spaCy-entity-linker

# %%
# initialize language model
nlp = spacy.load("en_core_web_lg")

# add pipeline (declared through entry_points in setup.py)
nlp.add_pipe("entityLinker", last=True)

# %%
wiki_texts = []

# %%
WIKIDATA_TO_WIKI = {}
for text in corpus:
    try:
        doc = nlp(text)            
        record = {"text": str(doc), "spans": []}
        # returns all entities in the whole document
        all_linked_entities = doc._.linkedEntities
        for i, entity in enumerate(all_linked_entities):
            wikidata_url = entity.url
            if wikidata_url not in WIKIDATA_TO_WIKI:
                wiki_url = wiki_url_from_wikidata(wikidata_url.split("/")[-1], "en")
                WIKIDATA_TO_WIKI[wikidata_url] = wiki_url
            else:
                wiki_url = WIKIDATA_TO_WIKI[wikidata_url]
            if wiki_url in wiki_to_bmo:
                span = {
                    "text": entity.span.text,
                    "start": entity.span.start_char,
                    "end": entity.span.end_char,
                    "label": wiki_to_bmo[wiki_url]
                }
                record["spans"].append(span)
            if i > 30 and len(record["spans"]) == 0:
                break
        if len(record["spans"]) > 0:
            wiki_texts.append(record)
        
    except Exception as e:
        pass

# %%
with open("../data/wiki_texts.json", "w") as f:
    json.dump(wiki_texts, f)

# %%
dataset = Dataset(
    forge,
    name="Wikipedia texts for BMO entities",
    description="This dataset contains a set of annotated Wikipedia texts mentioning various BMO entities.")
dataset.add_distribution(
    "../data/wiki_texts.json",
    content_type="application/json")
forge.register(dataset)
# Out:
# <action> _register_one
# <succeeded> True
